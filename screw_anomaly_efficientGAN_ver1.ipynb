# %% [markdown]
# # 環境確認

# %%
import sys
import torch

print("Pythonのバージョン：",sys.version)
print("PyTorchのバージョン：", torch.__version__)
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# Pythonのバージョン： 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# PyTorchのバージョン： 1.10.0+cu111
# 使用しているGPUの確認
# Mon Feb 21 04:17:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # データのダウンロード

# %%
# データのダウンロード
# !wget https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420938130-1629953152/screw.tar.xz
# Out:
# --2022-02-21 04:17:45--  https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420938130-1629953152/screw.tar.xz
# Resolving www.mydrive.ch (www.mydrive.ch)... 91.214.169.64
# Connecting to www.mydrive.ch (www.mydrive.ch)|91.214.169.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 195344332 (186M) [application/x-xz]
# Saving to: ‘screw.tar.xz’
#
# screw.tar.xz        100%[===================>] 186.29M  16.1MB/s    in 13s
#
# 2022-02-21 04:17:59 (14.3 MB/s) - ‘screw.tar.xz’ saved [195344332/195344332]

# %%
# 解凍
# !tar -xf screw.tar.xz

# %%
# 作業ディレクトリを確認
# !ls
# Out:
# sample_data  screw  screw.tar.xz

# %% [markdown]
# # テストデータの準備

# %%
# テストデータのディレクトリを確認
# !ls screw/test/
# Out:
# good  manipulated_front  scratch_head  scratch_neck  thread_side  thread_top

# %%
# testディレクトリ内のディレクトリ内の画像リストを作成
import glob

good = glob.glob('screw/test/good/*.png')
manipulated_front = glob.glob('screw/test/manipulated_front/*.png')
scratch_head = glob.glob('screw/test/scratch_head/*.png')
scratch_neck = glob.glob('screw/test/scratch_neck/*.png')
thread_side = glob.glob('screw/test/thread_side/*.png')
thread_top = glob.glob('screw/test/thread_top/*.png')
print(good)
print(len(good))
# Out:
# ['screw/test/good/008.png', 'screw/test/good/017.png', 'screw/test/good/036.png', 'screw/test/good/037.png', 'screw/test/good/002.png', 'screw/test/good/020.png', 'screw/test/good/022.png', 'screw/test/good/038.png', 'screw/test/good/003.png', 'screw/test/good/025.png', 'screw/test/good/000.png', 'screw/test/good/018.png', 'screw/test/good/007.png', 'screw/test/good/031.png', 'screw/test/good/005.png', 'screw/test/good/040.png', 'screw/test/good/035.png', 'screw/test/good/034.png', 'screw/test/good/013.png', 'screw/test/good/015.png', 'screw/test/good/024.png', 'screw/test/good/019.png', 'screw/test/good/027.png', 'screw/test/good/009.png', 'screw/test/good/016.png', 'screw/test/good/011.png', 'screw/test/good/029.png', 'screw/test/good/033.png', 'screw/test/good/014.png', 'screw/test/good/012.png', 'screw/test/good/023.png', 'screw/test/good/039.png', 'screw/test/good/006.png', 'screw/test/good/001.png', 'screw/test/good/028.png', 'screw/test/good/004.png', 'screw/test/good/026.png', 'screw/test/good/021.png', 'screw/test/good/030.png', 'screw/test/good/010.png', 'screw/test/good/032.png']
# 41

# %% [markdown]
# # 事前準備

# %%
# ライブラリのインポート
import os
import random
from glob import glob
from warnings import filterwarnings

import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
import torch.nn.init as init
from natsort import natsorted
from PIL import Image
from skimage import io, transform
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image

from torchsummary import summary

filterwarnings("ignore")  # warningをオフにする

# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
'''デバイスの設定'''

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
'''初期設定'''

COLAB_FLG = False  # COLABで実行する場合はTrue, それ以外で実行する場合はFalse

if COLAB_FLG:
    from google.colab import drive
    drive.mount('/content/gdrive') # マウント先
    ATTACH_PATH = "/content/gdrive/MyDrive/screw_anomaly"  # 保存先のベースディレクトリ
else:
    ATTACH_PATH = "."  # ローカルならカレントディレクトリ
    
    
SAVE_MODEL_PATH = f"{ATTACH_PATH}/results/model/"  # モデルの保存先
SAVE_IMAGE_FROM_Z_PATH = f"{ATTACH_PATH}/results/image/image_from_z/"  # 乱数から生成した画像の保存先
SAVE_IMAGE_RECONSTRUCT = f"{ATTACH_PATH}/results/image/RECONSTRUCT/"  # 再構成した画像の保存先

# 保存先のディレクトリを作成する
os.makedirs(SAVE_MODEL_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_FROM_Z_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_RECONSTRUCT, exist_ok=True)

# %%
'''ハイパーパラメータの設定'''

import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--image_size", type=int, default=96)
parser.add_argument("--num_epochs", type=int, default=2000)
parser.add_argument("--batch_size", type=int, default=16)
parser.add_argument("--lr", type=float, default=4e-4)
parser.add_argument("--z_dim", type=int, default=128) # ノイズの次元
parser.add_argument("--beta1", type=float, default=0.5) # Adamのハイパーパラメータ
parser.add_argument("--beta2", type=float, default=0.999) # Adamのハイパーパラメータ
opt = parser.parse_args(args=[])
print(opt)
# Out:
# Namespace(batch_size=16, beta1=0.5, beta2=0.999, image_size=96, lr=0.0004, num_epochs=2000, z_dim=128)

# %%
# デバイスの設定
device = "cuda" if torch.cuda.is_available() else "cpu"
kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {} # GPUが使える場合、DataLoaderでのミニバッチの取り出しを高速化

# %% [markdown]
# # DataLoader

# %%
train_root = './screw/train/good/'  # train dataの保存してあるディレクトリ
val_root = './screw/test/good/'  # val dataの保存してあるディレクトリ

# ディレクトリから画像を読み込んでDataLoaderに渡す用のクラス

class LoadFromFolder(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = natsorted(os.listdir(main_dir)) # ディレクトリ一覧を取得して自然ソート
        self.all_imgs_name = natsorted(all_imgs)
        self.imgs_loc = [os.path.join(self.main_dir, i) for i in self.all_imgs_name] # 画像のディレクトリ一覧

    def __len__(self):
        return len(self.all_imgs_name)
    
    def load_image(self, path):
        image = Image.open(path).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image
    
    def __getitem__(self, idx):
        
        # 後ほどsliceで画像を複数枚取得したいのでsliceでも取れるようにする
        if type(idx) == slice:
            paths = self.imgs_loc[idx]
            tensor_image = [self.load_image(path) for path in paths]
            tensor_image = torch.cat(tensor_image).reshape(len(tensor_image), *tensor_image[0].shape)
        elif type(idx) == int:
            path = self.imgs_loc[idx]
            tensor_image = self.load_image(path)
        return tensor_image

# 画像を読み込む際の前処理

transform_dict = {
    "train": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.RandomHorizontalFlip(), # ランダムに左右反転を行う
            transforms.ToTensor(),
        ]
    ),
    "test": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.ToTensor(),
        ]
    ),
}

# データを読み込む
train_dataset = LoadFromFolder(train_root, transform=transform_dict["train"])

test_dataset = LoadFromFolder(val_root, transform=transform_dict["test"])

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

val_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

# %% [markdown]
# # Encoder

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(256, 512, kernel_size=6, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(512, 512, kernel_size=1, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
        )

        self.last = nn.Sequential(nn.Conv2d(512, opt.z_dim, kernel_size=1, stride=1, bias=False))

    def forward(self, x):

        out = self.main(x)
        out = self.last(out)
        out = out.view(out.size()[0], -1, 1, 1)
        return out

# %%
# ネットワークを可視化する
summary(Encoder().to(device), (3, 96, 96))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 48, 48]           1,536
#        BatchNorm2d-2           [-1, 32, 48, 48]              64
#          LeakyReLU-3           [-1, 32, 48, 48]               0
#             Conv2d-4           [-1, 64, 24, 24]          32,768
#        BatchNorm2d-5           [-1, 64, 24, 24]             128
#          LeakyReLU-6           [-1, 64, 24, 24]               0
#             Conv2d-7          [-1, 128, 12, 12]         131,072
#        BatchNorm2d-8          [-1, 128, 12, 12]             256
#          LeakyReLU-9          [-1, 128, 12, 12]               0
#            Conv2d-10            [-1, 256, 6, 6]         524,288
#       BatchNorm2d-11            [-1, 256, 6, 6]             512
#         LeakyReLU-12            [-1, 256, 6, 6]               0
#            Conv2d-13            [-1, 512, 1, 1]       4,718,592
#       BatchNorm2d-14            [-1, 512, 1, 1]           1,024
#         LeakyReLU-15            [-1, 512, 1, 1]               0
#            Conv2d-16            [-1, 512, 1, 1]         262,144
#       BatchNorm2d-17            [-1, 512, 1, 1]           1,024
#         LeakyReLU-18            [-1, 512, 1, 1]               0
#            Conv2d-19            [-1, 128, 1, 1]          65,536
# ================================================================
# Total params: 5,738,944
# Trainable params: 5,738,944
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 3.19
# Params size (MB): 21.89
# Estimated Total Size (MB): 25.19
# ----------------------------------------------------------------

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.main = nn.Sequential(
            nn.ConvTranspose2d(opt.z_dim, 256, kernel_size=6, stride=1, padding=0, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False), #96x96
            nn.Tanh()
        )

    def forward(self, z):
        out = self.main(z)
        return out

# %%
# ネットワークを可視化する
summary(Generator().to(device), tuple([opt.z_dim, 1, 1]))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 256, 6, 6]       1,179,648
#        BatchNorm2d-2            [-1, 256, 6, 6]             512
#          LeakyReLU-3            [-1, 256, 6, 6]               0
#    ConvTranspose2d-4          [-1, 128, 12, 12]         524,288
#        BatchNorm2d-5          [-1, 128, 12, 12]             256
#          LeakyReLU-6          [-1, 128, 12, 12]               0
#    ConvTranspose2d-7           [-1, 64, 24, 24]         131,072
#        BatchNorm2d-8           [-1, 64, 24, 24]             128
#          LeakyReLU-9           [-1, 64, 24, 24]               0
#   ConvTranspose2d-10           [-1, 32, 48, 48]          32,768
#       BatchNorm2d-11           [-1, 32, 48, 48]              64
#         LeakyReLU-12           [-1, 32, 48, 48]               0
#   ConvTranspose2d-13            [-1, 3, 96, 96]           1,536
#              Tanh-14            [-1, 3, 96, 96]               0
# ================================================================
# Total params: 1,870,272
# Trainable params: 1,870,272
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.59
# Params size (MB): 7.13
# Estimated Total Size (MB): 10.72
# ----------------------------------------------------------------

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
            
        self.x_layer = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            # nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1, inplace=True), #48x48
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True), #24x24
            nn.Dropout2d(p=0.3),

            nn.AvgPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True), #12x12
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.1, inplace=True), #6x6
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(256, 256, kernel_size=6, stride=1) #1x1

        )
        self.z_layer = nn.Sequential(
            nn.Conv2d(opt.z_dim, 256, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.2),
        )
        
        self.last1 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=False),
            nn.Dropout2d(p=0.2),
        )
        self.last2 = nn.Sequential(
            nn.Conv2d(512, 1, kernel_size=1, stride=1),
        )

    def forward(self, x, z):
        
        output_x = self.x_layer(x)
        output_z = self.z_layer(z)
        
        concat_x_z = torch.cat((output_x, output_z), 1)
        output = self.last1(concat_x_z)

        feature = output.view(output.size()[0], -1)
        
        output = self.last2(output)
        output = F.sigmoid(output)
        return output.squeeze(), feature

# %%
# ネットワークを可視化する
summary(Discriminator().to(device), [(3, opt.image_size, opt.image_size), (opt.z_dim, 1, 1)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 96, 96]             896
#          LeakyReLU-2           [-1, 32, 96, 96]               0
#          Dropout2d-3           [-1, 32, 96, 96]               0
#          AvgPool2d-4           [-1, 32, 48, 48]               0
#             Conv2d-5           [-1, 64, 48, 48]          18,496
#        BatchNorm2d-6           [-1, 64, 48, 48]             128
#          LeakyReLU-7           [-1, 64, 48, 48]               0
#          Dropout2d-8           [-1, 64, 48, 48]               0
#          AvgPool2d-9           [-1, 64, 24, 24]               0
#            Conv2d-10          [-1, 128, 24, 24]          73,856
#       BatchNorm2d-11          [-1, 128, 24, 24]             256
#         LeakyReLU-12          [-1, 128, 24, 24]               0
#         Dropout2d-13          [-1, 128, 24, 24]               0
#         AvgPool2d-14          [-1, 128, 12, 12]               0
#            Conv2d-15          [-1, 256, 12, 12]         295,168
#       BatchNorm2d-16          [-1, 256, 12, 12]             512
#         LeakyReLU-17          [-1, 256, 12, 12]               0
#         Dropout2d-18          [-1, 256, 12, 12]               0
#         AvgPool2d-19            [-1, 256, 6, 6]               0
#            Conv2d-20            [-1, 256, 1, 1]       2,359,552
#            Conv2d-21            [-1, 256, 1, 1]          33,024
#         LeakyReLU-22            [-1, 256, 1, 1]               0
#         Dropout2d-23            [-1, 256, 1, 1]               0
#            Conv2d-24            [-1, 512, 1, 1]         262,656
#         LeakyReLU-25            [-1, 512, 1, 1]               0
#         Dropout2d-26            [-1, 512, 1, 1]               0
#            Conv2d-27              [-1, 1, 1, 1]             513
# ================================================================
# Total params: 3,045,057
# Trainable params: 3,045,057
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 13.50
# Forward/backward pass size (MB): 15.70
# Params size (MB): 11.62
# Estimated Total Size (MB): 40.82
# ----------------------------------------------------------------

# %%
# 重みの初期化を行う関数

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find("Linear") != -1:
        m.bias.data.fill_(0)

E = Encoder().to(device)
E.apply(weights_init)

G = Generator().to(device)
G.apply(weights_init)

D = Discriminator().to(device)
D.apply(weights_init)
# Out:
# Discriminator(
#   (x_layer): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (2): Dropout2d(p=0.3, inplace=False)
#     (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.1, inplace=True)
#     (7): Dropout2d(p=0.3, inplace=False)
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.1, inplace=True)
#     (12): Dropout2d(p=0.3, inplace=False)
#     (13): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.1, inplace=True)
#     (17): Dropout2d(p=0.3, inplace=False)
#     (18): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (19): Conv2d(256, 256, kernel_size=(6, 6), stride=(1, 1))
#   )
#   (z_layer): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (last1): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (last2): Sequential(
#     (0): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
criterion = nn.BCELoss()  # 評価関数
criterion_L1 = nn.L1Loss(reduction="sum") # 異常スコア計測用

# %%
# gとeは共通のoptimizer
optimizer_ge = torch.optim.Adam(list(G.parameters()) + list(E.parameters()), lr=opt.lr, betas=(opt.beta1,opt.beta2))
optimizer_d = torch.optim.Adam(D.parameters(), lr=opt.lr, betas=(opt.beta1,opt.beta2))

scheduler_ge = torch.optim.lr_scheduler.StepLR(optimizer_ge, step_size=50, gamma=0.9)
scheduler_d = torch.optim.lr_scheduler.StepLR(optimizer_d, step_size=50, gamma=0.9)

# %%
def Anomaly_score(x, E_x, G_E_x, Lambda=0.1):
    
    _,x_feature = D(x, E_x)
    _,G_E_x_feature = D(G_E_x, E_x)
    
    residual_loss = criterion_L1(x, G_E_x)
    discrimination_loss = criterion_L1(x_feature, G_E_x_feature)
    
    total_loss = (1-Lambda)*residual_loss + Lambda*discrimination_loss
    total_loss = total_loss.item()

    return total_loss

# %% [markdown]
# # 学習

# %%
Losses_D = []
Losses_GE = []
anomaly_scores = []

for epoch in range(opt.num_epochs):
    loss_d_sum = 0
    loss_ge_sum = 0
    anomaly_score_sum = 0
    
    for i,(x, x_val) in enumerate(zip(train_loader, val_loader)):
        
        G.train()
        D.train()
        E.train()

        # 値の設定
        y_true = Variable(torch.ones(x.size()[0])).to(device)
        y_fake = Variable(torch.zeros(x.size()[0])).to(device)
        
        x = Variable(x).to(device)
        z = Variable(init.normal(torch.Tensor(x.size()[0],opt.z_dim, 1, 1),mean=0,std=0.1)).to(device)
        
        # Discriminatorに対するノイズ
        noise1 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)
        noise2 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)

        # Discriminator
        optimizer_d.zero_grad()
        
        E_x = E(x) 
        p_true, _ = D(x + noise1, E_x)
        
        G_z = G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_d = criterion(p_true, y_true) + criterion(p_fake, y_fake)
        loss_d.backward(retain_graph=True)
        optimizer_d.step()
        
        # Generator, Encoder
        optimizer_ge.zero_grad()
        
        G_E_x = G(E_x)
        E_G_z = E(G_z)
    
        p_true, _ = D(x + noise1, E_x)
        
        # G_z = model_G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        
        loss_ge_1 = criterion(p_fake, y_true) + criterion(p_true, y_fake)
        loss_ge_2 = criterion_L1(x, G_E_x) +  criterion_L1(z, E_G_z)
        
        alpha = 0.01
        
        loss_ge = (1 - alpha)*loss_ge_1 + alpha*loss_ge_2
        loss_ge.backward(retain_graph=True)
        optimizer_ge.step()
        
        loss_d_sum += loss_d.item()
        loss_ge_sum += loss_ge.item()
        
        # anomaly scoreの記録
        
        G.eval()
        D.eval()
        E.eval()
        x_val = Variable(x_val).to(device)
        E_x_val = E(x_val)
        G_E_x_val = G(E_x_val)
        anomaly_score_sum += Anomaly_score(x_val, E_x_val, G_E_x_val)

        # 画像を保存
        if i == 0:
            
            G.eval()
            D.eval()
            E.eval()
        
            save_image_size_for_z = min(opt.batch_size, 8)
            save_images = G(z)
            save_image(save_images[:save_image_size_for_z], f"{SAVE_IMAGE_FROM_Z_PATH}/epoch_{epoch}.png", nrow=4)

            save_image_size_for_recon = min(opt.batch_size, 8)
            images = x[:save_image_size_for_recon]
            G_E_x = G(E(images))
            diff_images = torch.abs(images - G_E_x)
            comparison = torch.cat([images , G_E_x, diff_images]).to("cpu")
            save_image(comparison, f"{SAVE_IMAGE_RECONSTRUCT}/epoch_{epoch}.png", nrow=save_image_size_for_recon)
            
    scheduler_ge.step()
    scheduler_d.step()
        
    # lossを記録
    loss_d_mean = loss_d_sum / len(train_loader)
    loss_ge_mean = loss_ge_sum / len(train_loader)
    anomaly_score_mean = anomaly_score_sum / len(train_loader)
    
    print(f"{epoch}/{opt.num_epochs} epoch ge_loss: {loss_ge_mean:.3f} d_loss: {loss_d_mean:.3f} anomaly_score: {anomaly_score_mean:.3f}")
    
    Losses_D.append(loss_d_mean)
    Losses_GE.append(loss_ge_mean)
    anomaly_scores.append(anomaly_score_mean)
    
    # モデルを保存
    if (epoch + 1) % 10 == 0:
        torch.save(G.state_dict(),f'{SAVE_MODEL_PATH}/Generator_{epoch + 1}.pkl')
        torch.save(E.state_dict(),f'{SAVE_MODEL_PATH}/Encoder_{epoch + 1}.pkl')
        torch.save(D.state_dict(),f'{SAVE_MODEL_PATH}/Discriminator_{epoch + 1}.pkl')
# Out:
# 0/2000 epoch ge_loss: 464.169 d_loss: 0.206 anomaly_score: 34026.446
# 1/2000 epoch ge_loss: 431.987 d_loss: 0.200 anomaly_score: 33759.631
# 2/2000 epoch ge_loss: 387.258 d_loss: 0.195 anomaly_score: 32186.213
# 3/2000 epoch ge_loss: 347.284 d_loss: 0.172 anomaly_score: 28087.749
# 4/2000 epoch ge_loss: 303.361 d_loss: 0.131 anomaly_score: 23028.436
# 5/2000 epoch ge_loss: 259.195 d_loss: 0.078 anomaly_score: 18272.056
# 6/2000 epoch ge_loss: 231.123 d_loss: 0.067 anomaly_score: 14405.320
# 7/2000 epoch ge_loss: 197.004 d_loss: 0.046 anomaly_score: 10959.249
# 8/2000 epoch ge_loss: 167.122 d_loss: 0.059 anomaly_score: 8572.282
# 9/2000 epoch ge_loss: 141.048 d_loss: 0.026 anomaly_score: 6529.775
# 10/2000 epoch ge_loss: 118.115 d_loss: 0.032 anomaly_score: 5102.392
# 11/2000 epoch ge_loss: 103.009 d_loss: 0.022 anomaly_score: 4591.368
# 12/2000 epoch ge_loss: 89.516 d_loss: 0.028 anomaly_score: 4804.215
# 13/2000 epoch ge_loss: 73.708 d_loss: 0.060 anomaly_score: 4395.201
# 14/2000 epoch ge_loss: 58.989 d_loss: 0.027 anomaly_score: 4130.829
# 15/2000 epoch ge_loss: 54.667 d_loss: 0.023 anomaly_score: 4650.450
# 16/2000 epoch ge_loss: 50.564 d_loss: 0.016 anomaly_score: 4358.078
# 17/2000 epoch ge_loss: 46.022 d_loss: 0.035 anomaly_score: 4675.083
# 18/2000 epoch ge_loss: 42.023 d_loss: 0.021 anomaly_score: 5466.142
# 19/2000 epoch ge_loss: 38.423 d_loss: 0.013 anomaly_score: 5134.707
# 20/2000 epoch ge_loss: 36.196 d_loss: 0.019 anomaly_score: 4258.689
# 21/2000 epoch ge_loss: 34.746 d_loss: 0.012 anomaly_score: 8793.195
# 22/2000 epoch ge_loss: 35.056 d_loss: 0.015 anomaly_score: 8764.287
# 23/2000 epoch ge_loss: 32.661 d_loss: 0.016 anomaly_score: 5696.860
# 24/2000 epoch ge_loss: 32.345 d_loss: 0.026 anomaly_score: 4184.131
# 25/2000 epoch ge_loss: 30.428 d_loss: 0.027 anomaly_score: 4466.705
# 26/2000 epoch ge_loss: 29.975 d_loss: 0.053 anomaly_score: 3000.738
# 27/2000 epoch ge_loss: 29.134 d_loss: 0.017 anomaly_score: 5717.028
# 28/2000 epoch ge_loss: 29.092 d_loss: 0.009 anomaly_score: 6102.097
# 29/2000 epoch ge_loss: 28.841 d_loss: 0.026 anomaly_score: 3872.489
# 30/2000 epoch ge_loss: 27.058 d_loss: 0.016 anomaly_score: 3329.075
# 31/2000 epoch ge_loss: 28.903 d_loss: 0.009 anomaly_score: 5034.734
# 32/2000 epoch ge_loss: 25.734 d_loss: 0.007 anomaly_score: 4613.090
# 33/2000 epoch ge_loss: 25.705 d_loss: 0.006 anomaly_score: 2930.351
# 34/2000 epoch ge_loss: 25.442 d_loss: 0.008 anomaly_score: 6401.234
# 35/2000 epoch ge_loss: 25.805 d_loss: 0.010 anomaly_score: 6147.393
# 36/2000 epoch ge_loss: 25.700 d_loss: 0.018 anomaly_score: 3223.670
# 37/2000 epoch ge_loss: 24.673 d_loss: 0.026 anomaly_score: 5050.342
# 38/2000 epoch ge_loss: 23.679 d_loss: 0.018 anomaly_score: 5151.669
# 39/2000 epoch ge_loss: 23.360 d_loss: 0.010 anomaly_score: 2486.029
# 40/2000 epoch ge_loss: 23.479 d_loss: 0.013 anomaly_score: 2271.488
# 41/2000 epoch ge_loss: 23.349 d_loss: 0.007 anomaly_score: 7439.946
# 42/2000 epoch ge_loss: 23.894 d_loss: 0.019 anomaly_score: 7164.805
# 43/2000 epoch ge_loss: 22.739 d_loss: 0.014 anomaly_score: 4021.327
# 44/2000 epoch ge_loss: 23.019 d_loss: 0.019 anomaly_score: 4594.876
# 45/2000 epoch ge_loss: 22.679 d_loss: 0.011 anomaly_score: 6005.541
# 46/2000 epoch ge_loss: 22.575 d_loss: 0.012 anomaly_score: 7344.041
# 47/2000 epoch ge_loss: 20.802 d_loss: 0.010 anomaly_score: 3745.868
# 48/2000 epoch ge_loss: 21.600 d_loss: 0.012 anomaly_score: 10317.002
# 49/2000 epoch ge_loss: 21.184 d_loss: 0.039 anomaly_score: 6023.754
# 50/2000 epoch ge_loss: 21.088 d_loss: 0.022 anomaly_score: 3470.637
# 51/2000 epoch ge_loss: 20.072 d_loss: 0.011 anomaly_score: 2898.341
# 52/2000 epoch ge_loss: 21.923 d_loss: 0.014 anomaly_score: 3466.616
# 53/2000 epoch ge_loss: 20.758 d_loss: 0.005 anomaly_score: 3387.176
# 54/2000 epoch ge_loss: 20.751 d_loss: 0.011 anomaly_score: 3704.971
# 55/2000 epoch ge_loss: 19.734 d_loss: 0.010 anomaly_score: 2183.844
# 56/2000 epoch ge_loss: 20.387 d_loss: 0.011 anomaly_score: 2062.074
# 57/2000 epoch ge_loss: 19.199 d_loss: 0.025 anomaly_score: 5218.959
# 58/2000 epoch ge_loss: 20.447 d_loss: 0.015 anomaly_score: 7278.600
# 59/2000 epoch ge_loss: 19.168 d_loss: 0.010 anomaly_score: 4055.655
# 60/2000 epoch ge_loss: 19.079 d_loss: 0.008 anomaly_score: 2806.798
# 61/2000 epoch ge_loss: 19.095 d_loss: 0.014 anomaly_score: 3464.955
# 62/2000 epoch ge_loss: 18.924 d_loss: 0.006 anomaly_score: 3939.085
# 63/2000 epoch ge_loss: 18.650 d_loss: 0.010 anomaly_score: 1910.263
# 64/2000 epoch ge_loss: 19.223 d_loss: 0.006 anomaly_score: 1903.022
# 65/2000 epoch ge_loss: 18.463 d_loss: 0.014 anomaly_score: 3280.836
# 66/2000 epoch ge_loss: 20.124 d_loss: 0.010 anomaly_score: 3080.873
# 67/2000 epoch ge_loss: 18.525 d_loss: 0.005 anomaly_score: 2549.454
# 68/2000 epoch ge_loss: 19.762 d_loss: 0.005 anomaly_score: 2056.768
# 69/2000 epoch ge_loss: 18.971 d_loss: 0.008 anomaly_score: 2138.130
# 70/2000 epoch ge_loss: 18.628 d_loss: 0.006 anomaly_score: 2832.228
# 71/2000 epoch ge_loss: 19.715 d_loss: 0.007 anomaly_score: 2925.315
# 72/2000 epoch ge_loss: 19.710 d_loss: 0.004 anomaly_score: 2465.666
# 73/2000 epoch ge_loss: 18.979 d_loss: 0.007 anomaly_score: 1799.661
# 74/2000 epoch ge_loss: 18.334 d_loss: 0.009 anomaly_score: 6170.702
# 75/2000 epoch ge_loss: 18.595 d_loss: 0.007 anomaly_score: 6504.421
# 76/2000 epoch ge_loss: 18.671 d_loss: 0.019 anomaly_score: 4315.897
# 77/2000 epoch ge_loss: 20.067 d_loss: 0.011 anomaly_score: 3324.903
# 78/2000 epoch ge_loss: 18.725 d_loss: 0.005 anomaly_score: 1651.345
# 79/2000 epoch ge_loss: 17.959 d_loss: 0.015 anomaly_score: 2668.605
# 80/2000 epoch ge_loss: 18.156 d_loss: 0.005 anomaly_score: 4819.339
# 81/2000 epoch ge_loss: 18.374 d_loss: 0.004 anomaly_score: 3735.765
# 82/2000 epoch ge_loss: 18.760 d_loss: 0.007 anomaly_score: 1786.676
# 83/2000 epoch ge_loss: 17.731 d_loss: 0.004 anomaly_score: 2446.121
# 84/2000 epoch ge_loss: 19.447 d_loss: 0.017 anomaly_score: 3200.205
# 85/2000 epoch ge_loss: 18.036 d_loss: 0.010 anomaly_score: 2203.765
# 86/2000 epoch ge_loss: 17.967 d_loss: 0.008 anomaly_score: 1835.583
# 87/2000 epoch ge_loss: 17.594 d_loss: 0.006 anomaly_score: 1503.711
# 88/2000 epoch ge_loss: 18.724 d_loss: 0.002 anomaly_score: 2673.084
# 89/2000 epoch ge_loss: 18.797 d_loss: 0.006 anomaly_score: 4009.264
# 90/2000 epoch ge_loss: 19.192 d_loss: 0.007 anomaly_score: 4385.552
# 91/2000 epoch ge_loss: 18.490 d_loss: 0.008 anomaly_score: 4336.421
# 92/2000 epoch ge_loss: 18.387 d_loss: 0.012 anomaly_score: 4450.005
# 93/2000 epoch ge_loss: 20.463 d_loss: 0.004 anomaly_score: 3228.643
# 94/2000 epoch ge_loss: 18.937 d_loss: 0.005 anomaly_score: 2208.723
# 95/2000 epoch ge_loss: 17.823 d_loss: 0.028 anomaly_score: 2920.892
# 96/2000 epoch ge_loss: 18.735 d_loss: 0.013 anomaly_score: 6428.550
# 97/2000 epoch ge_loss: 17.484 d_loss: 0.010 anomaly_score: 2783.124
# 98/2000 epoch ge_loss: 18.688 d_loss: 0.001 anomaly_score: 3643.057
# 99/2000 epoch ge_loss: 19.090 d_loss: 0.002 anomaly_score: 2214.688
# 100/2000 epoch ge_loss: 20.176 d_loss: 0.020 anomaly_score: 3507.998
# 101/2000 epoch ge_loss: 16.954 d_loss: 0.010 anomaly_score: 2031.900
# 102/2000 epoch ge_loss: 17.786 d_loss: 0.011 anomaly_score: 2710.593
# 103/2000 epoch ge_loss: 17.602 d_loss: 0.006 anomaly_score: 2425.496
# 104/2000 epoch ge_loss: 18.152 d_loss: 0.005 anomaly_score: 1693.786
# 105/2000 epoch ge_loss: 17.185 d_loss: 0.003 anomaly_score: 2131.376
# 106/2000 epoch ge_loss: 17.215 d_loss: 0.002 anomaly_score: 2581.875
# 107/2000 epoch ge_loss: 16.409 d_loss: 0.002 anomaly_score: 3271.960
# 108/2000 epoch ge_loss: 19.131 d_loss: 0.003 anomaly_score: 2523.362
# 109/2000 epoch ge_loss: 17.385 d_loss: 0.001 anomaly_score: 3137.768
# 110/2000 epoch ge_loss: 17.807 d_loss: 0.001 anomaly_score: 2188.955
# 111/2000 epoch ge_loss: 17.866 d_loss: 0.015 anomaly_score: 2132.177
# 112/2000 epoch ge_loss: 17.128 d_loss: 0.003 anomaly_score: 2275.807
# 113/2000 epoch ge_loss: 17.378 d_loss: 0.002 anomaly_score: 2259.311
# 114/2000 epoch ge_loss: 19.070 d_loss: 0.003 anomaly_score: 11292.776
# 115/2000 epoch ge_loss: 19.096 d_loss: 0.002 anomaly_score: 8933.664
# 116/2000 epoch ge_loss: 17.597 d_loss: 0.002 anomaly_score: 4668.811
# 117/2000 epoch ge_loss: 18.489 d_loss: 0.002 anomaly_score: 3220.273
# 118/2000 epoch ge_loss: 18.157 d_loss: 0.005 anomaly_score: 2425.225
# 119/2000 epoch ge_loss: 17.615 d_loss: 0.004 anomaly_score: 1733.225
# 120/2000 epoch ge_loss: 17.840 d_loss: 0.001 anomaly_score: 2214.079
# 121/2000 epoch ge_loss: 17.467 d_loss: 0.001 anomaly_score: 1772.090
# 122/2000 epoch ge_loss: 17.767 d_loss: 0.001 anomaly_score: 1997.619
# 123/2000 epoch ge_loss: 16.731 d_loss: 0.001 anomaly_score: 1840.244
# 124/2000 epoch ge_loss: 16.860 d_loss: 0.003 anomaly_score: 3215.713
# 125/2000 epoch ge_loss: 16.800 d_loss: 0.002 anomaly_score: 3413.813
# 126/2000 epoch ge_loss: 17.165 d_loss: 0.007 anomaly_score: 1641.102
# 127/2000 epoch ge_loss: 16.824 d_loss: 0.006 anomaly_score: 1912.120
# 128/2000 epoch ge_loss: 16.962 d_loss: 0.016 anomaly_score: 1659.800
# 129/2000 epoch ge_loss: 17.047 d_loss: 0.014 anomaly_score: 2017.956
# 130/2000 epoch ge_loss: 17.908 d_loss: 0.009 anomaly_score: 2227.275
# 131/2000 epoch ge_loss: 18.762 d_loss: 0.008 anomaly_score: 1733.800
# 132/2000 epoch ge_loss: 17.326 d_loss: 0.006 anomaly_score: 2036.579
# 133/2000 epoch ge_loss: 17.861 d_loss: 0.003 anomaly_score: 3397.636
# 134/2000 epoch ge_loss: 18.496 d_loss: 0.012 anomaly_score: 10243.058
# 135/2000 epoch ge_loss: 17.308 d_loss: 0.010 anomaly_score: 7638.828
# 136/2000 epoch ge_loss: 17.668 d_loss: 0.005 anomaly_score: 4431.468
# 137/2000 epoch ge_loss: 17.880 d_loss: 0.002 anomaly_score: 2832.932
# 138/2000 epoch ge_loss: 17.080 d_loss: 0.002 anomaly_score: 2324.800
# 139/2000 epoch ge_loss: 20.227 d_loss: 0.015 anomaly_score: 2347.346
# 140/2000 epoch ge_loss: 18.499 d_loss: 0.004 anomaly_score: 1776.625
# 141/2000 epoch ge_loss: 19.786 d_loss: 0.003 anomaly_score: 1993.929
# 142/2000 epoch ge_loss: 17.428 d_loss: 0.003 anomaly_score: 1834.704
# 143/2000 epoch ge_loss: 17.221 d_loss: 0.002 anomaly_score: 1684.959
# 144/2000 epoch ge_loss: 16.715 d_loss: 0.002 anomaly_score: 1889.847
# 145/2000 epoch ge_loss: 18.255 d_loss: 0.004 anomaly_score: 2086.336
# 146/2000 epoch ge_loss: 17.510 d_loss: 0.004 anomaly_score: 1673.081
# 147/2000 epoch ge_loss: 16.762 d_loss: 0.002 anomaly_score: 1782.381
# 148/2000 epoch ge_loss: 17.073 d_loss: 0.005 anomaly_score: 1837.986
# 149/2000 epoch ge_loss: 15.915 d_loss: 0.003 anomaly_score: 1734.770
# 150/2000 epoch ge_loss: 16.833 d_loss: 0.003 anomaly_score: 1667.553
# 151/2000 epoch ge_loss: 17.135 d_loss: 0.008 anomaly_score: 1982.695
# 152/2000 epoch ge_loss: 16.269 d_loss: 0.003 anomaly_score: 1784.877
# 153/2000 epoch ge_loss: 16.308 d_loss: 0.009 anomaly_score: 1855.839
# 154/2000 epoch ge_loss: 15.724 d_loss: 0.009 anomaly_score: 1884.897
# 155/2000 epoch ge_loss: 16.959 d_loss: 0.009 anomaly_score: 1725.830
# 156/2000 epoch ge_loss: 15.396 d_loss: 0.005 anomaly_score: 1578.681
# 157/2000 epoch ge_loss: 15.535 d_loss: 0.006 anomaly_score: 1796.325
# 158/2000 epoch ge_loss: 15.492 d_loss: 0.009 anomaly_score: 1543.151
# 159/2000 epoch ge_loss: 19.363 d_loss: 0.006 anomaly_score: 2167.137
# 160/2000 epoch ge_loss: 17.222 d_loss: 0.003 anomaly_score: 2007.505
# 161/2000 epoch ge_loss: 16.523 d_loss: 0.003 anomaly_score: 1725.689
# 162/2000 epoch ge_loss: 15.975 d_loss: 0.006 anomaly_score: 1705.223
# 163/2000 epoch ge_loss: 16.672 d_loss: 0.003 anomaly_score: 1525.443
# 164/2000 epoch ge_loss: 16.583 d_loss: 0.004 anomaly_score: 1641.779
# 165/2000 epoch ge_loss: 15.955 d_loss: 0.004 anomaly_score: 1839.099
# 166/2000 epoch ge_loss: 16.217 d_loss: 0.006 anomaly_score: 1547.863
# 167/2000 epoch ge_loss: 15.434 d_loss: 0.013 anomaly_score: 1487.827
# 168/2000 epoch ge_loss: 16.253 d_loss: 0.008 anomaly_score: 1601.146
# 169/2000 epoch ge_loss: 16.269 d_loss: 0.014 anomaly_score: 1649.301
# 170/2000 epoch ge_loss: 15.840 d_loss: 0.020 anomaly_score: 4248.687
# 171/2000 epoch ge_loss: 16.124 d_loss: 0.008 anomaly_score: 2570.002
# 172/2000 epoch ge_loss: 17.171 d_loss: 0.008 anomaly_score: 2705.710
# 173/2000 epoch ge_loss: 17.634 d_loss: 0.004 anomaly_score: 7060.520
# 174/2000 epoch ge_loss: 16.281 d_loss: 0.004 anomaly_score: 3910.821
# 175/2000 epoch ge_loss: 16.231 d_loss: 0.018 anomaly_score: 2332.409
# 176/2000 epoch ge_loss: 18.867 d_loss: 0.029 anomaly_score: 1931.781
# 177/2000 epoch ge_loss: 16.208 d_loss: 0.008 anomaly_score: 1848.519
# 178/2000 epoch ge_loss: 17.099 d_loss: 0.005 anomaly_score: 1606.805
# 179/2000 epoch ge_loss: 16.154 d_loss: 0.003 anomaly_score: 1717.240
# 180/2000 epoch ge_loss: 15.638 d_loss: 0.004 anomaly_score: 1660.270
# 181/2000 epoch ge_loss: 16.222 d_loss: 0.003 anomaly_score: 1651.478
# 182/2000 epoch ge_loss: 16.080 d_loss: 0.001 anomaly_score: 1627.925
# 183/2000 epoch ge_loss: 16.997 d_loss: 0.016 anomaly_score: 1562.235
# 184/2000 epoch ge_loss: 16.169 d_loss: 0.006 anomaly_score: 1674.554
# 185/2000 epoch ge_loss: 16.580 d_loss: 0.002 anomaly_score: 1616.653
# 186/2000 epoch ge_loss: 16.289 d_loss: 0.002 anomaly_score: 1399.306
# 187/2000 epoch ge_loss: 16.148 d_loss: 0.005 anomaly_score: 1577.542
# 188/2000 epoch ge_loss: 16.199 d_loss: 0.007 anomaly_score: 1581.255
# 189/2000 epoch ge_loss: 16.353 d_loss: 0.005 anomaly_score: 1831.784
# 190/2000 epoch ge_loss: 17.204 d_loss: 0.003 anomaly_score: 1661.011
# 191/2000 epoch ge_loss: 16.083 d_loss: 0.002 anomaly_score: 1774.719
# 192/2000 epoch ge_loss: 16.736 d_loss: 0.007 anomaly_score: 1627.200
# 193/2000 epoch ge_loss: 16.905 d_loss: 0.022 anomaly_score: 1706.809
# 194/2000 epoch ge_loss: 16.931 d_loss: 0.006 anomaly_score: 1562.282
# 195/2000 epoch ge_loss: 16.981 d_loss: 0.009 anomaly_score: 1997.438
# 196/2000 epoch ge_loss: 16.266 d_loss: 0.005 anomaly_score: 1532.537
# 197/2000 epoch ge_loss: 16.750 d_loss: 0.003 anomaly_score: 1544.419
# 198/2000 epoch ge_loss: 16.565 d_loss: 0.006 anomaly_score: 1750.362
# 199/2000 epoch ge_loss: 17.936 d_loss: 0.012 anomaly_score: 1768.121
# 200/2000 epoch ge_loss: 16.370 d_loss: 0.009 anomaly_score: 1700.321
# 201/2000 epoch ge_loss: 15.440 d_loss: 0.007 anomaly_score: 1685.275
# 202/2000 epoch ge_loss: 15.994 d_loss: 0.003 anomaly_score: 1760.907
# 203/2000 epoch ge_loss: 16.610 d_loss: 0.002 anomaly_score: 1650.099
# 204/2000 epoch ge_loss: 16.096 d_loss: 0.006 anomaly_score: 1770.975
# 205/2000 epoch ge_loss: 16.515 d_loss: 0.002 anomaly_score: 1885.347
# 206/2000 epoch ge_loss: 19.553 d_loss: 0.002 anomaly_score: 2561.748
# 207/2000 epoch ge_loss: 15.868 d_loss: 0.008 anomaly_score: 1757.439
# 208/2000 epoch ge_loss: 15.475 d_loss: 0.002 anomaly_score: 1806.461
# 209/2000 epoch ge_loss: 16.373 d_loss: 0.016 anomaly_score: 1704.562
# 210/2000 epoch ge_loss: 17.138 d_loss: 0.029 anomaly_score: 2003.309
# 211/2000 epoch ge_loss: 14.888 d_loss: 0.005 anomaly_score: 1679.095
# 212/2000 epoch ge_loss: 16.007 d_loss: 0.004 anomaly_score: 1745.165
# 213/2000 epoch ge_loss: 14.408 d_loss: 0.006 anomaly_score: 1621.182
# 214/2000 epoch ge_loss: 16.163 d_loss: 0.004 anomaly_score: 1670.740
# 215/2000 epoch ge_loss: 16.965 d_loss: 0.004 anomaly_score: 1698.858
# 216/2000 epoch ge_loss: 15.214 d_loss: 0.002 anomaly_score: 1623.665
# 217/2000 epoch ge_loss: 15.501 d_loss: 0.002 anomaly_score: 1663.444
# 218/2000 epoch ge_loss: 15.091 d_loss: 0.008 anomaly_score: 1916.801
# 219/2000 epoch ge_loss: 15.713 d_loss: 0.033 anomaly_score: 1622.847
# 220/2000 epoch ge_loss: 14.991 d_loss: 0.008 anomaly_score: 1589.160
# 221/2000 epoch ge_loss: 15.430 d_loss: 0.020 anomaly_score: 1613.129
# 222/2000 epoch ge_loss: 14.778 d_loss: 0.007 anomaly_score: 1395.483
# 223/2000 epoch ge_loss: 14.955 d_loss: 0.003 anomaly_score: 1582.123
# 224/2000 epoch ge_loss: 17.007 d_loss: 0.003 anomaly_score: 1535.258
# 225/2000 epoch ge_loss: 15.229 d_loss: 0.004 anomaly_score: 1578.199
# 226/2000 epoch ge_loss: 15.041 d_loss: 0.006 anomaly_score: 1794.295
# 227/2000 epoch ge_loss: 15.112 d_loss: 0.003 anomaly_score: 1624.834
# 228/2000 epoch ge_loss: 15.217 d_loss: 0.003 anomaly_score: 1456.406
# 229/2000 epoch ge_loss: 16.502 d_loss: 0.003 anomaly_score: 1584.657
# 230/2000 epoch ge_loss: 15.074 d_loss: 0.002 anomaly_score: 1458.101
# 231/2000 epoch ge_loss: 14.814 d_loss: 0.003 anomaly_score: 1460.792
# 232/2000 epoch ge_loss: 15.485 d_loss: 0.004 anomaly_score: 1560.202
# 233/2000 epoch ge_loss: 14.643 d_loss: 0.003 anomaly_score: 1602.836
# 234/2000 epoch ge_loss: 15.103 d_loss: 0.014 anomaly_score: 1519.944
# 235/2000 epoch ge_loss: 15.515 d_loss: 0.018 anomaly_score: 1594.391
# 236/2000 epoch ge_loss: 15.187 d_loss: 0.008 anomaly_score: 1457.831
# 237/2000 epoch ge_loss: 15.617 d_loss: 0.008 anomaly_score: 1638.461
# 238/2000 epoch ge_loss: 15.146 d_loss: 0.008 anomaly_score: 1503.393
# 239/2000 epoch ge_loss: 16.309 d_loss: 0.005 anomaly_score: 1614.020
# 240/2000 epoch ge_loss: 15.859 d_loss: 0.005 anomaly_score: 1856.256
# 241/2000 epoch ge_loss: 16.940 d_loss: 0.017 anomaly_score: 1524.169
# 242/2000 epoch ge_loss: 15.035 d_loss: 0.033 anomaly_score: 1574.309
# 243/2000 epoch ge_loss: 14.975 d_loss: 0.009 anomaly_score: 1322.938
# 244/2000 epoch ge_loss: 15.080 d_loss: 0.005 anomaly_score: 1971.593
# 245/2000 epoch ge_loss: 16.378 d_loss: 0.015 anomaly_score: 2114.758
# 246/2000 epoch ge_loss: 15.706 d_loss: 0.038 anomaly_score: 1981.312
# 247/2000 epoch ge_loss: 16.824 d_loss: 0.014 anomaly_score: 1574.864
# 248/2000 epoch ge_loss: 15.582 d_loss: 0.012 anomaly_score: 1461.514
# 249/2000 epoch ge_loss: 16.547 d_loss: 0.013 anomaly_score: 1813.226
# 250/2000 epoch ge_loss: 16.104 d_loss: 0.007 anomaly_score: 1358.848
# 251/2000 epoch ge_loss: 16.638 d_loss: 0.005 anomaly_score: 1386.930
# 252/2000 epoch ge_loss: 15.765 d_loss: 0.009 anomaly_score: 1585.995
# 253/2000 epoch ge_loss: 15.646 d_loss: 0.027 anomaly_score: 1277.829
# 254/2000 epoch ge_loss: 16.445 d_loss: 0.015 anomaly_score: 1313.505
# 255/2000 epoch ge_loss: 15.963 d_loss: 0.010 anomaly_score: 1781.478
# 256/2000 epoch ge_loss: 15.730 d_loss: 0.009 anomaly_score: 1339.558
# 257/2000 epoch ge_loss: 14.728 d_loss: 0.011 anomaly_score: 1500.685
# 258/2000 epoch ge_loss: 13.996 d_loss: 0.007 anomaly_score: 1621.169
# 259/2000 epoch ge_loss: 15.233 d_loss: 0.005 anomaly_score: 1426.300
# 260/2000 epoch ge_loss: 14.738 d_loss: 0.003 anomaly_score: 1480.801
# 261/2000 epoch ge_loss: 15.695 d_loss: 0.006 anomaly_score: 1413.088
# 262/2000 epoch ge_loss: 15.180 d_loss: 0.005 anomaly_score: 1626.673
# 263/2000 epoch ge_loss: 16.225 d_loss: 0.008 anomaly_score: 1798.553
# 264/2000 epoch ge_loss: 15.567 d_loss: 0.009 anomaly_score: 1413.900
# 265/2000 epoch ge_loss: 15.197 d_loss: 0.009 anomaly_score: 1991.695
# 266/2000 epoch ge_loss: 14.842 d_loss: 0.005 anomaly_score: 1340.093
# 267/2000 epoch ge_loss: 15.648 d_loss: 0.006 anomaly_score: 1400.150
# 268/2000 epoch ge_loss: 15.461 d_loss: 0.005 anomaly_score: 1422.811
# 269/2000 epoch ge_loss: 14.387 d_loss: 0.011 anomaly_score: 1409.489
# 270/2000 epoch ge_loss: 14.418 d_loss: 0.007 anomaly_score: 1405.625
# 271/2000 epoch ge_loss: 14.935 d_loss: 0.008 anomaly_score: 1550.958
# 272/2000 epoch ge_loss: 15.905 d_loss: 0.010 anomaly_score: 1450.409
# 273/2000 epoch ge_loss: 14.251 d_loss: 0.017 anomaly_score: 2180.993
# 274/2000 epoch ge_loss: 15.631 d_loss: 0.007 anomaly_score: 2449.841
# 275/2000 epoch ge_loss: 15.276 d_loss: 0.005 anomaly_score: 2101.042
# 276/2000 epoch ge_loss: 15.923 d_loss: 0.005 anomaly_score: 1848.618
# 277/2000 epoch ge_loss: 14.611 d_loss: 0.006 anomaly_score: 1415.399
# 278/2000 epoch ge_loss: 14.709 d_loss: 0.005 anomaly_score: 1480.640
# 279/2000 epoch ge_loss: 14.857 d_loss: 0.005 anomaly_score: 1652.275
# 280/2000 epoch ge_loss: 14.289 d_loss: 0.012 anomaly_score: 1337.421
# 281/2000 epoch ge_loss: 14.416 d_loss: 0.011 anomaly_score: 1516.947
# 282/2000 epoch ge_loss: 14.244 d_loss: 0.011 anomaly_score: 1467.963
# 283/2000 epoch ge_loss: 14.979 d_loss: 0.010 anomaly_score: 1279.762
# 284/2000 epoch ge_loss: 13.717 d_loss: 0.005 anomaly_score: 1328.324
# 285/2000 epoch ge_loss: 14.750 d_loss: 0.007 anomaly_score: 1403.456
# 286/2000 epoch ge_loss: 14.771 d_loss: 0.008 anomaly_score: 1196.104
# 287/2000 epoch ge_loss: 15.766 d_loss: 0.007 anomaly_score: 1615.841
# 288/2000 epoch ge_loss: 15.812 d_loss: 0.004 anomaly_score: 1261.138
# 289/2000 epoch ge_loss: 17.701 d_loss: 0.009 anomaly_score: 1601.049
# 290/2000 epoch ge_loss: 16.039 d_loss: 0.009 anomaly_score: 1486.658
# 291/2000 epoch ge_loss: 15.331 d_loss: 0.016 anomaly_score: 1481.407
# 292/2000 epoch ge_loss: 15.515 d_loss: 0.008 anomaly_score: 1232.771
# 293/2000 epoch ge_loss: 16.092 d_loss: 0.009 anomaly_score: 1447.477
# 294/2000 epoch ge_loss: 14.225 d_loss: 0.011 anomaly_score: 1390.875
# 295/2000 epoch ge_loss: 14.823 d_loss: 0.013 anomaly_score: 1409.256
# 296/2000 epoch ge_loss: 13.922 d_loss: 0.004 anomaly_score: 1276.810
# 297/2000 epoch ge_loss: 16.483 d_loss: 0.007 anomaly_score: 1381.489
# 298/2000 epoch ge_loss: 14.925 d_loss: 0.005 anomaly_score: 1355.577
# 299/2000 epoch ge_loss: 14.118 d_loss: 0.011 anomaly_score: 1610.362
# 300/2000 epoch ge_loss: 14.366 d_loss: 0.012 anomaly_score: 2043.994
# 301/2000 epoch ge_loss: 14.379 d_loss: 0.006 anomaly_score: 1462.647
# 302/2000 epoch ge_loss: 14.586 d_loss: 0.011 anomaly_score: 1382.631
# 303/2000 epoch ge_loss: 14.380 d_loss: 0.014 anomaly_score: 1275.601
# 304/2000 epoch ge_loss: 14.502 d_loss: 0.009 anomaly_score: 1363.858
# 305/2000 epoch ge_loss: 14.503 d_loss: 0.013 anomaly_score: 1277.966
# 306/2000 epoch ge_loss: 14.778 d_loss: 0.024 anomaly_score: 1295.463
# 307/2000 epoch ge_loss: 15.653 d_loss: 0.008 anomaly_score: 1302.694
# 308/2000 epoch ge_loss: 15.327 d_loss: 0.013 anomaly_score: 1396.760
# 309/2000 epoch ge_loss: 13.840 d_loss: 0.008 anomaly_score: 1392.861
# 310/2000 epoch ge_loss: 14.250 d_loss: 0.004 anomaly_score: 1335.843
# 311/2000 epoch ge_loss: 13.994 d_loss: 0.008 anomaly_score: 1486.180
# 312/2000 epoch ge_loss: 13.863 d_loss: 0.007 anomaly_score: 1281.062
# 313/2000 epoch ge_loss: 13.785 d_loss: 0.008 anomaly_score: 1508.469
# 314/2000 epoch ge_loss: 13.494 d_loss: 0.003 anomaly_score: 1323.765
# 315/2000 epoch ge_loss: 14.352 d_loss: 0.012 anomaly_score: 1293.333
# 316/2000 epoch ge_loss: 15.954 d_loss: 0.014 anomaly_score: 1381.839
# 317/2000 epoch ge_loss: 14.209 d_loss: 0.005 anomaly_score: 1327.361
# 318/2000 epoch ge_loss: 13.344 d_loss: 0.007 anomaly_score: 1261.098
# 319/2000 epoch ge_loss: 15.007 d_loss: 0.007 anomaly_score: 1492.001
# 320/2000 epoch ge_loss: 13.805 d_loss: 0.006 anomaly_score: 1437.078
# 321/2000 epoch ge_loss: 14.058 d_loss: 0.004 anomaly_score: 1411.314
# 322/2000 epoch ge_loss: 13.351 d_loss: 0.004 anomaly_score: 1321.917
# 323/2000 epoch ge_loss: 14.760 d_loss: 0.005 anomaly_score: 1351.135
# 324/2000 epoch ge_loss: 15.991 d_loss: 0.005 anomaly_score: 1194.627
# 325/2000 epoch ge_loss: 15.395 d_loss: 0.005 anomaly_score: 1282.124
# 326/2000 epoch ge_loss: 14.711 d_loss: 0.015 anomaly_score: 1472.827
# 327/2000 epoch ge_loss: 14.095 d_loss: 0.014 anomaly_score: 1388.384
# 328/2000 epoch ge_loss: 14.333 d_loss: 0.011 anomaly_score: 1409.249
# 329/2000 epoch ge_loss: 13.979 d_loss: 0.013 anomaly_score: 1252.226
# 330/2000 epoch ge_loss: 15.369 d_loss: 0.010 anomaly_score: 1308.948
# 331/2000 epoch ge_loss: 14.581 d_loss: 0.014 anomaly_score: 1359.649
# 332/2000 epoch ge_loss: 15.131 d_loss: 0.012 anomaly_score: 1358.067
# 333/2000 epoch ge_loss: 14.448 d_loss: 0.010 anomaly_score: 1548.286
# 334/2000 epoch ge_loss: 15.315 d_loss: 0.010 anomaly_score: 1602.681
# 335/2000 epoch ge_loss: 14.301 d_loss: 0.011 anomaly_score: 1451.778
# 336/2000 epoch ge_loss: 14.164 d_loss: 0.008 anomaly_score: 1482.798
# 337/2000 epoch ge_loss: 14.136 d_loss: 0.008 anomaly_score: 1507.069
# 338/2000 epoch ge_loss: 15.079 d_loss: 0.006 anomaly_score: 1388.287
# 339/2000 epoch ge_loss: 15.794 d_loss: 0.009 anomaly_score: 1343.356
# 340/2000 epoch ge_loss: 14.353 d_loss: 0.005 anomaly_score: 1319.827
# 341/2000 epoch ge_loss: 14.911 d_loss: 0.007 anomaly_score: 1288.149
# 342/2000 epoch ge_loss: 13.791 d_loss: 0.005 anomaly_score: 1314.751
# 343/2000 epoch ge_loss: 13.952 d_loss: 0.006 anomaly_score: 1389.541
# 344/2000 epoch ge_loss: 14.185 d_loss: 0.004 anomaly_score: 1380.803
# 345/2000 epoch ge_loss: 14.285 d_loss: 0.005 anomaly_score: 1322.447
# 346/2000 epoch ge_loss: 14.996 d_loss: 0.004 anomaly_score: 1492.927
# 347/2000 epoch ge_loss: 14.394 d_loss: 0.004 anomaly_score: 1400.960
# 348/2000 epoch ge_loss: 14.571 d_loss: 0.008 anomaly_score: 1267.909
# 349/2000 epoch ge_loss: 14.643 d_loss: 0.006 anomaly_score: 1549.136
# 350/2000 epoch ge_loss: 13.439 d_loss: 0.002 anomaly_score: 1393.589
# 351/2000 epoch ge_loss: 14.167 d_loss: 0.010 anomaly_score: 1366.304
# 352/2000 epoch ge_loss: 15.051 d_loss: 0.011 anomaly_score: 1307.412
# 353/2000 epoch ge_loss: 14.217 d_loss: 0.021 anomaly_score: 1208.150
# 354/2000 epoch ge_loss: 14.492 d_loss: 0.014 anomaly_score: 1325.221
# 355/2000 epoch ge_loss: 13.451 d_loss: 0.010 anomaly_score: 1309.157
# 356/2000 epoch ge_loss: 14.161 d_loss: 0.010 anomaly_score: 1276.616
# 357/2000 epoch ge_loss: 14.038 d_loss: 0.016 anomaly_score: 1220.701
# 358/2000 epoch ge_loss: 13.346 d_loss: 0.037 anomaly_score: 1464.554
# 359/2000 epoch ge_loss: 12.883 d_loss: 0.016 anomaly_score: 1383.965
# 360/2000 epoch ge_loss: 13.702 d_loss: 0.013 anomaly_score: 1308.888
# 361/2000 epoch ge_loss: 14.731 d_loss: 0.015 anomaly_score: 1371.081
# 362/2000 epoch ge_loss: 13.698 d_loss: 0.013 anomaly_score: 1447.083
# 363/2000 epoch ge_loss: 13.867 d_loss: 0.006 anomaly_score: 1285.317
# 364/2000 epoch ge_loss: 13.449 d_loss: 0.008 anomaly_score: 1483.201
# 365/2000 epoch ge_loss: 14.208 d_loss: 0.010 anomaly_score: 1490.787
# 366/2000 epoch ge_loss: 12.992 d_loss: 0.016 anomaly_score: 1341.532
# 367/2000 epoch ge_loss: 13.797 d_loss: 0.009 anomaly_score: 1330.638
# 368/2000 epoch ge_loss: 14.290 d_loss: 0.014 anomaly_score: 1479.084
# 369/2000 epoch ge_loss: 15.843 d_loss: 0.013 anomaly_score: 1382.518
# 370/2000 epoch ge_loss: 13.415 d_loss: 0.006 anomaly_score: 1285.594
# 371/2000 epoch ge_loss: 12.602 d_loss: 0.009 anomaly_score: 1454.092
# 372/2000 epoch ge_loss: 13.432 d_loss: 0.007 anomaly_score: 1292.093
# 373/2000 epoch ge_loss: 14.384 d_loss: 0.010 anomaly_score: 1547.671
# 374/2000 epoch ge_loss: 13.999 d_loss: 0.022 anomaly_score: 1366.584
# 375/2000 epoch ge_loss: 13.426 d_loss: 0.014 anomaly_score: 1347.381
# 376/2000 epoch ge_loss: 14.513 d_loss: 0.008 anomaly_score: 1493.425
# 377/2000 epoch ge_loss: 13.846 d_loss: 0.010 anomaly_score: 1307.108
# 378/2000 epoch ge_loss: 13.978 d_loss: 0.007 anomaly_score: 1410.840
# 379/2000 epoch ge_loss: 13.740 d_loss: 0.008 anomaly_score: 1311.950
# 380/2000 epoch ge_loss: 13.614 d_loss: 0.007 anomaly_score: 1395.971
# 381/2000 epoch ge_loss: 14.517 d_loss: 0.006 anomaly_score: 1628.015
# 382/2000 epoch ge_loss: 14.034 d_loss: 0.002 anomaly_score: 1370.273
# 383/2000 epoch ge_loss: 14.617 d_loss: 0.007 anomaly_score: 1188.713
# 384/2000 epoch ge_loss: 14.974 d_loss: 0.005 anomaly_score: 1233.582
# 385/2000 epoch ge_loss: 14.473 d_loss: 0.012 anomaly_score: 1247.190
# 386/2000 epoch ge_loss: 14.738 d_loss: 0.008 anomaly_score: 1535.556
# 387/2000 epoch ge_loss: 14.112 d_loss: 0.014 anomaly_score: 1379.155
# 388/2000 epoch ge_loss: 14.476 d_loss: 0.009 anomaly_score: 1318.191
# 389/2000 epoch ge_loss: 14.345 d_loss: 0.010 anomaly_score: 1373.255
# 390/2000 epoch ge_loss: 13.328 d_loss: 0.003 anomaly_score: 1556.701
# 391/2000 epoch ge_loss: 13.257 d_loss: 0.011 anomaly_score: 1331.832
# 392/2000 epoch ge_loss: 14.892 d_loss: 0.015 anomaly_score: 1267.904
# 393/2000 epoch ge_loss: 13.205 d_loss: 0.008 anomaly_score: 1286.364
# 394/2000 epoch ge_loss: 12.696 d_loss: 0.008 anomaly_score: 1293.696
# 395/2000 epoch ge_loss: 13.326 d_loss: 0.006 anomaly_score: 1322.784
# 396/2000 epoch ge_loss: 14.246 d_loss: 0.007 anomaly_score: 1518.583
# 397/2000 epoch ge_loss: 15.742 d_loss: 0.007 anomaly_score: 1430.843
# 398/2000 epoch ge_loss: 15.025 d_loss: 0.006 anomaly_score: 1443.549
# 399/2000 epoch ge_loss: 15.131 d_loss: 0.005 anomaly_score: 1601.836
# 400/2000 epoch ge_loss: 13.765 d_loss: 0.006 anomaly_score: 1290.538
# 401/2000 epoch ge_loss: 13.668 d_loss: 0.004 anomaly_score: 1185.789
# 402/2000 epoch ge_loss: 15.954 d_loss: 0.007 anomaly_score: 1240.847
# 403/2000 epoch ge_loss: 14.657 d_loss: 0.009 anomaly_score: 1436.980
# 404/2000 epoch ge_loss: 14.512 d_loss: 0.004 anomaly_score: 1372.022
# 405/2000 epoch ge_loss: 13.109 d_loss: 0.005 anomaly_score: 1252.477
# 406/2000 epoch ge_loss: 15.894 d_loss: 0.006 anomaly_score: 1385.070
# 407/2000 epoch ge_loss: 13.951 d_loss: 0.002 anomaly_score: 1442.460
# 408/2000 epoch ge_loss: 13.612 d_loss: 0.006 anomaly_score: 1608.920
# 409/2000 epoch ge_loss: 13.607 d_loss: 0.008 anomaly_score: 1373.661
# 410/2000 epoch ge_loss: 14.079 d_loss: 0.006 anomaly_score: 1387.713
# 411/2000 epoch ge_loss: 13.531 d_loss: 0.003 anomaly_score: 1150.894
# 412/2000 epoch ge_loss: 14.362 d_loss: 0.005 anomaly_score: 1293.964
# 413/2000 epoch ge_loss: 13.587 d_loss: 0.008 anomaly_score: 1368.718
# 414/2000 epoch ge_loss: 14.353 d_loss: 0.002 anomaly_score: 1404.173
# 415/2000 epoch ge_loss: 13.368 d_loss: 0.006 anomaly_score: 1325.669
# 416/2000 epoch ge_loss: 13.840 d_loss: 0.007 anomaly_score: 1238.710
# 417/2000 epoch ge_loss: 15.238 d_loss: 0.006 anomaly_score: 1475.244
# 418/2000 epoch ge_loss: 15.326 d_loss: 0.011 anomaly_score: 1343.108
# 419/2000 epoch ge_loss: 13.193 d_loss: 0.013 anomaly_score: 1449.192
# 420/2000 epoch ge_loss: 15.523 d_loss: 0.012 anomaly_score: 1365.604
# 421/2000 epoch ge_loss: 14.148 d_loss: 0.009 anomaly_score: 1171.420
# 422/2000 epoch ge_loss: 13.676 d_loss: 0.022 anomaly_score: 1436.907
# 423/2000 epoch ge_loss: 14.264 d_loss: 0.012 anomaly_score: 1085.595
# 424/2000 epoch ge_loss: 13.468 d_loss: 0.026 anomaly_score: 1267.326
# 425/2000 epoch ge_loss: 13.340 d_loss: 0.010 anomaly_score: 1203.377
# 426/2000 epoch ge_loss: 12.996 d_loss: 0.007 anomaly_score: 1182.091
# 427/2000 epoch ge_loss: 13.286 d_loss: 0.005 anomaly_score: 1226.394
# 428/2000 epoch ge_loss: 13.872 d_loss: 0.006 anomaly_score: 1168.966
# 429/2000 epoch ge_loss: 13.933 d_loss: 0.017 anomaly_score: 1255.055
# 430/2000 epoch ge_loss: 17.204 d_loss: 0.009 anomaly_score: 1417.438
# 431/2000 epoch ge_loss: 15.076 d_loss: 0.010 anomaly_score: 1210.353
# 432/2000 epoch ge_loss: 14.195 d_loss: 0.008 anomaly_score: 1339.900
# 433/2000 epoch ge_loss: 15.651 d_loss: 0.009 anomaly_score: 1293.509
# 434/2000 epoch ge_loss: 13.799 d_loss: 0.010 anomaly_score: 1366.349
# 435/2000 epoch ge_loss: 15.654 d_loss: 0.016 anomaly_score: 1237.241
# 436/2000 epoch ge_loss: 12.893 d_loss: 0.004 anomaly_score: 1294.142
# 437/2000 epoch ge_loss: 14.670 d_loss: 0.007 anomaly_score: 1530.424
# 438/2000 epoch ge_loss: 13.408 d_loss: 0.003 anomaly_score: 1535.942
# 439/2000 epoch ge_loss: 13.526 d_loss: 0.005 anomaly_score: 1343.199
# 440/2000 epoch ge_loss: 14.183 d_loss: 0.005 anomaly_score: 1239.722
# 441/2000 epoch ge_loss: 13.919 d_loss: 0.011 anomaly_score: 1264.309
# 442/2000 epoch ge_loss: 13.614 d_loss: 0.005 anomaly_score: 1423.115
# 443/2000 epoch ge_loss: 14.612 d_loss: 0.003 anomaly_score: 1111.450
# 444/2000 epoch ge_loss: 13.859 d_loss: 0.004 anomaly_score: 1252.201
# 445/2000 epoch ge_loss: 14.118 d_loss: 0.004 anomaly_score: 1244.243
# 446/2000 epoch ge_loss: 13.449 d_loss: 0.002 anomaly_score: 1182.139
# 447/2000 epoch ge_loss: 13.798 d_loss: 0.002 anomaly_score: 1146.896
# 448/2000 epoch ge_loss: 15.252 d_loss: 0.009 anomaly_score: 1162.058
# 449/2000 epoch ge_loss: 15.259 d_loss: 0.010 anomaly_score: 1271.769
# 450/2000 epoch ge_loss: 13.693 d_loss: 0.007 anomaly_score: 1308.930
# 451/2000 epoch ge_loss: 14.009 d_loss: 0.007 anomaly_score: 1208.663
# 452/2000 epoch ge_loss: 13.349 d_loss: 0.003 anomaly_score: 1295.446
# 453/2000 epoch ge_loss: 15.051 d_loss: 0.007 anomaly_score: 1213.187
# 454/2000 epoch ge_loss: 13.993 d_loss: 0.003 anomaly_score: 1309.992
# 455/2000 epoch ge_loss: 13.741 d_loss: 0.005 anomaly_score: 1165.577
# 456/2000 epoch ge_loss: 14.219 d_loss: 0.006 anomaly_score: 1363.668
# 457/2000 epoch ge_loss: 13.988 d_loss: 0.002 anomaly_score: 1276.093
# 458/2000 epoch ge_loss: 14.064 d_loss: 0.010 anomaly_score: 1488.357
# 459/2000 epoch ge_loss: 13.613 d_loss: 0.012 anomaly_score: 1393.691
# 460/2000 epoch ge_loss: 13.627 d_loss: 0.043 anomaly_score: 1244.342
# 461/2000 epoch ge_loss: 12.895 d_loss: 0.034 anomaly_score: 1312.009
# 462/2000 epoch ge_loss: 13.410 d_loss: 0.012 anomaly_score: 1396.787
# 463/2000 epoch ge_loss: 13.425 d_loss: 0.009 anomaly_score: 1150.635
# 464/2000 epoch ge_loss: 13.285 d_loss: 0.005 anomaly_score: 1288.968
# 465/2000 epoch ge_loss: 13.947 d_loss: 0.005 anomaly_score: 1228.707
# 466/2000 epoch ge_loss: 13.340 d_loss: 0.005 anomaly_score: 1266.827
# 467/2000 epoch ge_loss: 13.951 d_loss: 0.003 anomaly_score: 1310.501
# 468/2000 epoch ge_loss: 14.644 d_loss: 0.004 anomaly_score: 1271.464
# 469/2000 epoch ge_loss: 14.674 d_loss: 0.003 anomaly_score: 1291.527
# 470/2000 epoch ge_loss: 13.818 d_loss: 0.010 anomaly_score: 1269.287
# 471/2000 epoch ge_loss: 12.604 d_loss: 0.007 anomaly_score: 1305.208
# 472/2000 epoch ge_loss: 13.487 d_loss: 0.002 anomaly_score: 1331.929
# 473/2000 epoch ge_loss: 13.351 d_loss: 0.003 anomaly_score: 1187.573
# 474/2000 epoch ge_loss: 13.158 d_loss: 0.010 anomaly_score: 1256.460
# 475/2000 epoch ge_loss: 12.769 d_loss: 0.036 anomaly_score: 1158.644
# 476/2000 epoch ge_loss: 13.751 d_loss: 0.009 anomaly_score: 1228.931
# 477/2000 epoch ge_loss: 13.818 d_loss: 0.004 anomaly_score: 1227.638
# 478/2000 epoch ge_loss: 14.622 d_loss: 0.020 anomaly_score: 1311.353
# 479/2000 epoch ge_loss: 14.292 d_loss: 0.007 anomaly_score: 1233.606
# 480/2000 epoch ge_loss: 13.073 d_loss: 0.027 anomaly_score: 1130.637
# 481/2000 epoch ge_loss: 13.449 d_loss: 0.005 anomaly_score: 1157.600
# 482/2000 epoch ge_loss: 16.374 d_loss: 0.014 anomaly_score: 1268.579
# 483/2000 epoch ge_loss: 13.586 d_loss: 0.008 anomaly_score: 1247.071
# 484/2000 epoch ge_loss: 13.026 d_loss: 0.003 anomaly_score: 1285.402
# 485/2000 epoch ge_loss: 13.092 d_loss: 0.004 anomaly_score: 1227.384
# 486/2000 epoch ge_loss: 13.406 d_loss: 0.008 anomaly_score: 1381.600
# 487/2000 epoch ge_loss: 14.289 d_loss: 0.005 anomaly_score: 1244.073
# 488/2000 epoch ge_loss: 13.765 d_loss: 0.022 anomaly_score: 1373.717
# 489/2000 epoch ge_loss: 14.694 d_loss: 0.012 anomaly_score: 1300.013
# 490/2000 epoch ge_loss: 13.316 d_loss: 0.018 anomaly_score: 1252.473
# 491/2000 epoch ge_loss: 13.927 d_loss: 0.012 anomaly_score: 1251.467
# 492/2000 epoch ge_loss: 12.923 d_loss: 0.011 anomaly_score: 1737.232
# 493/2000 epoch ge_loss: 13.283 d_loss: 0.004 anomaly_score: 1373.527
# 494/2000 epoch ge_loss: 14.270 d_loss: 0.010 anomaly_score: 1361.488
# 495/2000 epoch ge_loss: 12.283 d_loss: 0.003 anomaly_score: 1249.284
# 496/2000 epoch ge_loss: 14.826 d_loss: 0.003 anomaly_score: 1111.227
# 497/2000 epoch ge_loss: 17.017 d_loss: 0.003 anomaly_score: 1249.280
# 498/2000 epoch ge_loss: 13.799 d_loss: 0.005 anomaly_score: 1267.594
# 499/2000 epoch ge_loss: 15.242 d_loss: 0.010 anomaly_score: 1425.885
# 500/2000 epoch ge_loss: 13.882 d_loss: 0.005 anomaly_score: 1632.364
# 501/2000 epoch ge_loss: 14.090 d_loss: 0.003 anomaly_score: 1446.330
# 502/2000 epoch ge_loss: 13.427 d_loss: 0.002 anomaly_score: 1233.616
# 503/2000 epoch ge_loss: 13.491 d_loss: 0.003 anomaly_score: 1187.147
# 504/2000 epoch ge_loss: 13.001 d_loss: 0.002 anomaly_score: 1162.763
# 505/2000 epoch ge_loss: 13.106 d_loss: 0.008 anomaly_score: 1124.210
# 506/2000 epoch ge_loss: 13.212 d_loss: 0.006 anomaly_score: 1133.212
# 507/2000 epoch ge_loss: 15.807 d_loss: 0.004 anomaly_score: 1174.845
# 508/2000 epoch ge_loss: 12.954 d_loss: 0.023 anomaly_score: 1229.422
# 509/2000 epoch ge_loss: 12.549 d_loss: 0.009 anomaly_score: 1197.851
# 510/2000 epoch ge_loss: 13.577 d_loss: 0.004 anomaly_score: 1189.736
# 511/2000 epoch ge_loss: 13.511 d_loss: 0.006 anomaly_score: 1321.274
# 512/2000 epoch ge_loss: 14.789 d_loss: 0.007 anomaly_score: 1317.558
# 513/2000 epoch ge_loss: 13.184 d_loss: 0.008 anomaly_score: 1221.645
# 514/2000 epoch ge_loss: 13.155 d_loss: 0.009 anomaly_score: 1181.906
# 515/2000 epoch ge_loss: 14.022 d_loss: 0.010 anomaly_score: 1140.166
# 516/2000 epoch ge_loss: 12.945 d_loss: 0.005 anomaly_score: 1324.012
# 517/2000 epoch ge_loss: 13.389 d_loss: 0.003 anomaly_score: 1179.987
# 518/2000 epoch ge_loss: 13.145 d_loss: 0.005 anomaly_score: 1169.413
# 519/2000 epoch ge_loss: 13.319 d_loss: 0.009 anomaly_score: 1139.858
# 520/2000 epoch ge_loss: 13.300 d_loss: 0.005 anomaly_score: 1352.944
# 521/2000 epoch ge_loss: 13.136 d_loss: 0.006 anomaly_score: 1181.049
# 522/2000 epoch ge_loss: 14.281 d_loss: 0.008 anomaly_score: 1178.705
# 523/2000 epoch ge_loss: 13.571 d_loss: 0.011 anomaly_score: 1258.035
# 524/2000 epoch ge_loss: 13.692 d_loss: 0.012 anomaly_score: 1184.023
# 525/2000 epoch ge_loss: 13.678 d_loss: 0.011 anomaly_score: 1142.022
# 526/2000 epoch ge_loss: 12.852 d_loss: 0.013 anomaly_score: 1296.156
# 527/2000 epoch ge_loss: 12.885 d_loss: 0.007 anomaly_score: 1127.826
# 528/2000 epoch ge_loss: 14.252 d_loss: 0.011 anomaly_score: 1189.346
# 529/2000 epoch ge_loss: 14.244 d_loss: 0.005 anomaly_score: 1201.312
# 530/2000 epoch ge_loss: 14.047 d_loss: 0.011 anomaly_score: 1178.847
# 531/2000 epoch ge_loss: 13.494 d_loss: 0.008 anomaly_score: 1149.112
# 532/2000 epoch ge_loss: 14.090 d_loss: 0.004 anomaly_score: 1107.712
# 533/2000 epoch ge_loss: 14.426 d_loss: 0.019 anomaly_score: 1581.195
# 534/2000 epoch ge_loss: 17.155 d_loss: 0.019 anomaly_score: 1357.665
# 535/2000 epoch ge_loss: 13.292 d_loss: 0.007 anomaly_score: 1201.873
# 536/2000 epoch ge_loss: 12.293 d_loss: 0.007 anomaly_score: 1214.017
# 537/2000 epoch ge_loss: 12.327 d_loss: 0.011 anomaly_score: 1232.035
# 538/2000 epoch ge_loss: 14.265 d_loss: 0.005 anomaly_score: 1106.621
# 539/2000 epoch ge_loss: 13.529 d_loss: 0.014 anomaly_score: 1098.910
# 540/2000 epoch ge_loss: 12.805 d_loss: 0.024 anomaly_score: 1232.885
# 541/2000 epoch ge_loss: 14.696 d_loss: 0.015 anomaly_score: 1390.499
# 542/2000 epoch ge_loss: 15.091 d_loss: 0.014 anomaly_score: 1435.338
# 543/2000 epoch ge_loss: 13.726 d_loss: 0.014 anomaly_score: 1305.426
# 544/2000 epoch ge_loss: 12.836 d_loss: 0.003 anomaly_score: 1319.730
# 545/2000 epoch ge_loss: 14.134 d_loss: 0.005 anomaly_score: 1498.019
# 546/2000 epoch ge_loss: 13.233 d_loss: 0.006 anomaly_score: 1278.183
# 547/2000 epoch ge_loss: 12.357 d_loss: 0.005 anomaly_score: 1249.538
# 548/2000 epoch ge_loss: 15.395 d_loss: 0.009 anomaly_score: 1258.526
# 549/2000 epoch ge_loss: 15.035 d_loss: 0.006 anomaly_score: 1202.758
# 550/2000 epoch ge_loss: 13.532 d_loss: 0.004 anomaly_score: 1188.133
# 551/2000 epoch ge_loss: 14.050 d_loss: 0.010 anomaly_score: 1135.932
# 552/2000 epoch ge_loss: 14.007 d_loss: 0.004 anomaly_score: 1179.016
# 553/2000 epoch ge_loss: 12.912 d_loss: 0.009 anomaly_score: 1161.099
# 554/2000 epoch ge_loss: 16.547 d_loss: 0.004 anomaly_score: 1090.207
# Traceback (most recent call last):
# 555/2000 epoch ge_loss: 13.020 d_loss: 0.005 anomaly_score: 1210.164
# 556/2000 epoch ge_loss: 13.697 d_loss: 0.008 anomaly_score: 1110.640
# 557/2000 epoch ge_loss: 13.507 d_loss: 0.010 anomaly_score: 1208.303
# 558/2000 epoch ge_loss: 13.680 d_loss: 0.007 anomaly_score: 1342.196
# 559/2000 epoch ge_loss: 13.732 d_loss: 0.005 anomaly_score: 1232.880
# 560/2000 epoch ge_loss: 14.638 d_loss: 0.020 anomaly_score: 1266.899
# 561/2000 epoch ge_loss: 12.200 d_loss: 0.030 anomaly_score: 1178.140
# 562/2000 epoch ge_loss: 12.339 d_loss: 0.018 anomaly_score: 1176.957
# 563/2000 epoch ge_loss: 14.308 d_loss: 0.045 anomaly_score: 1190.407
# 564/2000 epoch ge_loss: 11.117 d_loss: 0.020 anomaly_score: 1220.116
# 565/2000 epoch ge_loss: 13.779 d_loss: 0.008 anomaly_score: 1262.219
# 566/2000 epoch ge_loss: 13.197 d_loss: 0.006 anomaly_score: 1122.854
# 567/2000 epoch ge_loss: 12.517 d_loss: 0.008 anomaly_score: 1079.663
# 568/2000 epoch ge_loss: 13.845 d_loss: 0.006 anomaly_score: 1134.145
# 569/2000 epoch ge_loss: 11.995 d_loss: 0.016 anomaly_score: 1206.173
# 570/2000 epoch ge_loss: 12.199 d_loss: 0.007 anomaly_score: 1270.522
# 571/2000 epoch ge_loss: 14.994 d_loss: 0.004 anomaly_score: 1179.904
# 572/2000 epoch ge_loss: 13.055 d_loss: 0.006 anomaly_score: 1296.866
# 573/2000 epoch ge_loss: 12.868 d_loss: 0.004 anomaly_score: 1172.575
# 574/2000 epoch ge_loss: 12.434 d_loss: 0.014 anomaly_score: 1133.225
# 575/2000 epoch ge_loss: 12.767 d_loss: 0.009 anomaly_score: 1278.615
# 576/2000 epoch ge_loss: 12.962 d_loss: 0.005 anomaly_score: 1198.622
# 577/2000 epoch ge_loss: 13.160 d_loss: 0.007 anomaly_score: 1333.395
# 578/2000 epoch ge_loss: 12.703 d_loss: 0.016 anomaly_score: 1350.146
# 579/2000 epoch ge_loss: 13.530 d_loss: 0.020 anomaly_score: 1347.662
# 580/2000 epoch ge_loss: 12.772 d_loss: 0.032 anomaly_score: 1157.785
# 581/2000 epoch ge_loss: 12.540 d_loss: 0.011 anomaly_score: 1164.912
# 582/2000 epoch ge_loss: 13.900 d_loss: 0.007 anomaly_score: 1095.210
# 583/2000 epoch ge_loss: 13.030 d_loss: 0.005 anomaly_score: 1210.103
# 584/2000 epoch ge_loss: 13.663 d_loss: 0.006 anomaly_score: 1189.302
# 585/2000 epoch ge_loss: 12.783 d_loss: 0.008 anomaly_score: 1325.839
# 586/2000 epoch ge_loss: 13.530 d_loss: 0.008 anomaly_score: 1309.083
# 587/2000 epoch ge_loss: 13.346 d_loss: 0.008 anomaly_score: 1267.951
# 588/2000 epoch ge_loss: 13.972 d_loss: 0.004 anomaly_score: 1251.620
# 589/2000 epoch ge_loss: 14.083 d_loss: 0.018 anomaly_score: 1081.443
# 590/2000 epoch ge_loss: 13.154 d_loss: 0.012 anomaly_score: 1191.877
# 591/2000 epoch ge_loss: 15.080 d_loss: 0.015 anomaly_score: 1301.333
# 592/2000 epoch ge_loss: 13.997 d_loss: 0.011 anomaly_score: 1248.146
# 593/2000 epoch ge_loss: 12.828 d_loss: 0.007 anomaly_score: 1143.393
# 594/2000 epoch ge_loss: 13.190 d_loss: 0.007 anomaly_score: 1213.055
# 595/2000 epoch ge_loss: 14.557 d_loss: 0.010 anomaly_score: 1131.262
# 596/2000 epoch ge_loss: 14.760 d_loss: 0.022 anomaly_score: 1209.254
# 597/2000 epoch ge_loss: 13.840 d_loss: 0.008 anomaly_score: 1146.415
# 598/2000 epoch ge_loss: 13.441 d_loss: 0.004 anomaly_score: 1104.306
# 599/2000 epoch ge_loss: 11.957 d_loss: 0.019 anomaly_score: 1173.852
# 600/2000 epoch ge_loss: 12.835 d_loss: 0.012 anomaly_score: 1080.474
# 601/2000 epoch ge_loss: 12.890 d_loss: 0.019 anomaly_score: 1179.785
# 602/2000 epoch ge_loss: 12.095 d_loss: 0.009 anomaly_score: 1239.659
# 603/2000 epoch ge_loss: 13.814 d_loss: 0.003 anomaly_score: 1347.648
# 604/2000 epoch ge_loss: 14.354 d_loss: 0.011 anomaly_score: 1430.276
# 605/2000 epoch ge_loss: 13.316 d_loss: 0.004 anomaly_score: 1289.912
# 606/2000 epoch ge_loss: 13.900 d_loss: 0.009 anomaly_score: 1214.433
# 607/2000 epoch ge_loss: 12.727 d_loss: 0.006 anomaly_score: 1141.164
# 608/2000 epoch ge_loss: 13.501 d_loss: 0.004 anomaly_score: 1369.308
# 609/2000 epoch ge_loss: 12.950 d_loss: 0.004 anomaly_score: 1174.246
# 610/2000 epoch ge_loss: 14.084 d_loss: 0.014 anomaly_score: 1080.935
# 611/2000 epoch ge_loss: 12.871 d_loss: 0.009 anomaly_score: 1223.885
# 612/2000 epoch ge_loss: 14.598 d_loss: 0.004 anomaly_score: 1241.598
# 613/2000 epoch ge_loss: 12.728 d_loss: 0.004 anomaly_score: 1182.538
# 614/2000 epoch ge_loss: 12.330 d_loss: 0.013 anomaly_score: 1139.201
# 615/2000 epoch ge_loss: 13.319 d_loss: 0.010 anomaly_score: 1335.837
# 616/2000 epoch ge_loss: 12.303 d_loss: 0.017 anomaly_score: 1169.762
# 617/2000 epoch ge_loss: 12.175 d_loss: 0.013 anomaly_score: 1178.441
# 618/2000 epoch ge_loss: 15.029 d_loss: 0.015 anomaly_score: 1077.008
# 619/2000 epoch ge_loss: 14.294 d_loss: 0.006 anomaly_score: 1134.577
# 620/2000 epoch ge_loss: 11.959 d_loss: 0.007 anomaly_score: 1130.540
# 621/2000 epoch ge_loss: 12.945 d_loss: 0.012 anomaly_score: 1100.321
# 622/2000 epoch ge_loss: 12.466 d_loss: 0.007 anomaly_score: 1172.337
# 623/2000 epoch ge_loss: 12.438 d_loss: 0.013 anomaly_score: 1166.023
# 624/2000 epoch ge_loss: 12.201 d_loss: 0.007 anomaly_score: 1237.561
# 625/2000 epoch ge_loss: 12.974 d_loss: 0.023 anomaly_score: 1167.089
# 626/2000 epoch ge_loss: 12.194 d_loss: 0.013 anomaly_score: 1090.074
# 627/2000 epoch ge_loss: 14.131 d_loss: 0.018 anomaly_score: 1157.407
# 628/2000 epoch ge_loss: 13.310 d_loss: 0.022 anomaly_score: 1145.641
# 629/2000 epoch ge_loss: 12.171 d_loss: 0.015 anomaly_score: 1103.007
# 630/2000 epoch ge_loss: 12.482 d_loss: 0.011 anomaly_score: 1123.701
# 631/2000 epoch ge_loss: 12.638 d_loss: 0.014 anomaly_score: 1275.482
# 632/2000 epoch ge_loss: 13.616 d_loss: 0.007 anomaly_score: 1278.952
# 633/2000 epoch ge_loss: 12.454 d_loss: 0.007 anomaly_score: 1263.053
# 634/2000 epoch ge_loss: 13.103 d_loss: 0.010 anomaly_score: 1292.814
# 635/2000 epoch ge_loss: 13.689 d_loss: 0.019 anomaly_score: 1172.248
# 636/2000 epoch ge_loss: 12.491 d_loss: 0.009 anomaly_score: 1154.010
# 637/2000 epoch ge_loss: 12.523 d_loss: 0.005 anomaly_score: 1298.434
# 638/2000 epoch ge_loss: 13.741 d_loss: 0.010 anomaly_score: 1223.432
# 639/2000 epoch ge_loss: 13.370 d_loss: 0.034 anomaly_score: 1184.427
# 640/2000 epoch ge_loss: 12.348 d_loss: 0.011 anomaly_score: 1184.427
# 641/2000 epoch ge_loss: 12.806 d_loss: 0.015 anomaly_score: 1235.000
# 642/2000 epoch ge_loss: 12.223 d_loss: 0.006 anomaly_score: 1230.452
# 643/2000 epoch ge_loss: 13.148 d_loss: 0.017 anomaly_score: 1201.491
# 644/2000 epoch ge_loss: 12.493 d_loss: 0.017 anomaly_score: 1127.947
# 645/2000 epoch ge_loss: 12.584 d_loss: 0.017 anomaly_score: 1222.230
# 646/2000 epoch ge_loss: 12.402 d_loss: 0.018 anomaly_score: 1225.642
# 647/2000 epoch ge_loss: 13.295 d_loss: 0.018 anomaly_score: 1108.143
# 648/2000 epoch ge_loss: 12.983 d_loss: 0.015 anomaly_score: 1089.839
# 649/2000 epoch ge_loss: 13.816 d_loss: 0.011 anomaly_score: 1162.794
# 650/2000 epoch ge_loss: 15.263 d_loss: 0.010 anomaly_score: 1263.569
# 651/2000 epoch ge_loss: 12.765 d_loss: 0.017 anomaly_score: 1128.239
# 652/2000 epoch ge_loss: 12.535 d_loss: 0.010 anomaly_score: 1185.199
# 653/2000 epoch ge_loss: 12.079 d_loss: 0.013 anomaly_score: 1285.145
# 654/2000 epoch ge_loss: 12.877 d_loss: 0.021 anomaly_score: 1444.752
# 655/2000 epoch ge_loss: 14.897 d_loss: 0.023 anomaly_score: 1340.437
# 656/2000 epoch ge_loss: 12.483 d_loss: 0.010 anomaly_score: 1201.363
# 657/2000 epoch ge_loss: 14.616 d_loss: 0.010 anomaly_score: 1104.729
# 658/2000 epoch ge_loss: 13.357 d_loss: 0.012 anomaly_score: 1160.551
# 659/2000 epoch ge_loss: 12.892 d_loss: 0.010 anomaly_score: 1121.797
# 660/2000 epoch ge_loss: 14.195 d_loss: 0.010 anomaly_score: 1147.505
# 661/2000 epoch ge_loss: 12.318 d_loss: 0.019 anomaly_score: 1172.627
# 662/2000 epoch ge_loss: 12.695 d_loss: 0.012 anomaly_score: 1238.396
# 663/2000 epoch ge_loss: 12.700 d_loss: 0.007 anomaly_score: 1134.764
# 664/2000 epoch ge_loss: 12.481 d_loss: 0.015 anomaly_score: 1241.905
# 665/2000 epoch ge_loss: 15.102 d_loss: 0.014 anomaly_score: 1252.088
# 666/2000 epoch ge_loss: 12.862 d_loss: 0.031 anomaly_score: 1257.897
# 667/2000 epoch ge_loss: 13.262 d_loss: 0.012 anomaly_score: 1323.174
# 668/2000 epoch ge_loss: 12.115 d_loss: 0.006 anomaly_score: 1179.177
# 669/2000 epoch ge_loss: 13.669 d_loss: 0.041 anomaly_score: 1125.785
# 670/2000 epoch ge_loss: 12.542 d_loss: 0.007 anomaly_score: 1208.858
# 671/2000 epoch ge_loss: 12.718 d_loss: 0.012 anomaly_score: 1014.025
# 672/2000 epoch ge_loss: 13.764 d_loss: 0.009 anomaly_score: 1096.366
# 673/2000 epoch ge_loss: 11.879 d_loss: 0.010 anomaly_score: 1132.713
# 674/2000 epoch ge_loss: 12.301 d_loss: 0.005 anomaly_score: 1134.241
# 675/2000 epoch ge_loss: 14.028 d_loss: 0.017 anomaly_score: 1199.293
# 676/2000 epoch ge_loss: 12.138 d_loss: 0.012 anomaly_score: 1187.481
# 677/2000 epoch ge_loss: 12.512 d_loss: 0.032 anomaly_score: 1342.718
# 678/2000 epoch ge_loss: 12.091 d_loss: 0.007 anomaly_score: 1144.969
# 679/2000 epoch ge_loss: 14.101 d_loss: 0.016 anomaly_score: 1141.053
# 680/2000 epoch ge_loss: 12.365 d_loss: 0.012 anomaly_score: 1329.906
# 681/2000 epoch ge_loss: 12.282 d_loss: 0.004 anomaly_score: 1425.573
# 682/2000 epoch ge_loss: 13.592 d_loss: 0.011 anomaly_score: 1227.562
# 683/2000 epoch ge_loss: 15.018 d_loss: 0.016 anomaly_score: 1187.260
# 684/2000 epoch ge_loss: 12.293 d_loss: 0.008 anomaly_score: 1167.149
# 685/2000 epoch ge_loss: 13.789 d_loss: 0.023 anomaly_score: 1157.633
# 686/2000 epoch ge_loss: 13.511 d_loss: 0.022 anomaly_score: 1063.901
# 687/2000 epoch ge_loss: 12.017 d_loss: 0.042 anomaly_score: 1142.875
# 688/2000 epoch ge_loss: 13.455 d_loss: 0.030 anomaly_score: 1140.504
# 689/2000 epoch ge_loss: 13.310 d_loss: 0.029 anomaly_score: 1182.490
# 690/2000 epoch ge_loss: 12.695 d_loss: 0.014 anomaly_score: 1149.023
# 691/2000 epoch ge_loss: 12.219 d_loss: 0.011 anomaly_score: 1027.617
# 692/2000 epoch ge_loss: 15.229 d_loss: 0.006 anomaly_score: 1095.763
# 693/2000 epoch ge_loss: 13.251 d_loss: 0.015 anomaly_score: 1102.825
# 694/2000 epoch ge_loss: 11.524 d_loss: 0.006 anomaly_score: 1111.097
# 695/2000 epoch ge_loss: 12.412 d_loss: 0.013 anomaly_score: 1253.810
# ...
# 1770/2000 epoch ge_loss: 11.256 d_loss: 0.047 anomaly_score: 970.984
# 1771/2000 epoch ge_loss: 11.306 d_loss: 0.024 anomaly_score: 949.669
# 1772/2000 epoch ge_loss: 10.429 d_loss: 0.049 anomaly_score: 942.401
# 1773/2000 epoch ge_loss: 10.884 d_loss: 0.027 anomaly_score: 991.796
# 1774/2000 epoch ge_loss: 10.797 d_loss: 0.032 anomaly_score: 992.852
# 1775/2000 epoch ge_loss: 11.133 d_loss: 0.010 anomaly_score: 981.830
# 1776/2000 epoch ge_loss: 11.661 d_loss: 0.013 anomaly_score: 975.644
# 1777/2000 epoch ge_loss: 11.007 d_loss: 0.018 anomaly_score: 954.116
# 1778/2000 epoch ge_loss: 11.498 d_loss: 0.031 anomaly_score: 958.399
# 1779/2000 epoch ge_loss: 11.003 d_loss: 0.026 anomaly_score: 991.905
# 1780/2000 epoch ge_loss: 11.944 d_loss: 0.028 anomaly_score: 1009.020
# 1781/2000 epoch ge_loss: 12.264 d_loss: 0.032 anomaly_score: 1008.381
# 1782/2000 epoch ge_loss: 10.884 d_loss: 0.023 anomaly_score: 998.512
# 1783/2000 epoch ge_loss: 12.073 d_loss: 0.029 anomaly_score: 996.798
# 1784/2000 epoch ge_loss: 10.125 d_loss: 0.015 anomaly_score: 990.447
# 1785/2000 epoch ge_loss: 11.426 d_loss: 0.020 anomaly_score: 1013.298
# 1786/2000 epoch ge_loss: 11.774 d_loss: 0.040 anomaly_score: 1010.704
# 1787/2000 epoch ge_loss: 10.706 d_loss: 0.024 anomaly_score: 1034.405
# 1788/2000 epoch ge_loss: 10.951 d_loss: 0.008 anomaly_score: 985.349
# 1789/2000 epoch ge_loss: 12.178 d_loss: 0.017 anomaly_score: 942.783
# 1790/2000 epoch ge_loss: 10.788 d_loss: 0.020 anomaly_score: 953.128
# 1791/2000 epoch ge_loss: 10.876 d_loss: 0.024 anomaly_score: 957.166
# 1792/2000 epoch ge_loss: 10.699 d_loss: 0.029 anomaly_score: 950.174
# 1793/2000 epoch ge_loss: 11.288 d_loss: 0.056 anomaly_score: 912.752
# 1794/2000 epoch ge_loss: 10.763 d_loss: 0.031 anomaly_score: 910.918
# 1795/2000 epoch ge_loss: 10.161 d_loss: 0.024 anomaly_score: 910.121
# 1796/2000 epoch ge_loss: 12.256 d_loss: 0.008 anomaly_score: 961.348
# 1797/2000 epoch ge_loss: 10.717 d_loss: 0.014 anomaly_score: 999.421
# 1798/2000 epoch ge_loss: 11.489 d_loss: 0.022 anomaly_score: 970.024
# 1799/2000 epoch ge_loss: 10.856 d_loss: 0.011 anomaly_score: 933.988
# 1800/2000 epoch ge_loss: 11.535 d_loss: 0.009 anomaly_score: 942.387
# 1801/2000 epoch ge_loss: 11.456 d_loss: 0.014 anomaly_score: 958.119
# 1802/2000 epoch ge_loss: 10.574 d_loss: 0.014 anomaly_score: 936.627
# 1803/2000 epoch ge_loss: 11.323 d_loss: 0.026 anomaly_score: 973.051
# 1804/2000 epoch ge_loss: 11.632 d_loss: 0.028 anomaly_score: 1005.188
# 1805/2000 epoch ge_loss: 10.616 d_loss: 0.016 anomaly_score: 1000.886
# 1806/2000 epoch ge_loss: 10.937 d_loss: 0.022 anomaly_score: 1010.034
# 1807/2000 epoch ge_loss: 11.479 d_loss: 0.036 anomaly_score: 1005.602
# 1808/2000 epoch ge_loss: 10.804 d_loss: 0.035 anomaly_score: 997.200
# 1809/2000 epoch ge_loss: 10.951 d_loss: 0.016 anomaly_score: 1000.380
# 1810/2000 epoch ge_loss: 11.770 d_loss: 0.005 anomaly_score: 959.499
# 1811/2000 epoch ge_loss: 11.115 d_loss: 0.018 anomaly_score: 922.966
# 1812/2000 epoch ge_loss: 10.898 d_loss: 0.010 anomaly_score: 931.472
# 1813/2000 epoch ge_loss: 11.613 d_loss: 0.006 anomaly_score: 983.426
# 1814/2000 epoch ge_loss: 11.068 d_loss: 0.007 anomaly_score: 979.938
# 1815/2000 epoch ge_loss: 10.899 d_loss: 0.051 anomaly_score: 947.735
# 1816/2000 epoch ge_loss: 11.450 d_loss: 0.023 anomaly_score: 982.781
# 1817/2000 epoch ge_loss: 10.464 d_loss: 0.006 anomaly_score: 971.685
# 1818/2000 epoch ge_loss: 11.967 d_loss: 0.030 anomaly_score: 976.757
# 1819/2000 epoch ge_loss: 12.232 d_loss: 0.028 anomaly_score: 1013.208
# 1820/2000 epoch ge_loss: 11.018 d_loss: 0.007 anomaly_score: 1020.520
# 1821/2000 epoch ge_loss: 10.371 d_loss: 0.021 anomaly_score: 1016.658
# 1822/2000 epoch ge_loss: 11.684 d_loss: 0.015 anomaly_score: 1010.868
# 1823/2000 epoch ge_loss: 11.165 d_loss: 0.014 anomaly_score: 999.863
# 1824/2000 epoch ge_loss: 10.492 d_loss: 0.014 anomaly_score: 1005.320
# 1825/2000 epoch ge_loss: 11.228 d_loss: 0.023 anomaly_score: 992.816
# 1826/2000 epoch ge_loss: 11.191 d_loss: 0.027 anomaly_score: 968.321
# 1827/2000 epoch ge_loss: 11.272 d_loss: 0.014 anomaly_score: 996.153
# 1828/2000 epoch ge_loss: 10.410 d_loss: 0.040 anomaly_score: 996.686
# 1829/2000 epoch ge_loss: 12.954 d_loss: 0.025 anomaly_score: 992.799
# 1830/2000 epoch ge_loss: 10.797 d_loss: 0.036 anomaly_score: 990.189
# 1831/2000 epoch ge_loss: 10.652 d_loss: 0.019 anomaly_score: 980.654
# 1832/2000 epoch ge_loss: 11.738 d_loss: 0.031 anomaly_score: 968.359
# 1833/2000 epoch ge_loss: 10.718 d_loss: 0.026 anomaly_score: 1004.714
# 1834/2000 epoch ge_loss: 11.027 d_loss: 0.010 anomaly_score: 1024.692
# 1835/2000 epoch ge_loss: 11.701 d_loss: 0.015 anomaly_score: 1014.311
# 1836/2000 epoch ge_loss: 10.931 d_loss: 0.019 anomaly_score: 988.576
# 1837/2000 epoch ge_loss: 11.352 d_loss: 0.019 anomaly_score: 937.647
# 1838/2000 epoch ge_loss: 12.379 d_loss: 0.025 anomaly_score: 919.864
# 1839/2000 epoch ge_loss: 11.224 d_loss: 0.006 anomaly_score: 949.911
# 1840/2000 epoch ge_loss: 12.010 d_loss: 0.019 anomaly_score: 962.482
# 1841/2000 epoch ge_loss: 11.343 d_loss: 0.068 anomaly_score: 950.404
# 1842/2000 epoch ge_loss: 11.409 d_loss: 0.039 anomaly_score: 966.985
# 1843/2000 epoch ge_loss: 10.975 d_loss: 0.024 anomaly_score: 987.309
# 1844/2000 epoch ge_loss: 10.814 d_loss: 0.039 anomaly_score: 987.911
# 1845/2000 epoch ge_loss: 10.743 d_loss: 0.026 anomaly_score: 961.724
# 1846/2000 epoch ge_loss: 10.402 d_loss: 0.031 anomaly_score: 961.510
# 1847/2000 epoch ge_loss: 12.936 d_loss: 0.026 anomaly_score: 971.131
# 1848/2000 epoch ge_loss: 11.152 d_loss: 0.036 anomaly_score: 997.644
# 1849/2000 epoch ge_loss: 11.160 d_loss: 0.013 anomaly_score: 946.390
# 1850/2000 epoch ge_loss: 12.167 d_loss: 0.019 anomaly_score: 974.728
# 1851/2000 epoch ge_loss: 10.703 d_loss: 0.025 anomaly_score: 982.945
# 1852/2000 epoch ge_loss: 11.029 d_loss: 0.017 anomaly_score: 987.749
# 1853/2000 epoch ge_loss: 12.669 d_loss: 0.024 anomaly_score: 979.853
# 1854/2000 epoch ge_loss: 11.966 d_loss: 0.032 anomaly_score: 975.178
# 1855/2000 epoch ge_loss: 10.495 d_loss: 0.010 anomaly_score: 997.615
# 1856/2000 epoch ge_loss: 11.376 d_loss: 0.031 anomaly_score: 1000.292
# 1857/2000 epoch ge_loss: 10.201 d_loss: 0.008 anomaly_score: 1045.001
# 1858/2000 epoch ge_loss: 11.568 d_loss: 0.022 anomaly_score: 1037.310
# 1859/2000 epoch ge_loss: 11.017 d_loss: 0.015 anomaly_score: 1013.703
# 1860/2000 epoch ge_loss: 12.306 d_loss: 0.049 anomaly_score: 992.630
# 1861/2000 epoch ge_loss: 10.741 d_loss: 0.039 anomaly_score: 1005.478
# 1862/2000 epoch ge_loss: 12.603 d_loss: 0.035 anomaly_score: 997.054
# 1863/2000 epoch ge_loss: 10.388 d_loss: 0.080 anomaly_score: 979.619
# 1864/2000 epoch ge_loss: 11.699 d_loss: 0.028 anomaly_score: 984.470
# 1865/2000 epoch ge_loss: 11.596 d_loss: 0.012 anomaly_score: 980.208
# 1866/2000 epoch ge_loss: 11.634 d_loss: 0.013 anomaly_score: 1009.157
# 1867/2000 epoch ge_loss: 11.176 d_loss: 0.031 anomaly_score: 994.465
# 1868/2000 epoch ge_loss: 11.090 d_loss: 0.019 anomaly_score: 965.556
# 1869/2000 epoch ge_loss: 10.470 d_loss: 0.038 anomaly_score: 969.487
# 1870/2000 epoch ge_loss: 11.233 d_loss: 0.029 anomaly_score: 961.554
# 1871/2000 epoch ge_loss: 10.445 d_loss: 0.023 anomaly_score: 946.009
# 1872/2000 epoch ge_loss: 10.924 d_loss: 0.004 anomaly_score: 940.027
# 1873/2000 epoch ge_loss: 11.320 d_loss: 0.023 anomaly_score: 961.966
# 1874/2000 epoch ge_loss: 11.876 d_loss: 0.014 anomaly_score: 980.874
# 1875/2000 epoch ge_loss: 12.061 d_loss: 0.009 anomaly_score: 986.333
# 1876/2000 epoch ge_loss: 10.538 d_loss: 0.009 anomaly_score: 988.769
# 1877/2000 epoch ge_loss: 11.608 d_loss: 0.023 anomaly_score: 999.017
# 1878/2000 epoch ge_loss: 10.435 d_loss: 0.038 anomaly_score: 1008.907
# 1879/2000 epoch ge_loss: 12.132 d_loss: 0.022 anomaly_score: 1001.271
# 1880/2000 epoch ge_loss: 11.657 d_loss: 0.020 anomaly_score: 959.029
# 1881/2000 epoch ge_loss: 11.828 d_loss: 0.018 anomaly_score: 970.374
# 1882/2000 epoch ge_loss: 11.182 d_loss: 0.014 anomaly_score: 996.787
# 1883/2000 epoch ge_loss: 11.066 d_loss: 0.020 anomaly_score: 996.552
# 1884/2000 epoch ge_loss: 11.286 d_loss: 0.015 anomaly_score: 978.398
# 1885/2000 epoch ge_loss: 10.778 d_loss: 0.042 anomaly_score: 976.363
# 1886/2000 epoch ge_loss: 11.297 d_loss: 0.040 anomaly_score: 985.606
# 1887/2000 epoch ge_loss: 10.740 d_loss: 0.033 anomaly_score: 972.359
# 1888/2000 epoch ge_loss: 10.752 d_loss: 0.014 anomaly_score: 997.075
# 1889/2000 epoch ge_loss: 12.075 d_loss: 0.010 anomaly_score: 962.088
# 1890/2000 epoch ge_loss: 10.482 d_loss: 0.045 anomaly_score: 938.403
# 1891/2000 epoch ge_loss: 11.912 d_loss: 0.020 anomaly_score: 930.616
# 1892/2000 epoch ge_loss: 11.702 d_loss: 0.021 anomaly_score: 969.442
# 1893/2000 epoch ge_loss: 11.363 d_loss: 0.038 anomaly_score: 985.694
# 1894/2000 epoch ge_loss: 10.843 d_loss: 0.014 anomaly_score: 992.061
# 1895/2000 epoch ge_loss: 12.238 d_loss: 0.020 anomaly_score: 978.586
# 1896/2000 epoch ge_loss: 11.829 d_loss: 0.018 anomaly_score: 973.710
# 1897/2000 epoch ge_loss: 11.531 d_loss: 0.015 anomaly_score: 988.511
# 1898/2000 epoch ge_loss: 12.072 d_loss: 0.014 anomaly_score: 969.729
# 1899/2000 epoch ge_loss: 12.535 d_loss: 0.014 anomaly_score: 975.198
# 1900/2000 epoch ge_loss: 10.776 d_loss: 0.017 anomaly_score: 987.412
# 1901/2000 epoch ge_loss: 11.162 d_loss: 0.017 anomaly_score: 957.126
# 1902/2000 epoch ge_loss: 10.978 d_loss: 0.022 anomaly_score: 950.857
# 1903/2000 epoch ge_loss: 10.436 d_loss: 0.023 anomaly_score: 987.044
# 1904/2000 epoch ge_loss: 12.076 d_loss: 0.016 anomaly_score: 984.776
# 1905/2000 epoch ge_loss: 12.521 d_loss: 0.026 anomaly_score: 998.077
# 1906/2000 epoch ge_loss: 12.034 d_loss: 0.015 anomaly_score: 1011.250
# 1907/2000 epoch ge_loss: 11.432 d_loss: 0.021 anomaly_score: 973.264
# 1908/2000 epoch ge_loss: 12.437 d_loss: 0.022 anomaly_score: 994.737
# 1909/2000 epoch ge_loss: 9.921 d_loss: 0.050 anomaly_score: 998.668
# 1910/2000 epoch ge_loss: 10.596 d_loss: 0.013 anomaly_score: 978.106
# 1911/2000 epoch ge_loss: 11.287 d_loss: 0.036 anomaly_score: 999.902
# 1912/2000 epoch ge_loss: 10.753 d_loss: 0.007 anomaly_score: 985.418
# 1913/2000 epoch ge_loss: 11.185 d_loss: 0.022 anomaly_score: 962.753
# 1914/2000 epoch ge_loss: 10.686 d_loss: 0.034 anomaly_score: 985.557
# 1915/2000 epoch ge_loss: 10.755 d_loss: 0.024 anomaly_score: 1017.299
# 1916/2000 epoch ge_loss: 11.831 d_loss: 0.013 anomaly_score: 1006.678
# 1917/2000 epoch ge_loss: 11.042 d_loss: 0.021 anomaly_score: 975.854
# 1918/2000 epoch ge_loss: 10.901 d_loss: 0.018 anomaly_score: 1011.494
# 1919/2000 epoch ge_loss: 10.857 d_loss: 0.021 anomaly_score: 1010.291
# 1920/2000 epoch ge_loss: 10.521 d_loss: 0.018 anomaly_score: 1009.701
# 1921/2000 epoch ge_loss: 10.293 d_loss: 0.030 anomaly_score: 1002.432
# 1922/2000 epoch ge_loss: 11.398 d_loss: 0.011 anomaly_score: 999.167
# 1923/2000 epoch ge_loss: 12.723 d_loss: 0.028 anomaly_score: 987.306
# 1924/2000 epoch ge_loss: 10.778 d_loss: 0.014 anomaly_score: 947.840
# 1925/2000 epoch ge_loss: 11.640 d_loss: 0.033 anomaly_score: 948.345
# 1926/2000 epoch ge_loss: 10.381 d_loss: 0.019 anomaly_score: 966.967
# 1927/2000 epoch ge_loss: 11.265 d_loss: 0.015 anomaly_score: 1005.558
# 1928/2000 epoch ge_loss: 11.370 d_loss: 0.027 anomaly_score: 1013.479
# 1929/2000 epoch ge_loss: 10.766 d_loss: 0.032 anomaly_score: 976.264
# 1930/2000 epoch ge_loss: 12.045 d_loss: 0.032 anomaly_score: 961.500
# 1931/2000 epoch ge_loss: 10.875 d_loss: 0.012 anomaly_score: 975.724
# 1932/2000 epoch ge_loss: 11.432 d_loss: 0.018 anomaly_score: 978.052
# 1933/2000 epoch ge_loss: 11.493 d_loss: 0.022 anomaly_score: 990.922
# 1934/2000 epoch ge_loss: 11.160 d_loss: 0.021 anomaly_score: 969.576
# 1935/2000 epoch ge_loss: 11.075 d_loss: 0.020 anomaly_score: 1003.092
# 1936/2000 epoch ge_loss: 10.405 d_loss: 0.031 anomaly_score: 1011.654
# 1937/2000 epoch ge_loss: 10.736 d_loss: 0.020 anomaly_score: 1002.224
# 1938/2000 epoch ge_loss: 10.353 d_loss: 0.011 anomaly_score: 987.304
# 1939/2000 epoch ge_loss: 11.201 d_loss: 0.017 anomaly_score: 1013.278
# 1940/2000 epoch ge_loss: 10.426 d_loss: 0.019 anomaly_score: 978.395
# 1941/2000 epoch ge_loss: 10.598 d_loss: 0.034 anomaly_score: 960.650
# 1942/2000 epoch ge_loss: 11.813 d_loss: 0.013 anomaly_score: 946.638
# 1943/2000 epoch ge_loss: 10.675 d_loss: 0.019 anomaly_score: 988.041
# 1944/2000 epoch ge_loss: 10.496 d_loss: 0.028 anomaly_score: 1011.186
# 1945/2000 epoch ge_loss: 10.412 d_loss: 0.015 anomaly_score: 995.488
# 1946/2000 epoch ge_loss: 12.154 d_loss: 0.019 anomaly_score: 1007.629
# 1947/2000 epoch ge_loss: 10.736 d_loss: 0.012 anomaly_score: 1017.807
# 1948/2000 epoch ge_loss: 12.542 d_loss: 0.025 anomaly_score: 1050.652
# 1949/2000 epoch ge_loss: 10.987 d_loss: 0.005 anomaly_score: 1026.496
# 1950/2000 epoch ge_loss: 11.749 d_loss: 0.017 anomaly_score: 1000.872
# 1951/2000 epoch ge_loss: 11.278 d_loss: 0.021 anomaly_score: 1001.746
# 1952/2000 epoch ge_loss: 11.336 d_loss: 0.018 anomaly_score: 976.350
# 1953/2000 epoch ge_loss: 10.906 d_loss: 0.015 anomaly_score: 992.802
# 1954/2000 epoch ge_loss: 10.662 d_loss: 0.014 anomaly_score: 955.831
# 1955/2000 epoch ge_loss: 11.742 d_loss: 0.008 anomaly_score: 948.442
# 1956/2000 epoch ge_loss: 11.075 d_loss: 0.008 anomaly_score: 952.304
# 1957/2000 epoch ge_loss: 12.578 d_loss: 0.013 anomaly_score: 968.519
# 1958/2000 epoch ge_loss: 10.461 d_loss: 0.022 anomaly_score: 972.287
# 1959/2000 epoch ge_loss: 13.313 d_loss: 0.027 anomaly_score: 944.181
# 1960/2000 epoch ge_loss: 12.023 d_loss: 0.028 anomaly_score: 981.930
# 1961/2000 epoch ge_loss: 11.564 d_loss: 0.024 anomaly_score: 1023.016
# 1962/2000 epoch ge_loss: 10.777 d_loss: 0.023 anomaly_score: 1014.342
# 1963/2000 epoch ge_loss: 12.898 d_loss: 0.019 anomaly_score: 999.829
# 1964/2000 epoch ge_loss: 10.592 d_loss: 0.011 anomaly_score: 1001.397
# 1965/2000 epoch ge_loss: 11.682 d_loss: 0.029 anomaly_score: 1025.303
# 1966/2000 epoch ge_loss: 12.061 d_loss: 0.014 anomaly_score: 1032.172
# 1967/2000 epoch ge_loss: 11.481 d_loss: 0.024 anomaly_score: 1015.762
# 1968/2000 epoch ge_loss: 10.710 d_loss: 0.036 anomaly_score: 1011.884
# 1969/2000 epoch ge_loss: 12.472 d_loss: 0.029 anomaly_score: 984.761
# 1970/2000 epoch ge_loss: 11.279 d_loss: 0.017 anomaly_score: 1014.914
# 1971/2000 epoch ge_loss: 11.272 d_loss: 0.017 anomaly_score: 1026.933
# 1972/2000 epoch ge_loss: 12.503 d_loss: 0.035 anomaly_score: 1007.633
# 1973/2000 epoch ge_loss: 10.593 d_loss: 0.018 anomaly_score: 994.712
# 1974/2000 epoch ge_loss: 10.627 d_loss: 0.017 anomaly_score: 981.634
# 1975/2000 epoch ge_loss: 12.721 d_loss: 0.032 anomaly_score: 998.485
# 1976/2000 epoch ge_loss: 10.946 d_loss: 0.028 anomaly_score: 1017.354
# 1977/2000 epoch ge_loss: 10.858 d_loss: 0.021 anomaly_score: 983.711
# 1978/2000 epoch ge_loss: 11.942 d_loss: 0.051 anomaly_score: 970.369
# 1979/2000 epoch ge_loss: 12.626 d_loss: 0.014 anomaly_score: 991.353
# 1980/2000 epoch ge_loss: 12.955 d_loss: 0.035 anomaly_score: 1041.967
# 1981/2000 epoch ge_loss: 10.978 d_loss: 0.023 anomaly_score: 1049.214
# 1982/2000 epoch ge_loss: 10.771 d_loss: 0.015 anomaly_score: 1005.210
# 1983/2000 epoch ge_loss: 11.056 d_loss: 0.034 anomaly_score: 994.683
# 1984/2000 epoch ge_loss: 10.813 d_loss: 0.039 anomaly_score: 996.901
# 1985/2000 epoch ge_loss: 10.893 d_loss: 0.035 anomaly_score: 1066.910
# 1986/2000 epoch ge_loss: 11.518 d_loss: 0.024 anomaly_score: 1051.978
# 1987/2000 epoch ge_loss: 10.719 d_loss: 0.022 anomaly_score: 1034.548
# 1988/2000 epoch ge_loss: 11.186 d_loss: 0.016 anomaly_score: 1021.466
# 1989/2000 epoch ge_loss: 10.878 d_loss: 0.022 anomaly_score: 970.347
# 1990/2000 epoch ge_loss: 10.046 d_loss: 0.027 anomaly_score: 968.563
# 1991/2000 epoch ge_loss: 11.021 d_loss: 0.013 anomaly_score: 969.494
# 1992/2000 epoch ge_loss: 10.890 d_loss: 0.014 anomaly_score: 1025.271
# 1993/2000 epoch ge_loss: 11.110 d_loss: 0.023 anomaly_score: 1022.908
# 1994/2000 epoch ge_loss: 11.785 d_loss: 0.010 anomaly_score: 1035.731
# 1995/2000 epoch ge_loss: 11.656 d_loss: 0.008 anomaly_score: 1004.727
# 1996/2000 epoch ge_loss: 11.589 d_loss: 0.012 anomaly_score: 1018.409
# 1997/2000 epoch ge_loss: 10.760 d_loss: 0.029 anomaly_score: 978.514
# 1998/2000 epoch ge_loss: 12.301 d_loss: 0.019 anomaly_score: 995.564
# 1999/2000 epoch ge_loss: 11.052 d_loss: 0.006 anomaly_score: 1002.632

# %%
# Generator+EncoderとDiscriminatorのLossの推移と、anomaly scoreの推移
plt.figure(figsize=(12, 8*2))

plt.subplot(211)
plt.plot(range(len(Losses_GE)), Losses_GE, label="ge loss",color="blue")
plt.legend()

plt.plot(range(len(Losses_D)), Losses_D, label="d loss",color="orange")
plt.legend()
plt.subplot(212)
plt.plot(range(len(anomaly_scores)), anomaly_scores, label="anomaly score",color="green")
plt.legend()

plt.show()

# %% [markdown]
# # 潜在変数Zの最適化とテスト画像での異常検知

# %%
# 学習したモデルの読み込み

LOAD_EPOCH = 2000

G = Generator().to(device)
G.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Generator_{LOAD_EPOCH}.pkl"))
G.eval()


E = Encoder().to(device)
E.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Encoder_{LOAD_EPOCH}.pkl"))
E.eval()

D = Discriminator().to(device)
D.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Discriminator_{LOAD_EPOCH}.pkl"))
D.eval()
print("load model")
# Out:
# load model

# %%
# 正常な画像で実行

random_image_size = 40

test_root_normal = './screw/test/good/'
test_dataset_normal = LoadFromFolder(test_root_normal, transform=transform_dict["test"])

test_images_normal = random.sample(list(test_dataset_normal), random_image_size)

normal_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_normal)):

    x = test_images_normal[idx].view(1, 3, 96, 96).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    normal_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %%
# manipulated_frontで実行

random_image_size = 20

test_root_manipulated_front = './screw/test/manipulated_front/'
test_dataset_manipulated_front = LoadFromFolder(test_root_manipulated_front, transform=transform_dict["test"])

test_images_manipulated_front = random.sample(list(test_dataset_manipulated_front), random_image_size)

manipulated_front_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_manipulated_front)):

    x = test_images_manipulated_front[idx].view(1, 3, 96, 96).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    manipulated_front_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()
# Out:
# Anomaly_score: 438.724
# Anomaly_score: 449.026
# Anomaly_score: 475.536
# Anomaly_score: 450.874
# Anomaly_score: 418.250
# Anomaly_score: 476.693
# Anomaly_score: 449.439
# Anomaly_score: 531.336
# Anomaly_score: 375.021
# Anomaly_score: 465.868
# Anomaly_score: 459.326
# Anomaly_score: 453.810
# Anomaly_score: 454.671
# Anomaly_score: 396.394
# Anomaly_score: 408.975
# Anomaly_score: 383.489
# Anomaly_score: 452.719
# Anomaly_score: 414.861
# Anomaly_score: 431.224
# Anomaly_score: 409.644

# %%
# 正常品のスコアをデータフレーム化
normal_df = pd.DataFrame({'score': normal_anomaly_score})
normal_df['label'] = 'normal'

# 傷品のスコアをデータフレーム化
manipulated_front_df = pd.DataFrame({'score': manipulated_front_anomaly_score})
manipulated_front_df['label'] = 'scratch'

#テストデータのlossを可視化
plt.hist(normal_df['score'], alpha=0.5, bins=20, label='normal')
plt.hist(manipulated_front_df['score'], alpha=0.5, bins=20, label='scratch')
plt.legend(loc="upper right", fontsize=13)
plt.show()
