# %% [markdown]
# # 環境確認

# %%
import sys
import torch

print("Pythonのバージョン：",sys.version)
print("PyTorchのバージョン：", torch.__version__)
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# Pythonのバージョン： 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# PyTorchのバージョン： 1.10.0+cu111
# 使用しているGPUの確認
# Tue Feb 22 04:01:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    81W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # データのダウンロード

# %%
# データのダウンロード
# !wget https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420938130-1629953152/screw.tar.xz
# Out:
# --2022-02-22 04:01:44--  https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420938130-1629953152/screw.tar.xz
# Resolving www.mydrive.ch (www.mydrive.ch)... 91.214.169.64
# Connecting to www.mydrive.ch (www.mydrive.ch)|91.214.169.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 195344332 (186M) [application/x-xz]
# Saving to: ‘screw.tar.xz.2’
#
# screw.tar.xz.2      100%[===================>] 186.29M  18.8MB/s    in 11s
#
# 2022-02-22 04:01:56 (16.7 MB/s) - ‘screw.tar.xz.2’ saved [195344332/195344332]

# %%
# 解凍
# !tar -xf screw.tar.xz

# %%
# 作業ディレクトリを確認
# !ls
# Out:
# results  sample_data  screw  screw.tar.xz  screw.tar.xz.1  screw.tar.xz.2

# %% [markdown]
# # テストデータの準備

# %%
# テストデータのディレクトリを確認
# !ls screw/test/
# Out:
# good  manipulated_front  scratch_head  scratch_neck  thread_side  thread_top

# %%
# testディレクトリ内のディレクトリ内の画像リストを作成
import glob

good = glob.glob('screw/test/good/*.png')
manipulated_front = glob.glob('screw/test/manipulated_front/*.png')
scratch_head = glob.glob('screw/test/scratch_head/*.png')
scratch_neck = glob.glob('screw/test/scratch_neck/*.png')
thread_side = glob.glob('screw/test/thread_side/*.png')
thread_top = glob.glob('screw/test/thread_top/*.png')
print(good)
print(len(good))
# Out:
# ['screw/test/good/008.png', 'screw/test/good/017.png', 'screw/test/good/036.png', 'screw/test/good/037.png', 'screw/test/good/002.png', 'screw/test/good/020.png', 'screw/test/good/022.png', 'screw/test/good/038.png', 'screw/test/good/003.png', 'screw/test/good/025.png', 'screw/test/good/000.png', 'screw/test/good/018.png', 'screw/test/good/007.png', 'screw/test/good/031.png', 'screw/test/good/005.png', 'screw/test/good/040.png', 'screw/test/good/035.png', 'screw/test/good/034.png', 'screw/test/good/013.png', 'screw/test/good/015.png', 'screw/test/good/024.png', 'screw/test/good/019.png', 'screw/test/good/027.png', 'screw/test/good/009.png', 'screw/test/good/016.png', 'screw/test/good/011.png', 'screw/test/good/029.png', 'screw/test/good/033.png', 'screw/test/good/014.png', 'screw/test/good/012.png', 'screw/test/good/023.png', 'screw/test/good/039.png', 'screw/test/good/006.png', 'screw/test/good/001.png', 'screw/test/good/028.png', 'screw/test/good/004.png', 'screw/test/good/026.png', 'screw/test/good/021.png', 'screw/test/good/030.png', 'screw/test/good/010.png', 'screw/test/good/032.png']
# 41

# %% [markdown]
# # 事前準備

# %%
# ライブラリのインポート
import os
import random
from glob import glob
from warnings import filterwarnings

import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
import torch.nn.init as init
from natsort import natsorted
from PIL import Image
from skimage import io, transform
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image

from torchsummary import summary

filterwarnings("ignore")  # warningをオフにする

# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
'''デバイスの設定'''

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
'''初期設定'''

COLAB_FLG = False  # COLABで実行する場合はTrue, それ以外で実行する場合はFalse

if COLAB_FLG:
    from google.colab import drive
    drive.mount('/content/gdrive') # マウント先
    ATTACH_PATH = "/content/gdrive/MyDrive/screw_anomaly"  # 保存先のベースディレクトリ
else:
    ATTACH_PATH = "."  # ローカルならカレントディレクトリ
    
    
SAVE_MODEL_PATH = f"{ATTACH_PATH}/results/model/"  # モデルの保存先
SAVE_IMAGE_FROM_Z_PATH = f"{ATTACH_PATH}/results/image/image_from_z/"  # 乱数から生成した画像の保存先
SAVE_IMAGE_RECONSTRUCT = f"{ATTACH_PATH}/results/image/RECONSTRUCT/"  # 再構成した画像の保存先

# 保存先のディレクトリを作成する
os.makedirs(SAVE_MODEL_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_FROM_Z_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_RECONSTRUCT, exist_ok=True)

# %%
'''ハイパーパラメータの設定'''

import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--image_size", type=int, default=384)
parser.add_argument("--num_epochs", type=int, default=1000)
parser.add_argument("--batch_size", type=int, default=16)
parser.add_argument("--lr", type=float, default=4e-4)
parser.add_argument("--z_dim", type=int, default=128) # ノイズの次元
parser.add_argument("--beta1", type=float, default=0.5) # Adamのハイパーパラメータ
parser.add_argument("--beta2", type=float, default=0.999) # Adamのハイパーパラメータ
opt = parser.parse_args(args=[])
print(opt)
# Out:
# Namespace(batch_size=16, beta1=0.5, beta2=0.999, image_size=384, lr=0.0004, num_epochs=1000, z_dim=128)

# %%
# デバイスの設定
device = "cuda" if torch.cuda.is_available() else "cpu"
kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {} # GPUが使える場合、DataLoaderでのミニバッチの取り出しを高速化

# %% [markdown]
# # DataLoader

# %%
train_root = './screw/train/good/'  # train dataの保存してあるディレクトリ
val_root = './screw/test/good/'  # val dataの保存してあるディレクトリ

# ディレクトリから画像を読み込んでDataLoaderに渡す用のクラス

class LoadFromFolder(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = natsorted(os.listdir(main_dir)) # ディレクトリ一覧を取得して自然ソート
        self.all_imgs_name = natsorted(all_imgs)
        self.imgs_loc = [os.path.join(self.main_dir, i) for i in self.all_imgs_name] # 画像のディレクトリ一覧

    def __len__(self):
        return len(self.all_imgs_name)
    
    def load_image(self, path):
        image = Image.open(path).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image
    
    def __getitem__(self, idx):
        
        # 後ほどsliceで画像を複数枚取得したいのでsliceでも取れるようにする
        if type(idx) == slice:
            paths = self.imgs_loc[idx]
            tensor_image = [self.load_image(path) for path in paths]
            tensor_image = torch.cat(tensor_image).reshape(len(tensor_image), *tensor_image[0].shape)
        elif type(idx) == int:
            path = self.imgs_loc[idx]
            tensor_image = self.load_image(path)
        return tensor_image

# 画像を読み込む際の前処理

transform_dict = {
    "train": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.RandomHorizontalFlip(), # ランダムに左右反転を行う
            transforms.ToTensor(),
        ]
    ),
    "test": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.ToTensor(),
        ]
    ),
}

# データを読み込む
train_dataset = LoadFromFolder(train_root, transform=transform_dict["train"])

test_dataset = LoadFromFolder(val_root, transform=transform_dict["test"])

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

val_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

# %% [markdown]
# # Encoder

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=4, stride=2, padding=1, bias=False), # 96x96
            nn.BatchNorm2d(8),
            nn.LeakyReLU(0.2),

            nn.Conv2d(8, 16, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2), 

            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(256, 512, kernel_size=6, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(512, 512, kernel_size=1, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
        )

        self.last = nn.Sequential(nn.Conv2d(512, opt.z_dim, kernel_size=1, stride=1, bias=False))

    def forward(self, x):

        out = self.main(x)
        out = self.last(out)
        out = out.view(out.size()[0], -1, 1, 1)
        return out

# %%
# ネットワークを可視化する
summary(Encoder().to(device), (3, opt.image_size, opt.image_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 192, 192]             384
#        BatchNorm2d-2          [-1, 8, 192, 192]              16
#          LeakyReLU-3          [-1, 8, 192, 192]               0
#             Conv2d-4           [-1, 16, 96, 96]           2,048
#        BatchNorm2d-5           [-1, 16, 96, 96]              32
#          LeakyReLU-6           [-1, 16, 96, 96]               0
#             Conv2d-7           [-1, 32, 48, 48]           8,192
#        BatchNorm2d-8           [-1, 32, 48, 48]              64
#          LeakyReLU-9           [-1, 32, 48, 48]               0
#            Conv2d-10           [-1, 64, 24, 24]          32,768
#       BatchNorm2d-11           [-1, 64, 24, 24]             128
#         LeakyReLU-12           [-1, 64, 24, 24]               0
#            Conv2d-13          [-1, 128, 12, 12]         131,072
#       BatchNorm2d-14          [-1, 128, 12, 12]             256
#         LeakyReLU-15          [-1, 128, 12, 12]               0
#            Conv2d-16            [-1, 256, 6, 6]         524,288
#       BatchNorm2d-17            [-1, 256, 6, 6]             512
#         LeakyReLU-18            [-1, 256, 6, 6]               0
#            Conv2d-19            [-1, 512, 1, 1]       4,718,592
#       BatchNorm2d-20            [-1, 512, 1, 1]           1,024
#         LeakyReLU-21            [-1, 512, 1, 1]               0
#            Conv2d-22            [-1, 512, 1, 1]         262,144
#       BatchNorm2d-23            [-1, 512, 1, 1]           1,024
#         LeakyReLU-24            [-1, 512, 1, 1]               0
#            Conv2d-25            [-1, 128, 1, 1]          65,536
# ================================================================
# Total params: 5,748,080
# Trainable params: 5,748,080
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.69
# Forward/backward pass size (MB): 13.31
# Params size (MB): 21.93
# Estimated Total Size (MB): 36.93
# ----------------------------------------------------------------

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.main = nn.Sequential(
            nn.ConvTranspose2d(opt.z_dim, 1024, kernel_size=6, stride=1, padding=0, bias=False), # 3x3
            nn.BatchNorm2d(1024),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(1024, 512, kernel_size=7, stride=1, padding=0, bias=False), # 6x6
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(512, 256, kernel_size=13, stride=1, padding=0, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False), #96x96
            nn.Tanh()
        )

    def forward(self, z):
        out = self.main(z)
        return out

# %%
# ネットワークを可視化する
summary(Generator().to(device), tuple([opt.z_dim, 1, 1]))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1           [-1, 1024, 6, 6]       4,718,592
#        BatchNorm2d-2           [-1, 1024, 6, 6]           2,048
#          LeakyReLU-3           [-1, 1024, 6, 6]               0
#    ConvTranspose2d-4          [-1, 512, 12, 12]      25,690,112
#        BatchNorm2d-5          [-1, 512, 12, 12]           1,024
#          LeakyReLU-6          [-1, 512, 12, 12]               0
#    ConvTranspose2d-7          [-1, 256, 24, 24]      22,151,168
#        BatchNorm2d-8          [-1, 256, 24, 24]             512
#          LeakyReLU-9          [-1, 256, 24, 24]               0
#   ConvTranspose2d-10          [-1, 128, 48, 48]         524,288
#       BatchNorm2d-11          [-1, 128, 48, 48]             256
#         LeakyReLU-12          [-1, 128, 48, 48]               0
#   ConvTranspose2d-13           [-1, 64, 96, 96]         131,072
#       BatchNorm2d-14           [-1, 64, 96, 96]             128
#         LeakyReLU-15           [-1, 64, 96, 96]               0
#   ConvTranspose2d-16         [-1, 32, 192, 192]          32,768
#       BatchNorm2d-17         [-1, 32, 192, 192]              64
#         LeakyReLU-18         [-1, 32, 192, 192]               0
#   ConvTranspose2d-19          [-1, 3, 384, 384]           1,536
#              Tanh-20          [-1, 3, 384, 384]               0
# ================================================================
# Total params: 53,253,568
# Trainable params: 53,253,568
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 59.91
# Params size (MB): 203.15
# Estimated Total Size (MB): 263.05
# ----------------------------------------------------------------

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
            
        self.x_layer = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=3, stride=1, padding=1),
            # nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1, inplace=True), #96x96
            nn.Dropout2d(p=0.3),

            nn.AvgPool2d(2),
            nn.Conv2d(8, 16, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.1, inplace=True), #48x48
            nn.Dropout2d(p=0.3),

            nn.AvgPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1, inplace=True), #48x48
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True), #24x24
            nn.Dropout2d(p=0.3),

            nn.AvgPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True), #12x12
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.1, inplace=True), #6x6
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(256, 256, kernel_size=6, stride=1) #1x1

        )
        self.z_layer = nn.Sequential(
            nn.Conv2d(opt.z_dim, 256, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.2),
        )
        
        self.last1 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=False),
            nn.Dropout2d(p=0.2),
        )
        self.last2 = nn.Sequential(
            nn.Conv2d(512, 1, kernel_size=1, stride=1),
        )

    def forward(self, x, z):
        
        output_x = self.x_layer(x)
        output_z = self.z_layer(z)
        
        concat_x_z = torch.cat((output_x, output_z), 1)
        output = self.last1(concat_x_z)

        feature = output.view(output.size()[0], -1)
        
        output = self.last2(output)
        output = F.sigmoid(output)
        return output.squeeze(), feature

# %%
# ネットワークを可視化する
summary(Discriminator().to(device), [(3, opt.image_size, opt.image_size), (opt.z_dim, 1, 1)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 384, 384]             224
#          LeakyReLU-2          [-1, 8, 384, 384]               0
#          Dropout2d-3          [-1, 8, 384, 384]               0
#          AvgPool2d-4          [-1, 8, 192, 192]               0
#             Conv2d-5         [-1, 16, 192, 192]           1,168
#        BatchNorm2d-6         [-1, 16, 192, 192]              32
#          LeakyReLU-7         [-1, 16, 192, 192]               0
#          Dropout2d-8         [-1, 16, 192, 192]               0
#          AvgPool2d-9           [-1, 16, 96, 96]               0
#            Conv2d-10           [-1, 32, 96, 96]           4,640
#       BatchNorm2d-11           [-1, 32, 96, 96]              64
#         LeakyReLU-12           [-1, 32, 96, 96]               0
#         Dropout2d-13           [-1, 32, 96, 96]               0
#         AvgPool2d-14           [-1, 32, 48, 48]               0
#            Conv2d-15           [-1, 64, 48, 48]          18,496
#       BatchNorm2d-16           [-1, 64, 48, 48]             128
#         LeakyReLU-17           [-1, 64, 48, 48]               0
#         Dropout2d-18           [-1, 64, 48, 48]               0
#         AvgPool2d-19           [-1, 64, 24, 24]               0
#            Conv2d-20          [-1, 128, 24, 24]          73,856
#       BatchNorm2d-21          [-1, 128, 24, 24]             256
#         LeakyReLU-22          [-1, 128, 24, 24]               0
#         Dropout2d-23          [-1, 128, 24, 24]               0
#         AvgPool2d-24          [-1, 128, 12, 12]               0
#            Conv2d-25          [-1, 256, 12, 12]         295,168
#       BatchNorm2d-26          [-1, 256, 12, 12]             512
#         LeakyReLU-27          [-1, 256, 12, 12]               0
#         Dropout2d-28          [-1, 256, 12, 12]               0
#         AvgPool2d-29            [-1, 256, 6, 6]               0
#            Conv2d-30            [-1, 256, 1, 1]       2,359,552
#            Conv2d-31            [-1, 256, 1, 1]          33,024
#         LeakyReLU-32            [-1, 256, 1, 1]               0
#         Dropout2d-33            [-1, 256, 1, 1]               0
#            Conv2d-34            [-1, 512, 1, 1]         262,656
#         LeakyReLU-35            [-1, 512, 1, 1]               0
#         Dropout2d-36            [-1, 512, 1, 1]               0
#            Conv2d-37              [-1, 1, 1, 1]             513
# ================================================================
# Total params: 3,050,289
# Trainable params: 3,050,289
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 216.00
# Forward/backward pass size (MB): 66.32
# Params size (MB): 11.64
# Estimated Total Size (MB): 293.96
# ----------------------------------------------------------------

# %%
# 重みの初期化を行う関数

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find("Linear") != -1:
        m.bias.data.fill_(0)

E = Encoder().to(device)
E.apply(weights_init)

G = Generator().to(device)
G.apply(weights_init)

D = Discriminator().to(device)
D.apply(weights_init)
# Out:
# Discriminator(
#   (x_layer): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (2): Dropout2d(p=0.3, inplace=False)
#     (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (4): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.1, inplace=True)
#     (7): Dropout2d(p=0.3, inplace=False)
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.1, inplace=True)
#     (12): Dropout2d(p=0.3, inplace=False)
#     (13): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (14): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.1, inplace=True)
#     (17): Dropout2d(p=0.3, inplace=False)
#     (18): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (19): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): LeakyReLU(negative_slope=0.1, inplace=True)
#     (22): Dropout2d(p=0.3, inplace=False)
#     (23): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (24): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): LeakyReLU(negative_slope=0.1, inplace=True)
#     (27): Dropout2d(p=0.3, inplace=False)
#     (28): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (29): Conv2d(256, 256, kernel_size=(6, 6), stride=(1, 1))
#   )
#   (z_layer): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (last1): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (last2): Sequential(
#     (0): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
criterion = nn.BCELoss()  # 評価関数
criterion_L1 = nn.L1Loss(reduction="sum") # 異常スコア計測用

# %%
# gとeは共通のoptimizer
optimizer_ge = torch.optim.Adam(list(G.parameters()) + list(E.parameters()), lr=opt.lr, betas=(opt.beta1,opt.beta2))
optimizer_d = torch.optim.Adam(D.parameters(), lr=opt.lr, betas=(opt.beta1,opt.beta2))

scheduler_ge = torch.optim.lr_scheduler.StepLR(optimizer_ge, step_size=50, gamma=0.9)
scheduler_d = torch.optim.lr_scheduler.StepLR(optimizer_d, step_size=50, gamma=0.9)

# %%
def Anomaly_score(x, E_x, G_E_x, Lambda=0.1):
    
    _,x_feature = D(x, E_x)
    _,G_E_x_feature = D(G_E_x, E_x)
    
    residual_loss = criterion_L1(x, G_E_x)
    discrimination_loss = criterion_L1(x_feature, G_E_x_feature)
    
    total_loss = (1-Lambda)*residual_loss + Lambda*discrimination_loss
    total_loss = total_loss.item()

    return total_loss

# %% [markdown]
# # 学習

# %%
Losses_D = []
Losses_GE = []
anomaly_scores = []

for epoch in range(opt.num_epochs):
    loss_d_sum = 0
    loss_ge_sum = 0
    anomaly_score_sum = 0
    
    for i,(x, x_val) in enumerate(zip(train_loader, val_loader)):
        
        G.train()
        D.train()
        E.train()

        # 値の設定
        y_true = Variable(torch.ones(x.size()[0])).to(device)
        y_fake = Variable(torch.zeros(x.size()[0])).to(device)
        
        x = Variable(x).to(device)
        z = Variable(init.normal(torch.Tensor(x.size()[0],opt.z_dim, 1, 1),mean=0,std=0.1)).to(device)
        
        # Discriminatorに対するノイズ
        noise1 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)
        noise2 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)

        # Discriminator
        optimizer_d.zero_grad()
        
        E_x = E(x) 
        p_true, _ = D(x + noise1, E_x)
        
        G_z = G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_d = criterion(p_true, y_true) + criterion(p_fake, y_fake)
        loss_d.backward(retain_graph=True)
        optimizer_d.step()
        
        # Generator, Encoder
        optimizer_ge.zero_grad()
        
        G_E_x = G(E_x)
        E_G_z = E(G_z)
    
        p_true, _ = D(x + noise1, E_x)
        
        # G_z = model_G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        
        loss_ge_1 = criterion(p_fake, y_true) + criterion(p_true, y_fake)
        loss_ge_2 = criterion_L1(x, G_E_x) +  criterion_L1(z, E_G_z)
        
        alpha = 0.01
        
        loss_ge = (1 - alpha)*loss_ge_1 + alpha*loss_ge_2
        loss_ge.backward(retain_graph=True)
        optimizer_ge.step()
        
        loss_d_sum += loss_d.item()
        loss_ge_sum += loss_ge.item()
        
        # anomaly scoreの記録
        
        G.eval()
        D.eval()
        E.eval()
        x_val = Variable(x_val).to(device)
        E_x_val = E(x_val)
        G_E_x_val = G(E_x_val)
        anomaly_score_sum += Anomaly_score(x_val, E_x_val, G_E_x_val)

        # 画像を保存
        if i == 0:
            
            G.eval()
            D.eval()
            E.eval()
        
            save_image_size_for_z = min(opt.batch_size, 8)
            save_images = G(z)
            save_image(save_images[:save_image_size_for_z], f"{SAVE_IMAGE_FROM_Z_PATH}/epoch_{epoch}.png", nrow=4)

            save_image_size_for_recon = min(opt.batch_size, 8)
            images = x[:save_image_size_for_recon]
            G_E_x = G(E(images))
            diff_images = torch.abs(images - G_E_x)
            comparison = torch.cat([images , G_E_x, diff_images]).to("cpu")
            save_image(comparison, f"{SAVE_IMAGE_RECONSTRUCT}/epoch_{epoch}.png", nrow=save_image_size_for_recon)
            
    scheduler_ge.step()
    scheduler_d.step()
        
    # lossを記録
    loss_d_mean = loss_d_sum / len(train_loader)
    loss_ge_mean = loss_ge_sum / len(train_loader)
    anomaly_score_mean = anomaly_score_sum / len(train_loader)
    
    print(f"{epoch}/{opt.num_epochs} epoch ge_loss: {loss_ge_mean:.3f} d_loss: {loss_d_mean:.3f} anomaly_score: {anomaly_score_mean:.3f}")
    
    Losses_D.append(loss_d_mean)
    Losses_GE.append(loss_ge_mean)
    anomaly_scores.append(anomaly_score_mean)
    
    # モデルを保存
    if (epoch + 1) % 10 == 0:
        torch.save(G.state_dict(),f'{SAVE_MODEL_PATH}/Generator_{epoch + 1}.pkl')
        torch.save(E.state_dict(),f'{SAVE_MODEL_PATH}/Encoder_{epoch + 1}.pkl')
        torch.save(D.state_dict(),f'{SAVE_MODEL_PATH}/Discriminator_{epoch + 1}.pkl')
# Out:
# 0/1000 epoch ge_loss: 7522.181 d_loss: 0.211 anomaly_score: 543351.550
# 1/1000 epoch ge_loss: 6861.415 d_loss: 0.208 anomaly_score: 532741.500
# 2/1000 epoch ge_loss: 6301.072 d_loss: 0.202 anomaly_score: 508252.925
# 3/1000 epoch ge_loss: 5679.238 d_loss: 0.188 anomaly_score: 465808.412
# 4/1000 epoch ge_loss: 5102.320 d_loss: 0.151 anomaly_score: 407572.769
# 5/1000 epoch ge_loss: 4489.125 d_loss: 0.106 anomaly_score: 337934.356
# 6/1000 epoch ge_loss: 3817.347 d_loss: 0.109 anomaly_score: 272796.644
# 7/1000 epoch ge_loss: 3397.768 d_loss: 0.057 anomaly_score: 213594.672
# 8/1000 epoch ge_loss: 2854.287 d_loss: 0.037 anomaly_score: 182793.106
# 9/1000 epoch ge_loss: 2422.390 d_loss: 0.026 anomaly_score: 133302.764
# 10/1000 epoch ge_loss: 2029.312 d_loss: 0.015 anomaly_score: 99704.791
# 11/1000 epoch ge_loss: 1723.303 d_loss: 0.015 anomaly_score: 101108.569
# 12/1000 epoch ge_loss: 1395.169 d_loss: 0.016 anomaly_score: 81032.562
# 13/1000 epoch ge_loss: 1106.152 d_loss: 0.019 anomaly_score: 73636.025
# 14/1000 epoch ge_loss: 1004.936 d_loss: 0.015 anomaly_score: 82169.934
# 15/1000 epoch ge_loss: 806.545 d_loss: 0.018 anomaly_score: 81617.183
# 16/1000 epoch ge_loss: 725.050 d_loss: 0.011 anomaly_score: 69364.522
# 17/1000 epoch ge_loss: 752.298 d_loss: 0.007 anomaly_score: 71976.564
# 18/1000 epoch ge_loss: 663.784 d_loss: 0.009 anomaly_score: 93769.742
# 19/1000 epoch ge_loss: 585.601 d_loss: 0.010 anomaly_score: 85465.177
# 20/1000 epoch ge_loss: 579.869 d_loss: 0.015 anomaly_score: 71959.919
# 21/1000 epoch ge_loss: 541.916 d_loss: 0.025 anomaly_score: 95828.725
# 22/1000 epoch ge_loss: 501.289 d_loss: 0.012 anomaly_score: 122859.573
# 23/1000 epoch ge_loss: 494.418 d_loss: 0.010 anomaly_score: 94475.477
# 24/1000 epoch ge_loss: 520.742 d_loss: 0.011 anomaly_score: 66748.875
# 25/1000 epoch ge_loss: 454.797 d_loss: 0.012 anomaly_score: 64976.175
# 26/1000 epoch ge_loss: 430.980 d_loss: 0.006 anomaly_score: 54214.412
# 27/1000 epoch ge_loss: 436.108 d_loss: 0.005 anomaly_score: 54152.583
# 28/1000 epoch ge_loss: 401.595 d_loss: 0.007 anomaly_score: 56247.597
# 29/1000 epoch ge_loss: 458.764 d_loss: 0.026 anomaly_score: 46973.011
# 30/1000 epoch ge_loss: 409.414 d_loss: 0.102 anomaly_score: 43873.549
# 31/1000 epoch ge_loss: 402.475 d_loss: 0.026 anomaly_score: 52806.476
# 32/1000 epoch ge_loss: 407.686 d_loss: 0.013 anomaly_score: 49878.327
# 33/1000 epoch ge_loss: 390.267 d_loss: 0.012 anomaly_score: 47303.047
# 34/1000 epoch ge_loss: 395.827 d_loss: 0.012 anomaly_score: 44183.759
# 35/1000 epoch ge_loss: 374.372 d_loss: 0.020 anomaly_score: 39319.494
# 36/1000 epoch ge_loss: 408.368 d_loss: 0.014 anomaly_score: 40116.698
# 37/1000 epoch ge_loss: 399.578 d_loss: 0.006 anomaly_score: 47258.595
# 38/1000 epoch ge_loss: 387.848 d_loss: 0.005 anomaly_score: 44155.618
# 39/1000 epoch ge_loss: 362.783 d_loss: 0.007 anomaly_score: 39830.061
# 40/1000 epoch ge_loss: 369.133 d_loss: 0.006 anomaly_score: 36296.549
# 41/1000 epoch ge_loss: 383.939 d_loss: 0.007 anomaly_score: 39172.232
# 42/1000 epoch ge_loss: 388.871 d_loss: 0.008 anomaly_score: 45277.460
# 43/1000 epoch ge_loss: 401.874 d_loss: 0.003 anomaly_score: 40835.048
# 44/1000 epoch ge_loss: 338.549 d_loss: 0.002 anomaly_score: 35677.770
# 45/1000 epoch ge_loss: 354.293 d_loss: 0.015 anomaly_score: 34338.676
# 46/1000 epoch ge_loss: 359.983 d_loss: 0.004 anomaly_score: 38435.782
# 47/1000 epoch ge_loss: 339.098 d_loss: 0.006 anomaly_score: 37131.605
# 48/1000 epoch ge_loss: 367.003 d_loss: 0.011 anomaly_score: 55014.691
# 49/1000 epoch ge_loss: 339.590 d_loss: 0.003 anomaly_score: 39628.988
# 50/1000 epoch ge_loss: 336.713 d_loss: 0.006 anomaly_score: 31022.504
# 51/1000 epoch ge_loss: 327.185 d_loss: 0.004 anomaly_score: 28765.831
# 52/1000 epoch ge_loss: 324.712 d_loss: 0.004 anomaly_score: 37021.039
# 53/1000 epoch ge_loss: 314.885 d_loss: 0.003 anomaly_score: 30125.796
# 54/1000 epoch ge_loss: 308.846 d_loss: 0.002 anomaly_score: 32643.298
# 55/1000 epoch ge_loss: 325.238 d_loss: 0.010 anomaly_score: 33905.252
# 56/1000 epoch ge_loss: 331.443 d_loss: 0.008 anomaly_score: 28575.439
# 57/1000 epoch ge_loss: 325.538 d_loss: 0.011 anomaly_score: 28770.942
# 58/1000 epoch ge_loss: 321.208 d_loss: 0.010 anomaly_score: 30476.578
# 59/1000 epoch ge_loss: 347.634 d_loss: 0.006 anomaly_score: 30924.377
# 60/1000 epoch ge_loss: 308.233 d_loss: 0.024 anomaly_score: 31084.921
# 61/1000 epoch ge_loss: 316.333 d_loss: 0.006 anomaly_score: 31178.279
# 62/1000 epoch ge_loss: 299.226 d_loss: 0.004 anomaly_score: 29637.398
# 63/1000 epoch ge_loss: 288.760 d_loss: 0.006 anomaly_score: 29515.496
# 64/1000 epoch ge_loss: 302.479 d_loss: 0.005 anomaly_score: 30837.763
# 65/1000 epoch ge_loss: 298.409 d_loss: 0.006 anomaly_score: 29749.558
# 66/1000 epoch ge_loss: 308.147 d_loss: 0.004 anomaly_score: 30072.780
# 67/1000 epoch ge_loss: 320.488 d_loss: 0.007 anomaly_score: 29367.759
# 68/1000 epoch ge_loss: 295.618 d_loss: 0.004 anomaly_score: 29630.747
# 69/1000 epoch ge_loss: 313.211 d_loss: 0.002 anomaly_score: 32751.433
# 70/1000 epoch ge_loss: 303.755 d_loss: 0.005 anomaly_score: 28861.695
# 71/1000 epoch ge_loss: 302.354 d_loss: 0.004 anomaly_score: 28415.703
# 72/1000 epoch ge_loss: 309.133 d_loss: 0.008 anomaly_score: 30444.844
# 73/1000 epoch ge_loss: 304.920 d_loss: 0.006 anomaly_score: 28231.200
# 74/1000 epoch ge_loss: 295.544 d_loss: 0.004 anomaly_score: 29651.034
# 75/1000 epoch ge_loss: 340.517 d_loss: 0.007 anomaly_score: 28757.720
# 76/1000 epoch ge_loss: 293.652 d_loss: 0.006 anomaly_score: 27147.423
# 77/1000 epoch ge_loss: 300.496 d_loss: 0.013 anomaly_score: 27083.569
# 78/1000 epoch ge_loss: 281.822 d_loss: 0.008 anomaly_score: 26432.450
# 79/1000 epoch ge_loss: 288.751 d_loss: 0.005 anomaly_score: 26697.450
# 80/1000 epoch ge_loss: 317.274 d_loss: 0.003 anomaly_score: 27565.343
# 81/1000 epoch ge_loss: 318.462 d_loss: 0.001 anomaly_score: 28622.266
# 82/1000 epoch ge_loss: 289.768 d_loss: 0.008 anomaly_score: 30211.442
# 83/1000 epoch ge_loss: 298.280 d_loss: 0.002 anomaly_score: 30367.938
# 84/1000 epoch ge_loss: 313.175 d_loss: 0.002 anomaly_score: 30439.690
# 85/1000 epoch ge_loss: 279.811 d_loss: 0.001 anomaly_score: 27052.619
# 86/1000 epoch ge_loss: 282.889 d_loss: 0.002 anomaly_score: 27990.332
# 87/1000 epoch ge_loss: 275.206 d_loss: 0.001 anomaly_score: 30850.825
# 88/1000 epoch ge_loss: 290.282 d_loss: 0.002 anomaly_score: 27769.110
# 89/1000 epoch ge_loss: 286.050 d_loss: 0.003 anomaly_score: 27388.654
# 90/1000 epoch ge_loss: 267.977 d_loss: 0.003 anomaly_score: 28551.521
# 91/1000 epoch ge_loss: 281.802 d_loss: 0.002 anomaly_score: 27527.534
# 92/1000 epoch ge_loss: 272.700 d_loss: 0.002 anomaly_score: 28666.399
# 93/1000 epoch ge_loss: 266.855 d_loss: 0.002 anomaly_score: 27787.044
# 94/1000 epoch ge_loss: 279.273 d_loss: 0.009 anomaly_score: 26334.296
# 95/1000 epoch ge_loss: 282.658 d_loss: 0.011 anomaly_score: 28193.195
# 96/1000 epoch ge_loss: 278.799 d_loss: 0.005 anomaly_score: 25779.186
# 97/1000 epoch ge_loss: 278.033 d_loss: 0.009 anomaly_score: 25643.191
# 98/1000 epoch ge_loss: 259.941 d_loss: 0.003 anomaly_score: 26071.056
# 99/1000 epoch ge_loss: 275.314 d_loss: 0.002 anomaly_score: 26260.195
# 100/1000 epoch ge_loss: 271.444 d_loss: 0.004 anomaly_score: 27420.915
# 101/1000 epoch ge_loss: 275.878 d_loss: 0.002 anomaly_score: 26262.400
# 102/1000 epoch ge_loss: 247.215 d_loss: 0.001 anomaly_score: 24736.421
# 103/1000 epoch ge_loss: 258.590 d_loss: 0.003 anomaly_score: 29846.213
# 104/1000 epoch ge_loss: 266.742 d_loss: 0.001 anomaly_score: 28083.813
# 105/1000 epoch ge_loss: 272.889 d_loss: 0.002 anomaly_score: 31335.928
# 106/1000 epoch ge_loss: 252.505 d_loss: 0.006 anomaly_score: 32908.543
# 107/1000 epoch ge_loss: 255.431 d_loss: 0.005 anomaly_score: 29804.595
# 108/1000 epoch ge_loss: 255.348 d_loss: 0.001 anomaly_score: 26422.076
# 109/1000 epoch ge_loss: 251.800 d_loss: 0.000 anomaly_score: 29724.165
# 110/1000 epoch ge_loss: 265.073 d_loss: 0.001 anomaly_score: 31031.393
# 111/1000 epoch ge_loss: 272.953 d_loss: 0.000 anomaly_score: 27329.236
# 112/1000 epoch ge_loss: 276.975 d_loss: 0.011 anomaly_score: 26254.165
# 113/1000 epoch ge_loss: 292.400 d_loss: 0.006 anomaly_score: 27947.322
# 114/1000 epoch ge_loss: 276.985 d_loss: 0.002 anomaly_score: 31333.242
# 115/1000 epoch ge_loss: 269.315 d_loss: 0.001 anomaly_score: 24921.403
# 116/1000 epoch ge_loss: 251.589 d_loss: 0.001 anomaly_score: 28979.642
# 117/1000 epoch ge_loss: 243.287 d_loss: 0.000 anomaly_score: 27334.032
# 118/1000 epoch ge_loss: 270.659 d_loss: 0.002 anomaly_score: 25630.858
# 119/1000 epoch ge_loss: 261.905 d_loss: 0.001 anomaly_score: 26229.270
# 120/1000 epoch ge_loss: 267.831 d_loss: 0.001 anomaly_score: 25006.419
# 121/1000 epoch ge_loss: 272.550 d_loss: 0.000 anomaly_score: 27024.686
# 122/1000 epoch ge_loss: 255.283 d_loss: 0.001 anomaly_score: 29614.068
# 123/1000 epoch ge_loss: 269.488 d_loss: 0.000 anomaly_score: 28744.570
# 124/1000 epoch ge_loss: 259.206 d_loss: 0.000 anomaly_score: 24218.248
# 125/1000 epoch ge_loss: 250.753 d_loss: 0.001 anomaly_score: 29731.846
# 126/1000 epoch ge_loss: 280.401 d_loss: 0.001 anomaly_score: 32003.437
# 127/1000 epoch ge_loss: 286.370 d_loss: 0.001 anomaly_score: 33095.856
# 128/1000 epoch ge_loss: 255.859 d_loss: 0.000 anomaly_score: 24326.259
# 129/1000 epoch ge_loss: 241.914 d_loss: 0.001 anomaly_score: 27871.848
# 130/1000 epoch ge_loss: 260.646 d_loss: 0.001 anomaly_score: 24949.400
# 131/1000 epoch ge_loss: 256.947 d_loss: 0.000 anomaly_score: 23251.027
# 132/1000 epoch ge_loss: 252.014 d_loss: 0.001 anomaly_score: 32809.733
# 133/1000 epoch ge_loss: 257.117 d_loss: 0.002 anomaly_score: 27548.687
# 134/1000 epoch ge_loss: 235.466 d_loss: 0.001 anomaly_score: 31408.668
# 135/1000 epoch ge_loss: 266.957 d_loss: 0.000 anomaly_score: 31356.875
# 136/1000 epoch ge_loss: 261.985 d_loss: 0.001 anomaly_score: 30430.908
# 137/1000 epoch ge_loss: 266.977 d_loss: 0.000 anomaly_score: 24782.141
# 138/1000 epoch ge_loss: 259.772 d_loss: 0.000 anomaly_score: 28144.315
# 139/1000 epoch ge_loss: 238.681 d_loss: 0.000 anomaly_score: 22690.073
# 140/1000 epoch ge_loss: 236.263 d_loss: 0.000 anomaly_score: 28823.660
# 141/1000 epoch ge_loss: 242.149 d_loss: 0.000 anomaly_score: 24942.677
# 142/1000 epoch ge_loss: 289.345 d_loss: 0.000 anomaly_score: 28838.650
# 143/1000 epoch ge_loss: 279.405 d_loss: 0.000 anomaly_score: 34743.107
# 144/1000 epoch ge_loss: 247.066 d_loss: 0.000 anomaly_score: 28118.531
# 145/1000 epoch ge_loss: 251.791 d_loss: 0.001 anomaly_score: 30123.020
# 146/1000 epoch ge_loss: 245.428 d_loss: 0.001 anomaly_score: 27740.161
# 147/1000 epoch ge_loss: 237.495 d_loss: 0.000 anomaly_score: 27430.737
# 148/1000 epoch ge_loss: 249.728 d_loss: 0.000 anomaly_score: 30345.006
# 149/1000 epoch ge_loss: 251.139 d_loss: 0.000 anomaly_score: 32163.906
# 150/1000 epoch ge_loss: 249.235 d_loss: 0.000 anomaly_score: 26950.989
# 151/1000 epoch ge_loss: 247.165 d_loss: 0.000 anomaly_score: 27577.148
# 152/1000 epoch ge_loss: 250.197 d_loss: 0.001 anomaly_score: 31409.498
# 153/1000 epoch ge_loss: 228.286 d_loss: 0.000 anomaly_score: 30357.371
# 154/1000 epoch ge_loss: 244.597 d_loss: 0.000 anomaly_score: 26186.631
# 155/1000 epoch ge_loss: 224.598 d_loss: 0.000 anomaly_score: 28325.995
# 156/1000 epoch ge_loss: 246.742 d_loss: 0.000 anomaly_score: 29640.277
# 157/1000 epoch ge_loss: 239.556 d_loss: 0.001 anomaly_score: 24883.455
# 158/1000 epoch ge_loss: 244.690 d_loss: 0.001 anomaly_score: 23568.797
# 159/1000 epoch ge_loss: 230.919 d_loss: 0.000 anomaly_score: 22884.393
# 160/1000 epoch ge_loss: 231.523 d_loss: 0.000 anomaly_score: 26612.363
# 161/1000 epoch ge_loss: 249.340 d_loss: 0.001 anomaly_score: 26924.068
# 162/1000 epoch ge_loss: 251.211 d_loss: 0.008 anomaly_score: 35294.560
# 163/1000 epoch ge_loss: 239.645 d_loss: 0.005 anomaly_score: 33362.534
# 164/1000 epoch ge_loss: 242.093 d_loss: 0.001 anomaly_score: 26512.407
# 165/1000 epoch ge_loss: 223.748 d_loss: 0.001 anomaly_score: 25883.188
# 166/1000 epoch ge_loss: 240.289 d_loss: 0.000 anomaly_score: 29419.935
# 167/1000 epoch ge_loss: 237.712 d_loss: 0.001 anomaly_score: 28402.798
# 168/1000 epoch ge_loss: 236.635 d_loss: 0.000 anomaly_score: 26978.761
# 169/1000 epoch ge_loss: 233.430 d_loss: 0.000 anomaly_score: 27060.721
# 170/1000 epoch ge_loss: 213.521 d_loss: 0.000 anomaly_score: 24939.906
# 171/1000 epoch ge_loss: 246.926 d_loss: 0.000 anomaly_score: 23865.658
# 172/1000 epoch ge_loss: 240.032 d_loss: 0.000 anomaly_score: 27229.023
# 173/1000 epoch ge_loss: 241.281 d_loss: 0.001 anomaly_score: 24705.997
# 174/1000 epoch ge_loss: 236.919 d_loss: 0.000 anomaly_score: 26643.032
# 175/1000 epoch ge_loss: 228.446 d_loss: 0.000 anomaly_score: 31046.160
# 176/1000 epoch ge_loss: 228.644 d_loss: 0.001 anomaly_score: 24479.382
# 177/1000 epoch ge_loss: 229.475 d_loss: 0.000 anomaly_score: 25150.774
# 178/1000 epoch ge_loss: 229.345 d_loss: 0.000 anomaly_score: 33187.107
# 179/1000 epoch ge_loss: 228.938 d_loss: 0.000 anomaly_score: 34458.763
# 180/1000 epoch ge_loss: 240.188 d_loss: 0.001 anomaly_score: 29998.272
# 181/1000 epoch ge_loss: 225.728 d_loss: 0.000 anomaly_score: 31634.500
# 182/1000 epoch ge_loss: 227.125 d_loss: 0.000 anomaly_score: 31255.535
# 183/1000 epoch ge_loss: 234.890 d_loss: 0.000 anomaly_score: 36402.208
# 184/1000 epoch ge_loss: 248.375 d_loss: 0.000 anomaly_score: 39346.169
# 185/1000 epoch ge_loss: 223.002 d_loss: 0.000 anomaly_score: 34389.055
# 186/1000 epoch ge_loss: 218.227 d_loss: 0.000 anomaly_score: 28673.208
# 187/1000 epoch ge_loss: 227.953 d_loss: 0.000 anomaly_score: 25774.358
# 188/1000 epoch ge_loss: 262.195 d_loss: 0.000 anomaly_score: 42060.451
# 189/1000 epoch ge_loss: 229.289 d_loss: 0.000 anomaly_score: 32653.761
# 190/1000 epoch ge_loss: 221.663 d_loss: 0.000 anomaly_score: 26859.570
# 191/1000 epoch ge_loss: 243.549 d_loss: 0.000 anomaly_score: 23213.099
# 192/1000 epoch ge_loss: 250.136 d_loss: 0.000 anomaly_score: 23802.237
# 193/1000 epoch ge_loss: 251.534 d_loss: 0.001 anomaly_score: 25689.463
# 194/1000 epoch ge_loss: 250.456 d_loss: 0.000 anomaly_score: 37322.647
# 195/1000 epoch ge_loss: 245.405 d_loss: 0.000 anomaly_score: 26264.988
# 196/1000 epoch ge_loss: 241.453 d_loss: 0.000 anomaly_score: 30287.186
# 197/1000 epoch ge_loss: 224.155 d_loss: 0.000 anomaly_score: 27807.048
# 198/1000 epoch ge_loss: 223.076 d_loss: 0.000 anomaly_score: 25380.951
# 199/1000 epoch ge_loss: 223.924 d_loss: 0.000 anomaly_score: 33926.175
# 200/1000 epoch ge_loss: 241.356 d_loss: 0.000 anomaly_score: 23858.908
# 201/1000 epoch ge_loss: 213.144 d_loss: 0.000 anomaly_score: 27329.820
# 202/1000 epoch ge_loss: 227.757 d_loss: 0.000 anomaly_score: 25602.450
# 203/1000 epoch ge_loss: 225.850 d_loss: 0.000 anomaly_score: 27636.954
# 204/1000 epoch ge_loss: 229.986 d_loss: 0.000 anomaly_score: 32195.008
# 205/1000 epoch ge_loss: 217.164 d_loss: 0.000 anomaly_score: 26442.621
# 206/1000 epoch ge_loss: 224.669 d_loss: 0.001 anomaly_score: 23318.366
# 207/1000 epoch ge_loss: 208.778 d_loss: 0.000 anomaly_score: 27551.498
# 208/1000 epoch ge_loss: 228.646 d_loss: 0.000 anomaly_score: 23502.546
# 209/1000 epoch ge_loss: 212.542 d_loss: 0.000 anomaly_score: 27572.075
# 210/1000 epoch ge_loss: 223.510 d_loss: 0.000 anomaly_score: 27997.050
# 211/1000 epoch ge_loss: 225.938 d_loss: 0.000 anomaly_score: 30127.920
# 212/1000 epoch ge_loss: 218.030 d_loss: 0.000 anomaly_score: 24852.211
# 213/1000 epoch ge_loss: 222.765 d_loss: 0.000 anomaly_score: 30534.143
# 214/1000 epoch ge_loss: 211.282 d_loss: 0.000 anomaly_score: 27759.135
# 215/1000 epoch ge_loss: 233.776 d_loss: 0.000 anomaly_score: 22823.517
# 216/1000 epoch ge_loss: 210.976 d_loss: 0.000 anomaly_score: 26081.102
# 217/1000 epoch ge_loss: 236.469 d_loss: 0.000 anomaly_score: 29098.061
# 218/1000 epoch ge_loss: 213.000 d_loss: 0.000 anomaly_score: 25065.688
# 219/1000 epoch ge_loss: 212.451 d_loss: 0.000 anomaly_score: 23888.060
# 220/1000 epoch ge_loss: 233.588 d_loss: 0.000 anomaly_score: 29908.911
# 221/1000 epoch ge_loss: 237.504 d_loss: 0.001 anomaly_score: 30362.960
# 222/1000 epoch ge_loss: 222.777 d_loss: 0.001 anomaly_score: 32597.375
# 223/1000 epoch ge_loss: 212.281 d_loss: 0.000 anomaly_score: 27270.043
# 224/1000 epoch ge_loss: 229.812 d_loss: 0.000 anomaly_score: 22414.697
# 225/1000 epoch ge_loss: 214.021 d_loss: 0.000 anomaly_score: 25350.236
# 226/1000 epoch ge_loss: 225.049 d_loss: 0.000 anomaly_score: 21471.184
# 227/1000 epoch ge_loss: 245.941 d_loss: 0.001 anomaly_score: 29453.321
# 228/1000 epoch ge_loss: 235.050 d_loss: 0.001 anomaly_score: 29190.284
# 229/1000 epoch ge_loss: 208.493 d_loss: 0.000 anomaly_score: 30584.513
# 230/1000 epoch ge_loss: 248.323 d_loss: 0.000 anomaly_score: 34571.898
# 231/1000 epoch ge_loss: 236.700 d_loss: 0.000 anomaly_score: 26272.663
# 232/1000 epoch ge_loss: 205.575 d_loss: 0.000 anomaly_score: 26280.197
# 233/1000 epoch ge_loss: 205.077 d_loss: 0.000 anomaly_score: 30332.983
# 234/1000 epoch ge_loss: 232.368 d_loss: 0.000 anomaly_score: 27783.329
# 235/1000 epoch ge_loss: 253.596 d_loss: 0.000 anomaly_score: 26452.304
# 236/1000 epoch ge_loss: 225.730 d_loss: 0.000 anomaly_score: 20801.300
# 237/1000 epoch ge_loss: 208.398 d_loss: 0.000 anomaly_score: 29430.498
# 238/1000 epoch ge_loss: 225.634 d_loss: 0.000 anomaly_score: 29229.654
# 239/1000 epoch ge_loss: 208.024 d_loss: 0.000 anomaly_score: 28911.098
# 240/1000 epoch ge_loss: 211.586 d_loss: 0.000 anomaly_score: 31498.238
# 241/1000 epoch ge_loss: 243.257 d_loss: 0.000 anomaly_score: 23560.510
# 242/1000 epoch ge_loss: 211.755 d_loss: 0.000 anomaly_score: 30894.356
# 243/1000 epoch ge_loss: 221.773 d_loss: 0.000 anomaly_score: 24573.086
# 244/1000 epoch ge_loss: 222.675 d_loss: 0.001 anomaly_score: 32171.946
# 245/1000 epoch ge_loss: 207.815 d_loss: 0.000 anomaly_score: 26586.717
# 246/1000 epoch ge_loss: 217.214 d_loss: 0.000 anomaly_score: 34864.440
# 247/1000 epoch ge_loss: 203.246 d_loss: 0.000 anomaly_score: 30443.233
# 248/1000 epoch ge_loss: 211.375 d_loss: 0.000 anomaly_score: 23165.660
# 249/1000 epoch ge_loss: 234.185 d_loss: 0.000 anomaly_score: 22770.904
# 250/1000 epoch ge_loss: 218.583 d_loss: 0.000 anomaly_score: 23951.008
# 251/1000 epoch ge_loss: 214.385 d_loss: 0.000 anomaly_score: 27408.141
# 252/1000 epoch ge_loss: 216.837 d_loss: 0.000 anomaly_score: 33922.774
# 253/1000 epoch ge_loss: 209.423 d_loss: 0.001 anomaly_score: 30748.612
# 254/1000 epoch ge_loss: 205.173 d_loss: 0.000 anomaly_score: 24142.323
# 255/1000 epoch ge_loss: 219.989 d_loss: 0.000 anomaly_score: 29254.915
# 256/1000 epoch ge_loss: 230.947 d_loss: 0.000 anomaly_score: 34395.932
# 257/1000 epoch ge_loss: 207.960 d_loss: 0.000 anomaly_score: 33332.349
# 258/1000 epoch ge_loss: 196.567 d_loss: 0.000 anomaly_score: 30824.434
# 259/1000 epoch ge_loss: 216.357 d_loss: 0.001 anomaly_score: 28995.109
# 260/1000 epoch ge_loss: 222.903 d_loss: 0.001 anomaly_score: 29569.156
# 261/1000 epoch ge_loss: 238.285 d_loss: 0.000 anomaly_score: 26803.015
# 262/1000 epoch ge_loss: 198.135 d_loss: 0.000 anomaly_score: 27018.151
# 263/1000 epoch ge_loss: 204.664 d_loss: 0.000 anomaly_score: 29881.227
# 264/1000 epoch ge_loss: 208.941 d_loss: 0.000 anomaly_score: 29250.414
# 265/1000 epoch ge_loss: 199.320 d_loss: 0.000 anomaly_score: 34462.611
# 266/1000 epoch ge_loss: 210.863 d_loss: 0.001 anomaly_score: 29699.318
# 267/1000 epoch ge_loss: 221.386 d_loss: 0.001 anomaly_score: 32709.510
# 268/1000 epoch ge_loss: 220.549 d_loss: 0.000 anomaly_score: 32542.244
# 269/1000 epoch ge_loss: 214.272 d_loss: 0.000 anomaly_score: 30150.541
# 270/1000 epoch ge_loss: 205.003 d_loss: 0.000 anomaly_score: 33935.611
# 271/1000 epoch ge_loss: 203.572 d_loss: 0.000 anomaly_score: 32117.998
# 272/1000 epoch ge_loss: 199.278 d_loss: 0.000 anomaly_score: 23094.579
# 273/1000 epoch ge_loss: 199.280 d_loss: 0.000 anomaly_score: 29333.364
# 274/1000 epoch ge_loss: 226.248 d_loss: 0.000 anomaly_score: 25092.656
# 275/1000 epoch ge_loss: 214.488 d_loss: 0.000 anomaly_score: 25280.744
# 276/1000 epoch ge_loss: 207.263 d_loss: 0.000 anomaly_score: 30408.174
# 277/1000 epoch ge_loss: 218.116 d_loss: 0.000 anomaly_score: 39315.774
# 278/1000 epoch ge_loss: 211.646 d_loss: 0.001 anomaly_score: 29544.700
# 279/1000 epoch ge_loss: 201.041 d_loss: 0.000 anomaly_score: 19973.453
# 280/1000 epoch ge_loss: 213.949 d_loss: 0.000 anomaly_score: 23397.491
# 281/1000 epoch ge_loss: 187.907 d_loss: 0.000 anomaly_score: 36623.348
# 282/1000 epoch ge_loss: 197.946 d_loss: 0.000 anomaly_score: 36299.973
# 283/1000 epoch ge_loss: 214.913 d_loss: 0.000 anomaly_score: 25403.040
# 284/1000 epoch ge_loss: 227.940 d_loss: 0.000 anomaly_score: 28180.286
# 285/1000 epoch ge_loss: 204.526 d_loss: 0.000 anomaly_score: 28671.264
# 286/1000 epoch ge_loss: 212.646 d_loss: 0.000 anomaly_score: 23358.950
# 287/1000 epoch ge_loss: 207.142 d_loss: 0.000 anomaly_score: 27131.162
# 288/1000 epoch ge_loss: 200.391 d_loss: 0.000 anomaly_score: 29508.388
# 289/1000 epoch ge_loss: 202.084 d_loss: 0.000 anomaly_score: 32461.494
# 290/1000 epoch ge_loss: 213.576 d_loss: 0.000 anomaly_score: 31240.086
# 291/1000 epoch ge_loss: 194.633 d_loss: 0.000 anomaly_score: 22507.920
# 292/1000 epoch ge_loss: 210.643 d_loss: 0.000 anomaly_score: 24005.723
# 293/1000 epoch ge_loss: 204.149 d_loss: 0.000 anomaly_score: 27863.976
# 294/1000 epoch ge_loss: 214.641 d_loss: 0.000 anomaly_score: 28854.627
# 295/1000 epoch ge_loss: 209.291 d_loss: 0.000 anomaly_score: 20721.861
# 296/1000 epoch ge_loss: 205.371 d_loss: 0.000 anomaly_score: 24166.536
# 297/1000 epoch ge_loss: 198.419 d_loss: 0.001 anomaly_score: 23643.850
# 298/1000 epoch ge_loss: 205.988 d_loss: 0.000 anomaly_score: 28443.597
# 299/1000 epoch ge_loss: 198.986 d_loss: 0.000 anomaly_score: 29294.983
# 300/1000 epoch ge_loss: 200.236 d_loss: 0.001 anomaly_score: 32431.553
# 301/1000 epoch ge_loss: 229.090 d_loss: 0.000 anomaly_score: 27260.247
# 302/1000 epoch ge_loss: 214.496 d_loss: 0.000 anomaly_score: 24018.068
# 303/1000 epoch ge_loss: 189.572 d_loss: 0.000 anomaly_score: 21996.014
# 304/1000 epoch ge_loss: 193.572 d_loss: 0.000 anomaly_score: 25652.789
# 305/1000 epoch ge_loss: 220.154 d_loss: 0.000 anomaly_score: 30114.693
# 306/1000 epoch ge_loss: 207.533 d_loss: 0.000 anomaly_score: 25883.447
# 307/1000 epoch ge_loss: 202.662 d_loss: 0.000 anomaly_score: 28305.815
# 308/1000 epoch ge_loss: 205.876 d_loss: 0.000 anomaly_score: 22550.310
# 309/1000 epoch ge_loss: 213.836 d_loss: 0.000 anomaly_score: 33771.918
# 310/1000 epoch ge_loss: 214.670 d_loss: 0.000 anomaly_score: 37292.887
# 311/1000 epoch ge_loss: 202.157 d_loss: 0.000 anomaly_score: 32413.280
# 312/1000 epoch ge_loss: 235.759 d_loss: 0.000 anomaly_score: 21264.368
# 313/1000 epoch ge_loss: 237.073 d_loss: 0.000 anomaly_score: 23664.009
# 314/1000 epoch ge_loss: 204.006 d_loss: 0.000 anomaly_score: 28469.023
# 315/1000 epoch ge_loss: 196.378 d_loss: 0.000 anomaly_score: 31218.370
# 316/1000 epoch ge_loss: 195.916 d_loss: 0.000 anomaly_score: 25602.678
# 317/1000 epoch ge_loss: 221.322 d_loss: 0.000 anomaly_score: 20208.979
# 318/1000 epoch ge_loss: 234.163 d_loss: 0.000 anomaly_score: 24403.009
# 319/1000 epoch ge_loss: 217.954 d_loss: 0.000 anomaly_score: 31432.486
# 320/1000 epoch ge_loss: 212.961 d_loss: 0.000 anomaly_score: 33282.593
# 321/1000 epoch ge_loss: 202.221 d_loss: 0.000 anomaly_score: 34692.415
# 322/1000 epoch ge_loss: 232.289 d_loss: 0.000 anomaly_score: 36936.975
# 323/1000 epoch ge_loss: 230.510 d_loss: 0.000 anomaly_score: 25494.372
# 324/1000 epoch ge_loss: 204.265 d_loss: 0.000 anomaly_score: 25104.213
# 325/1000 epoch ge_loss: 211.185 d_loss: 0.000 anomaly_score: 33662.072
# 326/1000 epoch ge_loss: 204.335 d_loss: 0.000 anomaly_score: 41231.117
# 327/1000 epoch ge_loss: 205.238 d_loss: 0.000 anomaly_score: 32259.345
# 328/1000 epoch ge_loss: 230.429 d_loss: 0.000 anomaly_score: 27595.565
# 329/1000 epoch ge_loss: 228.283 d_loss: 0.000 anomaly_score: 24401.725
# 330/1000 epoch ge_loss: 222.592 d_loss: 0.000 anomaly_score: 26751.361
# 331/1000 epoch ge_loss: 201.164 d_loss: 0.000 anomaly_score: 27354.296
# 332/1000 epoch ge_loss: 206.759 d_loss: 0.000 anomaly_score: 36428.091
# 333/1000 epoch ge_loss: 190.042 d_loss: 0.000 anomaly_score: 35301.394
# 334/1000 epoch ge_loss: 217.430 d_loss: 0.000 anomaly_score: 30085.129
# 335/1000 epoch ge_loss: 210.334 d_loss: 0.000 anomaly_score: 29271.162
# 336/1000 epoch ge_loss: 203.252 d_loss: 0.000 anomaly_score: 23221.079
# 337/1000 epoch ge_loss: 189.876 d_loss: 0.000 anomaly_score: 26952.759
# 338/1000 epoch ge_loss: 211.734 d_loss: 0.000 anomaly_score: 28027.895
# 339/1000 epoch ge_loss: 221.482 d_loss: 0.001 anomaly_score: 27927.069
# 340/1000 epoch ge_loss: 218.225 d_loss: 0.000 anomaly_score: 28303.841
# 341/1000 epoch ge_loss: 190.568 d_loss: 0.000 anomaly_score: 31752.337
# 342/1000 epoch ge_loss: 205.651 d_loss: 0.000 anomaly_score: 22224.851
# 343/1000 epoch ge_loss: 207.007 d_loss: 0.000 anomaly_score: 28363.423
# 344/1000 epoch ge_loss: 188.609 d_loss: 0.000 anomaly_score: 30709.938
# 345/1000 epoch ge_loss: 189.570 d_loss: 0.000 anomaly_score: 27043.736
# 346/1000 epoch ge_loss: 201.627 d_loss: 0.000 anomaly_score: 26997.291
# 347/1000 epoch ge_loss: 204.729 d_loss: 0.000 anomaly_score: 28023.990
# 348/1000 epoch ge_loss: 192.134 d_loss: 0.000 anomaly_score: 24580.667
# 349/1000 epoch ge_loss: 197.806 d_loss: 0.000 anomaly_score: 24837.427
# 350/1000 epoch ge_loss: 202.369 d_loss: 0.000 anomaly_score: 30723.992
# 351/1000 epoch ge_loss: 203.431 d_loss: 0.000 anomaly_score: 31096.202
# 352/1000 epoch ge_loss: 221.421 d_loss: 0.001 anomaly_score: 26328.693
# 353/1000 epoch ge_loss: 203.003 d_loss: 0.000 anomaly_score: 23224.910
# 354/1000 epoch ge_loss: 220.302 d_loss: 0.000 anomaly_score: 29770.056
# 355/1000 epoch ge_loss: 193.495 d_loss: 0.000 anomaly_score: 33306.002
# 356/1000 epoch ge_loss: 198.670 d_loss: 0.000 anomaly_score: 30628.849
# 357/1000 epoch ge_loss: 183.087 d_loss: 0.000 anomaly_score: 31608.712
# 358/1000 epoch ge_loss: 185.814 d_loss: 0.000 anomaly_score: 28846.784
# 359/1000 epoch ge_loss: 202.812 d_loss: 0.001 anomaly_score: 22945.025
# 360/1000 epoch ge_loss: 205.784 d_loss: 0.000 anomaly_score: 29297.662
# 361/1000 epoch ge_loss: 192.745 d_loss: 0.000 anomaly_score: 32011.066
# 362/1000 epoch ge_loss: 191.046 d_loss: 0.000 anomaly_score: 33343.201
# 363/1000 epoch ge_loss: 186.073 d_loss: 0.000 anomaly_score: 36284.049
# 364/1000 epoch ge_loss: 196.963 d_loss: 0.000 anomaly_score: 32159.125
# 365/1000 epoch ge_loss: 198.328 d_loss: 0.000 anomaly_score: 27459.366
# 366/1000 epoch ge_loss: 201.409 d_loss: 0.000 anomaly_score: 23918.518
# 367/1000 epoch ge_loss: 191.492 d_loss: 0.000 anomaly_score: 31184.134
# 368/1000 epoch ge_loss: 184.911 d_loss: 0.000 anomaly_score: 26855.547
# 369/1000 epoch ge_loss: 196.443 d_loss: 0.000 anomaly_score: 28622.971
# 370/1000 epoch ge_loss: 216.591 d_loss: 0.000 anomaly_score: 29621.818
# 371/1000 epoch ge_loss: 190.427 d_loss: 0.000 anomaly_score: 35203.192
# 372/1000 epoch ge_loss: 219.062 d_loss: 0.000 anomaly_score: 20452.035
# 373/1000 epoch ge_loss: 183.598 d_loss: 0.000 anomaly_score: 23446.637
# 374/1000 epoch ge_loss: 185.659 d_loss: 0.000 anomaly_score: 25944.501
# 375/1000 epoch ge_loss: 189.847 d_loss: 0.000 anomaly_score: 28536.907
# 376/1000 epoch ge_loss: 189.352 d_loss: 0.000 anomaly_score: 28962.513
# 377/1000 epoch ge_loss: 190.098 d_loss: 0.000 anomaly_score: 32129.412
# 378/1000 epoch ge_loss: 181.588 d_loss: 0.000 anomaly_score: 27849.231
# 379/1000 epoch ge_loss: 219.963 d_loss: 0.000 anomaly_score: 28641.143
# 380/1000 epoch ge_loss: 191.101 d_loss: 0.000 anomaly_score: 25881.283
# 381/1000 epoch ge_loss: 184.213 d_loss: 0.000 anomaly_score: 22045.058
# 382/1000 epoch ge_loss: 199.995 d_loss: 0.000 anomaly_score: 27651.332
# 383/1000 epoch ge_loss: 195.028 d_loss: 0.000 anomaly_score: 34342.552
# 384/1000 epoch ge_loss: 215.937 d_loss: 0.000 anomaly_score: 31715.526
# 385/1000 epoch ge_loss: 212.828 d_loss: 0.000 anomaly_score: 24126.242
# 386/1000 epoch ge_loss: 196.601 d_loss: 0.000 anomaly_score: 27630.045
# 387/1000 epoch ge_loss: 231.141 d_loss: 0.000 anomaly_score: 36175.223
# 388/1000 epoch ge_loss: 195.887 d_loss: 0.000 anomaly_score: 32378.871
# 389/1000 epoch ge_loss: 211.612 d_loss: 0.000 anomaly_score: 36767.575
# 390/1000 epoch ge_loss: 201.745 d_loss: 0.000 anomaly_score: 34979.031
# 391/1000 epoch ge_loss: 193.948 d_loss: 0.000 anomaly_score: 28447.338
# 392/1000 epoch ge_loss: 196.919 d_loss: 0.000 anomaly_score: 28999.233
# 393/1000 epoch ge_loss: 215.668 d_loss: 0.000 anomaly_score: 33046.820
# 394/1000 epoch ge_loss: 193.032 d_loss: 0.000 anomaly_score: 33036.818
# 395/1000 epoch ge_loss: 194.412 d_loss: 0.000 anomaly_score: 27437.060
# 396/1000 epoch ge_loss: 197.959 d_loss: 0.000 anomaly_score: 23058.049
# 397/1000 epoch ge_loss: 194.090 d_loss: 0.000 anomaly_score: 30754.579
# 398/1000 epoch ge_loss: 199.986 d_loss: 0.000 anomaly_score: 31656.995
# 399/1000 epoch ge_loss: 196.143 d_loss: 0.000 anomaly_score: 18514.089
# 400/1000 epoch ge_loss: 199.612 d_loss: 0.000 anomaly_score: 23269.384
# 401/1000 epoch ge_loss: 188.996 d_loss: 0.000 anomaly_score: 29159.947
# 402/1000 epoch ge_loss: 183.532 d_loss: 0.000 anomaly_score: 34166.877
# 403/1000 epoch ge_loss: 234.518 d_loss: 0.000 anomaly_score: 32069.171
# 404/1000 epoch ge_loss: 196.286 d_loss: 0.000 anomaly_score: 39538.741
# 405/1000 epoch ge_loss: 175.156 d_loss: 0.000 anomaly_score: 23035.506
# 406/1000 epoch ge_loss: 198.425 d_loss: 0.000 anomaly_score: 24044.289
# 407/1000 epoch ge_loss: 183.328 d_loss: 0.000 anomaly_score: 28274.666
# 408/1000 epoch ge_loss: 188.285 d_loss: 0.000 anomaly_score: 30704.932
# 409/1000 epoch ge_loss: 196.666 d_loss: 0.000 anomaly_score: 32646.837
# 410/1000 epoch ge_loss: 207.480 d_loss: 0.000 anomaly_score: 31465.031
# 411/1000 epoch ge_loss: 182.444 d_loss: 0.000 anomaly_score: 32620.542
# 412/1000 epoch ge_loss: 196.726 d_loss: 0.000 anomaly_score: 30565.513
# 413/1000 epoch ge_loss: 198.760 d_loss: 0.000 anomaly_score: 28252.310
# 414/1000 epoch ge_loss: 215.674 d_loss: 0.001 anomaly_score: 30215.986
# 415/1000 epoch ge_loss: 213.688 d_loss: 0.001 anomaly_score: 34414.559
# 416/1000 epoch ge_loss: 176.497 d_loss: 0.000 anomaly_score: 29452.355
# 417/1000 epoch ge_loss: 175.041 d_loss: 0.000 anomaly_score: 29745.934
# 418/1000 epoch ge_loss: 186.000 d_loss: 0.000 anomaly_score: 36451.214
# 419/1000 epoch ge_loss: 177.217 d_loss: 0.000 anomaly_score: 36467.865
# 420/1000 epoch ge_loss: 196.425 d_loss: 0.000 anomaly_score: 30229.022
# 421/1000 epoch ge_loss: 201.794 d_loss: 0.000 anomaly_score: 30542.056
# 422/1000 epoch ge_loss: 180.229 d_loss: 0.000 anomaly_score: 32409.068
# 423/1000 epoch ge_loss: 175.209 d_loss: 0.000 anomaly_score: 29880.295
# 424/1000 epoch ge_loss: 207.734 d_loss: 0.000 anomaly_score: 30033.656
# 425/1000 epoch ge_loss: 197.762 d_loss: 0.000 anomaly_score: 38635.235
# 426/1000 epoch ge_loss: 181.083 d_loss: 0.000 anomaly_score: 30908.485
# 427/1000 epoch ge_loss: 190.320 d_loss: 0.000 anomaly_score: 33687.664
# 428/1000 epoch ge_loss: 197.094 d_loss: 0.000 anomaly_score: 32555.680
# 429/1000 epoch ge_loss: 190.359 d_loss: 0.000 anomaly_score: 32486.780
# 430/1000 epoch ge_loss: 179.135 d_loss: 0.000 anomaly_score: 30097.088
# 431/1000 epoch ge_loss: 186.624 d_loss: 0.001 anomaly_score: 26743.389
# 432/1000 epoch ge_loss: 204.903 d_loss: 0.001 anomaly_score: 26711.304
# 433/1000 epoch ge_loss: 179.133 d_loss: 0.000 anomaly_score: 32370.992
# 434/1000 epoch ge_loss: 187.669 d_loss: 0.000 anomaly_score: 31534.142
# 435/1000 epoch ge_loss: 179.965 d_loss: 0.000 anomaly_score: 31972.874
# 436/1000 epoch ge_loss: 204.860 d_loss: 0.000 anomaly_score: 28628.166
# 437/1000 epoch ge_loss: 184.355 d_loss: 0.000 anomaly_score: 24834.884
# 438/1000 epoch ge_loss: 179.892 d_loss: 0.000 anomaly_score: 27753.231
# 439/1000 epoch ge_loss: 188.096 d_loss: 0.000 anomaly_score: 31151.711
# 440/1000 epoch ge_loss: 207.926 d_loss: 0.000 anomaly_score: 28539.363
# 441/1000 epoch ge_loss: 186.807 d_loss: 0.000 anomaly_score: 24347.505
# 442/1000 epoch ge_loss: 176.676 d_loss: 0.000 anomaly_score: 26532.517
# 443/1000 epoch ge_loss: 187.474 d_loss: 0.000 anomaly_score: 25655.051
# 444/1000 epoch ge_loss: 216.120 d_loss: 0.000 anomaly_score: 27050.638
# 445/1000 epoch ge_loss: 179.317 d_loss: 0.000 anomaly_score: 28394.836
# 446/1000 epoch ge_loss: 195.209 d_loss: 0.000 anomaly_score: 30796.680
# 447/1000 epoch ge_loss: 189.860 d_loss: 0.000 anomaly_score: 28512.498
# 448/1000 epoch ge_loss: 190.271 d_loss: 0.000 anomaly_score: 32728.524
# 449/1000 epoch ge_loss: 203.292 d_loss: 0.000 anomaly_score: 34923.485
# 450/1000 epoch ge_loss: 213.031 d_loss: 0.000 anomaly_score: 30889.636
# 451/1000 epoch ge_loss: 193.068 d_loss: 0.000 anomaly_score: 30839.255
# 452/1000 epoch ge_loss: 198.299 d_loss: 0.000 anomaly_score: 33737.895
# 453/1000 epoch ge_loss: 186.431 d_loss: 0.001 anomaly_score: 28901.616
# 454/1000 epoch ge_loss: 206.608 d_loss: 0.001 anomaly_score: 29616.870
# 455/1000 epoch ge_loss: 204.055 d_loss: 0.000 anomaly_score: 36645.801
# 456/1000 epoch ge_loss: 189.932 d_loss: 0.000 anomaly_score: 32338.854
# 457/1000 epoch ge_loss: 186.761 d_loss: 0.000 anomaly_score: 23088.209
# 458/1000 epoch ge_loss: 176.471 d_loss: 0.000 anomaly_score: 25038.047
# 459/1000 epoch ge_loss: 174.428 d_loss: 0.000 anomaly_score: 32924.418
# 460/1000 epoch ge_loss: 203.280 d_loss: 0.000 anomaly_score: 33063.692
# 461/1000 epoch ge_loss: 189.486 d_loss: 0.001 anomaly_score: 34888.797
# 462/1000 epoch ge_loss: 211.026 d_loss: 0.000 anomaly_score: 32159.395
# 463/1000 epoch ge_loss: 183.974 d_loss: 0.000 anomaly_score: 32456.012
# 464/1000 epoch ge_loss: 183.082 d_loss: 0.000 anomaly_score: 35638.472
# 465/1000 epoch ge_loss: 178.336 d_loss: 0.000 anomaly_score: 31336.096
# 466/1000 epoch ge_loss: 214.545 d_loss: 0.000 anomaly_score: 28712.135
# 467/1000 epoch ge_loss: 184.519 d_loss: 0.000 anomaly_score: 32866.490
# 468/1000 epoch ge_loss: 180.780 d_loss: 0.000 anomaly_score: 26890.078
# 469/1000 epoch ge_loss: 223.562 d_loss: 0.000 anomaly_score: 22107.196
# 470/1000 epoch ge_loss: 190.002 d_loss: 0.000 anomaly_score: 28798.820
# 471/1000 epoch ge_loss: 188.176 d_loss: 0.000 anomaly_score: 29811.836
# 472/1000 epoch ge_loss: 187.724 d_loss: 0.000 anomaly_score: 30527.895
# 473/1000 epoch ge_loss: 206.030 d_loss: 0.000 anomaly_score: 31258.643
# 474/1000 epoch ge_loss: 197.687 d_loss: 0.000 anomaly_score: 25518.165
# 475/1000 epoch ge_loss: 172.865 d_loss: 0.000 anomaly_score: 25084.211
# 476/1000 epoch ge_loss: 178.910 d_loss: 0.000 anomaly_score: 27442.803
# 477/1000 epoch ge_loss: 194.899 d_loss: 0.000 anomaly_score: 31116.586
# 478/1000 epoch ge_loss: 200.350 d_loss: 0.000 anomaly_score: 35193.001
# 479/1000 epoch ge_loss: 194.757 d_loss: 0.000 anomaly_score: 27041.278
# 480/1000 epoch ge_loss: 174.448 d_loss: 0.000 anomaly_score: 33763.219
# 481/1000 epoch ge_loss: 174.051 d_loss: 0.000 anomaly_score: 23601.438
# 482/1000 epoch ge_loss: 173.953 d_loss: 0.000 anomaly_score: 24603.424
# 483/1000 epoch ge_loss: 183.468 d_loss: 0.000 anomaly_score: 24290.577
# 484/1000 epoch ge_loss: 182.766 d_loss: 0.000 anomaly_score: 31196.902
# 485/1000 epoch ge_loss: 175.089 d_loss: 0.000 anomaly_score: 31963.926
# 486/1000 epoch ge_loss: 199.922 d_loss: 0.000 anomaly_score: 26735.049
# 487/1000 epoch ge_loss: 186.769 d_loss: 0.000 anomaly_score: 27933.120
# 488/1000 epoch ge_loss: 196.434 d_loss: 0.000 anomaly_score: 28035.804
# 489/1000 epoch ge_loss: 178.677 d_loss: 0.000 anomaly_score: 29553.337
# 490/1000 epoch ge_loss: 185.200 d_loss: 0.000 anomaly_score: 24353.294
# 491/1000 epoch ge_loss: 190.879 d_loss: 0.000 anomaly_score: 34926.188
# 492/1000 epoch ge_loss: 206.362 d_loss: 0.000 anomaly_score: 28264.273
# 493/1000 epoch ge_loss: 187.582 d_loss: 0.000 anomaly_score: 21779.577
# 494/1000 epoch ge_loss: 184.870 d_loss: 0.000 anomaly_score: 29501.688
# 495/1000 epoch ge_loss: 190.684 d_loss: 0.000 anomaly_score: 28178.801
# 496/1000 epoch ge_loss: 192.178 d_loss: 0.000 anomaly_score: 26746.454
# 497/1000 epoch ge_loss: 209.720 d_loss: 0.000 anomaly_score: 28908.562
# 498/1000 epoch ge_loss: 176.315 d_loss: 0.000 anomaly_score: 29512.261
# 499/1000 epoch ge_loss: 200.105 d_loss: 0.000 anomaly_score: 29317.091
# 500/1000 epoch ge_loss: 202.778 d_loss: 0.000 anomaly_score: 25222.440
# 501/1000 epoch ge_loss: 188.711 d_loss: 0.000 anomaly_score: 28556.578
# 502/1000 epoch ge_loss: 183.436 d_loss: 0.000 anomaly_score: 32330.855
# 503/1000 epoch ge_loss: 189.235 d_loss: 0.000 anomaly_score: 24800.322
# 504/1000 epoch ge_loss: 175.529 d_loss: 0.000 anomaly_score: 21556.129
# 505/1000 epoch ge_loss: 179.581 d_loss: 0.000 anomaly_score: 28033.495
# 506/1000 epoch ge_loss: 177.857 d_loss: 0.000 anomaly_score: 28252.689
# 507/1000 epoch ge_loss: 207.127 d_loss: 0.000 anomaly_score: 29119.921
# 508/1000 epoch ge_loss: 192.325 d_loss: 0.000 anomaly_score: 30093.819
# 509/1000 epoch ge_loss: 169.535 d_loss: 0.000 anomaly_score: 33693.316
# 510/1000 epoch ge_loss: 203.264 d_loss: 0.000 anomaly_score: 29072.994
# 511/1000 epoch ge_loss: 183.119 d_loss: 0.000 anomaly_score: 27860.030
# 512/1000 epoch ge_loss: 190.898 d_loss: 0.010 anomaly_score: 34025.484
# 513/1000 epoch ge_loss: 192.927 d_loss: 0.001 anomaly_score: 33838.053
# 514/1000 epoch ge_loss: 176.951 d_loss: 0.007 anomaly_score: 31368.395
# 515/1000 epoch ge_loss: 187.363 d_loss: 0.000 anomaly_score: 23911.930
# 516/1000 epoch ge_loss: 186.557 d_loss: 0.000 anomaly_score: 24300.814
# 517/1000 epoch ge_loss: 177.808 d_loss: 0.000 anomaly_score: 26835.508
# 518/1000 epoch ge_loss: 177.337 d_loss: 0.000 anomaly_score: 34744.018
# 519/1000 epoch ge_loss: 188.051 d_loss: 0.001 anomaly_score: 28954.297
# 520/1000 epoch ge_loss: 177.074 d_loss: 0.001 anomaly_score: 27289.343
# 521/1000 epoch ge_loss: 200.997 d_loss: 0.000 anomaly_score: 30994.748
# 522/1000 epoch ge_loss: 191.595 d_loss: 0.000 anomaly_score: 35951.540
# 523/1000 epoch ge_loss: 182.117 d_loss: 0.000 anomaly_score: 28947.476
# 524/1000 epoch ge_loss: 176.040 d_loss: 0.000 anomaly_score: 29504.693
# 525/1000 epoch ge_loss: 168.374 d_loss: 0.000 anomaly_score: 28684.356
# 526/1000 epoch ge_loss: 175.883 d_loss: 0.000 anomaly_score: 29583.466
# 527/1000 epoch ge_loss: 175.015 d_loss: 0.000 anomaly_score: 32978.818
# 528/1000 epoch ge_loss: 170.693 d_loss: 0.001 anomaly_score: 25034.487
# 529/1000 epoch ge_loss: 185.824 d_loss: 0.000 anomaly_score: 29196.600
# 530/1000 epoch ge_loss: 197.129 d_loss: 0.001 anomaly_score: 29546.667
# 531/1000 epoch ge_loss: 174.441 d_loss: 0.001 anomaly_score: 28424.330
# 532/1000 epoch ge_loss: 165.611 d_loss: 0.000 anomaly_score: 26098.114
# 533/1000 epoch ge_loss: 188.532 d_loss: 0.000 anomaly_score: 31698.984
# 534/1000 epoch ge_loss: 181.347 d_loss: 0.000 anomaly_score: 36921.924
# 535/1000 epoch ge_loss: 192.301 d_loss: 0.000 anomaly_score: 32940.587
# 536/1000 epoch ge_loss: 173.847 d_loss: 0.000 anomaly_score: 28630.680
# 537/1000 epoch ge_loss: 182.504 d_loss: 0.000 anomaly_score: 25491.732
# 538/1000 epoch ge_loss: 173.091 d_loss: 0.000 anomaly_score: 32442.855
# 539/1000 epoch ge_loss: 186.237 d_loss: 0.000 anomaly_score: 29904.099
# 540/1000 epoch ge_loss: 178.967 d_loss: 0.000 anomaly_score: 24357.401
# 541/1000 epoch ge_loss: 200.570 d_loss: 0.000 anomaly_score: 21827.107
# 542/1000 epoch ge_loss: 188.638 d_loss: 0.000 anomaly_score: 24060.825
# 543/1000 epoch ge_loss: 193.504 d_loss: 0.000 anomaly_score: 26297.316
# 544/1000 epoch ge_loss: 191.448 d_loss: 0.000 anomaly_score: 32329.153
# 545/1000 epoch ge_loss: 197.505 d_loss: 0.000 anomaly_score: 25812.748
# 546/1000 epoch ge_loss: 178.681 d_loss: 0.000 anomaly_score: 22160.035
# 547/1000 epoch ge_loss: 196.928 d_loss: 0.000 anomaly_score: 27054.824
# 548/1000 epoch ge_loss: 180.590 d_loss: 0.000 anomaly_score: 25839.950
# 549/1000 epoch ge_loss: 181.342 d_loss: 0.000 anomaly_score: 21868.214
# 550/1000 epoch ge_loss: 173.373 d_loss: 0.000 anomaly_score: 25818.815
# 551/1000 epoch ge_loss: 188.068 d_loss: 0.000 anomaly_score: 29346.652
# 552/1000 epoch ge_loss: 194.229 d_loss: 0.000 anomaly_score: 26602.169
# 553/1000 epoch ge_loss: 186.621 d_loss: 0.000 anomaly_score: 34692.865
# 554/1000 epoch ge_loss: 169.688 d_loss: 0.000 anomaly_score: 31754.949
# 555/1000 epoch ge_loss: 169.459 d_loss: 0.000 anomaly_score: 24253.252
# 556/1000 epoch ge_loss: 186.049 d_loss: 0.001 anomaly_score: 33789.115
# 557/1000 epoch ge_loss: 173.381 d_loss: 0.001 anomaly_score: 36997.520
# 558/1000 epoch ge_loss: 178.357 d_loss: 0.000 anomaly_score: 32668.442
# 559/1000 epoch ge_loss: 170.311 d_loss: 0.000 anomaly_score: 28341.604
# 560/1000 epoch ge_loss: 176.329 d_loss: 0.000 anomaly_score: 23702.420
# 561/1000 epoch ge_loss: 165.227 d_loss: 0.000 anomaly_score: 26119.913
# 562/1000 epoch ge_loss: 176.923 d_loss: 0.000 anomaly_score: 31112.235
# 563/1000 epoch ge_loss: 177.330 d_loss: 0.000 anomaly_score: 28218.191
# 564/1000 epoch ge_loss: 180.228 d_loss: 0.000 anomaly_score: 26611.395
# 565/1000 epoch ge_loss: 180.135 d_loss: 0.000 anomaly_score: 28498.701
# 566/1000 epoch ge_loss: 183.463 d_loss: 0.000 anomaly_score: 34363.070
# 567/1000 epoch ge_loss: 169.179 d_loss: 0.000 anomaly_score: 40548.914
# 568/1000 epoch ge_loss: 191.220 d_loss: 0.000 anomaly_score: 36857.372
# 569/1000 epoch ge_loss: 167.621 d_loss: 0.000 anomaly_score: 34322.245
# 570/1000 epoch ge_loss: 168.037 d_loss: 0.000 anomaly_score: 27023.173
# 571/1000 epoch ge_loss: 195.427 d_loss: 0.000 anomaly_score: 25618.593
# 572/1000 epoch ge_loss: 178.822 d_loss: 0.000 anomaly_score: 24759.575
# 573/1000 epoch ge_loss: 193.248 d_loss: 0.000 anomaly_score: 27369.959
# 574/1000 epoch ge_loss: 172.481 d_loss: 0.000 anomaly_score: 29709.673
# 575/1000 epoch ge_loss: 174.363 d_loss: 0.000 anomaly_score: 28504.461
# 576/1000 epoch ge_loss: 164.696 d_loss: 0.000 anomaly_score: 25784.438
# 577/1000 epoch ge_loss: 188.239 d_loss: 0.000 anomaly_score: 25241.758
# 578/1000 epoch ge_loss: 174.085 d_loss: 0.000 anomaly_score: 32135.302
# 579/1000 epoch ge_loss: 181.807 d_loss: 0.000 anomaly_score: 27699.620
# 580/1000 epoch ge_loss: 171.109 d_loss: 0.001 anomaly_score: 27843.836
# 581/1000 epoch ge_loss: 163.716 d_loss: 0.000 anomaly_score: 25278.494
# 582/1000 epoch ge_loss: 169.735 d_loss: 0.000 anomaly_score: 26637.491
# 583/1000 epoch ge_loss: 160.211 d_loss: 0.000 anomaly_score: 30958.748
# 584/1000 epoch ge_loss: 172.756 d_loss: 0.000 anomaly_score: 27703.309
# 585/1000 epoch ge_loss: 192.903 d_loss: 0.000 anomaly_score: 28220.369
# 586/1000 epoch ge_loss: 190.327 d_loss: 0.000 anomaly_score: 35198.230
# 587/1000 epoch ge_loss: 172.451 d_loss: 0.000 anomaly_score: 29179.345
# 588/1000 epoch ge_loss: 181.520 d_loss: 0.000 anomaly_score: 28549.618
# 589/1000 epoch ge_loss: 181.918 d_loss: 0.000 anomaly_score: 32532.127
# 590/1000 epoch ge_loss: 165.491 d_loss: 0.000 anomaly_score: 34744.082
# 591/1000 epoch ge_loss: 169.732 d_loss: 0.000 anomaly_score: 34156.293
# 592/1000 epoch ge_loss: 193.140 d_loss: 0.002 anomaly_score: 34149.268
# 593/1000 epoch ge_loss: 200.844 d_loss: 0.002 anomaly_score: 38991.294
# 594/1000 epoch ge_loss: 169.561 d_loss: 0.000 anomaly_score: 37552.916
# 595/1000 epoch ge_loss: 199.547 d_loss: 0.000 anomaly_score: 32194.216
# 596/1000 epoch ge_loss: 172.027 d_loss: 0.000 anomaly_score: 27545.568
# 597/1000 epoch ge_loss: 176.830 d_loss: 0.004 anomaly_score: 23782.596
# 598/1000 epoch ge_loss: 171.828 d_loss: 0.001 anomaly_score: 28290.343
# 599/1000 epoch ge_loss: 182.043 d_loss: 0.000 anomaly_score: 27389.876
# 600/1000 epoch ge_loss: 191.395 d_loss: 0.001 anomaly_score: 23295.618
# 601/1000 epoch ge_loss: 174.227 d_loss: 0.000 anomaly_score: 25246.826
# 602/1000 epoch ge_loss: 170.300 d_loss: 0.000 anomaly_score: 26068.763
# 603/1000 epoch ge_loss: 194.320 d_loss: 0.000 anomaly_score: 30784.562
# 604/1000 epoch ge_loss: 175.641 d_loss: 0.000 anomaly_score: 34891.213
# 605/1000 epoch ge_loss: 190.594 d_loss: 0.000 anomaly_score: 33517.767
# 606/1000 epoch ge_loss: 204.421 d_loss: 0.000 anomaly_score: 31305.283
# 607/1000 epoch ge_loss: 171.584 d_loss: 0.000 anomaly_score: 27959.049
# 608/1000 epoch ge_loss: 171.892 d_loss: 0.000 anomaly_score: 31454.909
# 609/1000 epoch ge_loss: 175.203 d_loss: 0.000 anomaly_score: 29778.631
# 610/1000 epoch ge_loss: 179.817 d_loss: 0.000 anomaly_score: 31025.558
# 611/1000 epoch ge_loss: 169.844 d_loss: 0.000 anomaly_score: 24856.246
# 612/1000 epoch ge_loss: 175.550 d_loss: 0.000 anomaly_score: 30021.388
# 613/1000 epoch ge_loss: 166.202 d_loss: 0.000 anomaly_score: 32577.632
# 614/1000 epoch ge_loss: 159.265 d_loss: 0.000 anomaly_score: 30303.471
# 615/1000 epoch ge_loss: 156.966 d_loss: 0.000 anomaly_score: 29734.846
# 616/1000 epoch ge_loss: 162.712 d_loss: 0.000 anomaly_score: 32849.374
# 617/1000 epoch ge_loss: 167.719 d_loss: 0.000 anomaly_score: 26824.516
# 618/1000 epoch ge_loss: 179.277 d_loss: 0.000 anomaly_score: 29385.406
# 619/1000 epoch ge_loss: 182.242 d_loss: 0.000 anomaly_score: 29514.595
# 620/1000 epoch ge_loss: 182.969 d_loss: 0.000 anomaly_score: 28840.027
# 621/1000 epoch ge_loss: 168.848 d_loss: 0.000 anomaly_score: 30676.164
# 622/1000 epoch ge_loss: 175.602 d_loss: 0.000 anomaly_score: 33975.147
# 623/1000 epoch ge_loss: 166.674 d_loss: 0.000 anomaly_score: 34471.430
# 624/1000 epoch ge_loss: 169.871 d_loss: 0.000 anomaly_score: 25781.060
# 625/1000 epoch ge_loss: 168.743 d_loss: 0.000 anomaly_score: 25277.276
# 626/1000 epoch ge_loss: 187.685 d_loss: 0.001 anomaly_score: 29923.940
# 627/1000 epoch ge_loss: 169.246 d_loss: 0.000 anomaly_score: 28644.389
# 628/1000 epoch ge_loss: 189.331 d_loss: 0.000 anomaly_score: 25684.848
# 629/1000 epoch ge_loss: 186.112 d_loss: 0.000 anomaly_score: 27900.437
# 630/1000 epoch ge_loss: 179.008 d_loss: 0.000 anomaly_score: 30092.612
# 631/1000 epoch ge_loss: 185.270 d_loss: 0.000 anomaly_score: 29719.470
# 632/1000 epoch ge_loss: 177.866 d_loss: 0.000 anomaly_score: 32492.921
# 633/1000 epoch ge_loss: 193.898 d_loss: 0.000 anomaly_score: 32824.362
# 634/1000 epoch ge_loss: 166.571 d_loss: 0.000 anomaly_score: 24539.057
# 635/1000 epoch ge_loss: 176.371 d_loss: 0.000 anomaly_score: 29461.965
# 636/1000 epoch ge_loss: 200.128 d_loss: 0.000 anomaly_score: 31178.336
# 637/1000 epoch ge_loss: 169.404 d_loss: 0.000 anomaly_score: 36585.812
# 638/1000 epoch ge_loss: 188.496 d_loss: 0.000 anomaly_score: 33713.723
# 639/1000 epoch ge_loss: 175.689 d_loss: 0.000 anomaly_score: 36049.864
# 640/1000 epoch ge_loss: 168.587 d_loss: 0.000 anomaly_score: 37516.758
# 641/1000 epoch ge_loss: 172.710 d_loss: 0.000 anomaly_score: 30801.656
# 642/1000 epoch ge_loss: 164.145 d_loss: 0.000 anomaly_score: 28154.577
# 643/1000 epoch ge_loss: 176.011 d_loss: 0.001 anomaly_score: 29261.548
# 644/1000 epoch ge_loss: 173.390 d_loss: 0.000 anomaly_score: 31026.551
# 645/1000 epoch ge_loss: 192.648 d_loss: 0.000 anomaly_score: 33082.387
# 646/1000 epoch ge_loss: 186.254 d_loss: 0.000 anomaly_score: 24986.127
# 647/1000 epoch ge_loss: 177.756 d_loss: 0.000 anomaly_score: 25551.486
# 648/1000 epoch ge_loss: 171.158 d_loss: 0.000 anomaly_score: 28232.572
# 649/1000 epoch ge_loss: 178.261 d_loss: 0.000 anomaly_score: 31683.448
# 650/1000 epoch ge_loss: 175.975 d_loss: 0.000 anomaly_score: 30539.788
# 651/1000 epoch ge_loss: 168.035 d_loss: 0.000 anomaly_score: 27134.888
# 652/1000 epoch ge_loss: 180.724 d_loss: 0.000 anomaly_score: 32780.372
# 653/1000 epoch ge_loss: 160.753 d_loss: 0.000 anomaly_score: 32462.544
# 654/1000 epoch ge_loss: 166.303 d_loss: 0.000 anomaly_score: 34923.348
# 655/1000 epoch ge_loss: 161.827 d_loss: 0.000 anomaly_score: 31475.420
# 656/1000 epoch ge_loss: 167.087 d_loss: 0.000 anomaly_score: 29722.073
# 657/1000 epoch ge_loss: 190.942 d_loss: 0.000 anomaly_score: 30066.265
# 658/1000 epoch ge_loss: 164.537 d_loss: 0.000 anomaly_score: 24622.837
# 659/1000 epoch ge_loss: 217.630 d_loss: 0.000 anomaly_score: 26713.346
# 660/1000 epoch ge_loss: 183.572 d_loss: 0.000 anomaly_score: 29322.427
# 661/1000 epoch ge_loss: 165.781 d_loss: 0.000 anomaly_score: 25987.818
# 662/1000 epoch ge_loss: 168.195 d_loss: 0.000 anomaly_score: 26720.829
# 663/1000 epoch ge_loss: 172.435 d_loss: 0.000 anomaly_score: 22077.814
# 664/1000 epoch ge_loss: 193.558 d_loss: 0.000 anomaly_score: 31592.275
# 665/1000 epoch ge_loss: 186.336 d_loss: 0.003 anomaly_score: 30608.058
# 666/1000 epoch ge_loss: 162.530 d_loss: 0.002 anomaly_score: 26536.477
# 667/1000 epoch ge_loss: 166.521 d_loss: 0.001 anomaly_score: 32105.258
# 668/1000 epoch ge_loss: 178.078 d_loss: 0.000 anomaly_score: 34769.205
# 669/1000 epoch ge_loss: 167.342 d_loss: 0.003 anomaly_score: 34807.530
# 670/1000 epoch ge_loss: 196.098 d_loss: 0.001 anomaly_score: 36311.409
# 671/1000 epoch ge_loss: 172.783 d_loss: 0.000 anomaly_score: 39446.017
# 672/1000 epoch ge_loss: 157.500 d_loss: 0.000 anomaly_score: 36046.384
# 673/1000 epoch ge_loss: 186.740 d_loss: 0.000 anomaly_score: 31183.663
# 674/1000 epoch ge_loss: 170.119 d_loss: 0.000 anomaly_score: 22863.931
# 675/1000 epoch ge_loss: 173.597 d_loss: 0.002 anomaly_score: 27966.999
# 676/1000 epoch ge_loss: 168.833 d_loss: 0.001 anomaly_score: 33334.380
# 677/1000 epoch ge_loss: 160.464 d_loss: 0.000 anomaly_score: 31715.398
# 678/1000 epoch ge_loss: 175.651 d_loss: 0.000 anomaly_score: 29090.164
# 679/1000 epoch ge_loss: 165.182 d_loss: 0.001 anomaly_score: 23763.400
# 680/1000 epoch ge_loss: 171.221 d_loss: 0.000 anomaly_score: 34220.852
# 681/1000 epoch ge_loss: 183.844 d_loss: 0.000 anomaly_score: 32210.524
# 682/1000 epoch ge_loss: 165.090 d_loss: 0.000 anomaly_score: 30375.673
# 683/1000 epoch ge_loss: 155.220 d_loss: 0.000 anomaly_score: 37328.827
# 684/1000 epoch ge_loss: 160.805 d_loss: 0.000 anomaly_score: 29771.297
# 685/1000 epoch ge_loss: 180.338 d_loss: 0.000 anomaly_score: 27405.221
# 686/1000 epoch ge_loss: 176.499 d_loss: 0.000 anomaly_score: 36497.409
# 687/1000 epoch ge_loss: 186.002 d_loss: 0.000 anomaly_score: 30487.970
# 688/1000 epoch ge_loss: 168.664 d_loss: 0.001 anomaly_score: 23815.267
# 689/1000 epoch ge_loss: 163.018 d_loss: 0.000 anomaly_score: 29113.075
# 690/1000 epoch ge_loss: 161.691 d_loss: 0.000 anomaly_score: 30725.821
# 691/1000 epoch ge_loss: 175.240 d_loss: 0.000 anomaly_score: 30896.423
# 692/1000 epoch ge_loss: 167.438 d_loss: 0.000 anomaly_score: 30920.602
# 693/1000 epoch ge_loss: 168.886 d_loss: 0.000 anomaly_score: 29180.830
# 694/1000 epoch ge_loss: 175.953 d_loss: 0.000 anomaly_score: 21315.062
# 695/1000 epoch ge_loss: 164.178 d_loss: 0.001 anomaly_score: 21255.603
# 696/1000 epoch ge_loss: 170.381 d_loss: 0.000 anomaly_score: 21946.160
# 697/1000 epoch ge_loss: 191.002 d_loss: 0.000 anomaly_score: 27722.336
# 698/1000 epoch ge_loss: 170.461 d_loss: 0.000 anomaly_score: 27623.866
# 699/1000 epoch ge_loss: 160.122 d_loss: 0.000 anomaly_score: 24440.098
# 700/1000 epoch ge_loss: 160.552 d_loss: 0.000 anomaly_score: 28336.711
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-8a47d6bcdd49> in <module>()
#      74         optimizer_ge.step()
#      75
# ---> 76         loss_d_sum += loss_d.item()
#      77         loss_ge_sum += loss_ge.item()
#      78
#
# KeyboardInterrupt:

# %%
# Generator+EncoderとDiscriminatorのLossの推移と、anomaly scoreの推移
plt.figure(figsize=(12, 8*2))

plt.subplot(211)
plt.plot(range(len(Losses_GE)), Losses_GE, label="ge loss",color="blue")
plt.legend()

plt.plot(range(len(Losses_D)), Losses_D, label="d loss",color="orange")
plt.legend()
plt.subplot(212)
plt.plot(range(len(anomaly_scores)), anomaly_scores, label="anomaly score",color="green")
plt.legend()

plt.show()

# %% [markdown]
# # 潜在変数Zの最適化とテスト画像での異常検知

# %%
# 学習したモデルの読み込み

LOAD_EPOCH = 700

G = Generator().to(device)
G.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Generator_{LOAD_EPOCH}.pkl"))
G.eval()


E = Encoder().to(device)
E.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Encoder_{LOAD_EPOCH}.pkl"))
E.eval()

D = Discriminator().to(device)
D.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Discriminator_{LOAD_EPOCH}.pkl"))
D.eval()
print("load model")
# Out:
# load model

# %%
# 正常な画像で実行

random_image_size = 40

test_root_normal = './screw/test/good/'
test_dataset_normal = LoadFromFolder(test_root_normal, transform=transform_dict["test"])

test_images_normal = random.sample(list(test_dataset_normal), random_image_size)

normal_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_normal)):

    x = test_images_normal[idx].view(1, 3, 384, 384).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    normal_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %%
# manipulated_frontで実行

random_image_size = 20

test_root_manipulated_front = './screw/test/manipulated_front/'
test_dataset_manipulated_front = LoadFromFolder(test_root_manipulated_front, transform=transform_dict["test"])

test_images_manipulated_front = random.sample(list(test_dataset_manipulated_front), random_image_size)

manipulated_front_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_manipulated_front)):

    x = test_images_manipulated_front[idx].view(1, 3, 384, 384).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    manipulated_front_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %%
# 正常品のスコアをデータフレーム化
normal_df = pd.DataFrame({'score': normal_anomaly_score})
normal_df['label'] = 'normal'

# 傷品のスコアをデータフレーム化
manipulated_front_df = pd.DataFrame({'score': manipulated_front_anomaly_score})
manipulated_front_df['label'] = 'scratch'

#テストデータのlossを可視化
plt.hist(normal_df['score'], alpha=0.5, bins=20, label='normal')
plt.hist(manipulated_front_df['score'], alpha=0.5, bins=20, label='scratch')
plt.legend(loc="upper right", fontsize=13)
plt.show()
