# %% [markdown]
# # 環境確認

# %%
import sys
import torch

print("Pythonのバージョン：",sys.version)
print("PyTorchのバージョン：", torch.__version__)
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# Pythonのバージョン： 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# PyTorchのバージョン： 1.10.0+cu111
# 使用しているGPUの確認
# Fri Feb 25 03:54:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    74W / 149W |   5674MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # データのダウンロード

# %%
# データのダウンロード
# !wget https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420938130-1629953152/screw.tar.xz
# Out:
# --2022-02-25 03:54:11--  https://www.mydrive.ch/shares/38536/3830184030e49fe74747669442f0f282/download/420938130-1629953152/screw.tar.xz
# Resolving www.mydrive.ch (www.mydrive.ch)... 91.214.169.64
# Connecting to www.mydrive.ch (www.mydrive.ch)|91.214.169.64|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 195344332 (186M) [application/x-xz]
# Saving to: ‘screw.tar.xz.3’
#
# screw.tar.xz.3      100%[===================>] 186.29M  10.4MB/s    in 21s
#
# 2022-02-25 03:54:33 (8.97 MB/s) - ‘screw.tar.xz.3’ saved [195344332/195344332]

# %%
# 解凍
# !tar -xf screw.tar.xz

# %%
# 作業ディレクトリを確認
# !ls
# Out:
# results      screw	   screw.tar.xz.1  screw.tar.xz.3
# sample_data  screw.tar.xz  screw.tar.xz.2

# %% [markdown]
# # テストデータの準備

# %%
# テストデータのディレクトリを確認
# !ls screw/test/
# Out:
# good  manipulated_front  scratch_head  scratch_neck  thread_side  thread_top

# %%
# testディレクトリ内のディレクトリ内の画像リストを作成
import glob

good = glob.glob('screw/test/good/*.png')
manipulated_front = glob.glob('screw/test/manipulated_front/*.png')
scratch_head = glob.glob('screw/test/scratch_head/*.png')
scratch_neck = glob.glob('screw/test/scratch_neck/*.png')
thread_side = glob.glob('screw/test/thread_side/*.png')
thread_top = glob.glob('screw/test/thread_top/*.png')
print(good)
print(len(good))
# Out:
# ['screw/test/good/013.png', 'screw/test/good/028.png', 'screw/test/good/006.png', 'screw/test/good/000.png', 'screw/test/good/039.png', 'screw/test/good/009.png', 'screw/test/good/015.png', 'screw/test/good/040.png', 'screw/test/good/011.png', 'screw/test/good/026.png', 'screw/test/good/010.png', 'screw/test/good/035.png', 'screw/test/good/034.png', 'screw/test/good/024.png', 'screw/test/good/029.png', 'screw/test/good/007.png', 'screw/test/good/032.png', 'screw/test/good/033.png', 'screw/test/good/030.png', 'screw/test/good/019.png', 'screw/test/good/004.png', 'screw/test/good/003.png', 'screw/test/good/020.png', 'screw/test/good/038.png', 'screw/test/good/025.png', 'screw/test/good/027.png', 'screw/test/good/017.png', 'screw/test/good/022.png', 'screw/test/good/014.png', 'screw/test/good/002.png', 'screw/test/good/008.png', 'screw/test/good/016.png', 'screw/test/good/001.png', 'screw/test/good/018.png', 'screw/test/good/023.png', 'screw/test/good/021.png', 'screw/test/good/036.png', 'screw/test/good/005.png', 'screw/test/good/031.png', 'screw/test/good/037.png', 'screw/test/good/012.png']
# 41

# %% [markdown]
# # 事前準備

# %%
# ライブラリのインポート
import os
import random
from glob import glob
from warnings import filterwarnings

import cv2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
import torch.nn.init as init
from natsort import natsorted
from PIL import Image
from skimage import io, transform
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image

from torchsummary import summary

filterwarnings("ignore")  # warningをオフにする

# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
'''デバイスの設定'''

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
'''初期設定'''

COLAB_FLG = False  # COLABで実行する場合はTrue, それ以外で実行する場合はFalse

if COLAB_FLG:
    from google.colab import drive
    drive.mount('/content/gdrive') # マウント先
    ATTACH_PATH = "/content/gdrive/MyDrive/screw_anomaly"  # 保存先のベースディレクトリ
else:
    ATTACH_PATH = "."  # ローカルならカレントディレクトリ
    
    
SAVE_MODEL_PATH = f"{ATTACH_PATH}/results/model/"  # モデルの保存先
SAVE_IMAGE_FROM_Z_PATH = f"{ATTACH_PATH}/results/image/image_from_z/"  # 乱数から生成した画像の保存先
SAVE_IMAGE_RECONSTRUCT = f"{ATTACH_PATH}/results/image/RECONSTRUCT/"  # 再構成した画像の保存先

# 保存先のディレクトリを作成する
os.makedirs(SAVE_MODEL_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_FROM_Z_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_RECONSTRUCT, exist_ok=True)

# %%
'''ハイパーパラメータの設定'''

import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--image_size", type=int, default=192)
parser.add_argument("--num_epochs", type=int, default=500)
parser.add_argument("--batch_size", type=int, default=16)
parser.add_argument("--lr", type=float, default=4e-4)
parser.add_argument("--z_dim", type=int, default=128) # ノイズの次元
parser.add_argument("--beta1", type=float, default=0.5) # Adamのハイパーパラメータ
parser.add_argument("--beta2", type=float, default=0.999) # Adamのハイパーパラメータ
opt = parser.parse_args(args=[])
print(opt)
# Out:
# Namespace(batch_size=16, beta1=0.5, beta2=0.999, image_size=192, lr=0.0004, num_epochs=500, z_dim=128)

# %%
# デバイスの設定
device = "cuda" if torch.cuda.is_available() else "cpu"
kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {} # GPUが使える場合、DataLoaderでのミニバッチの取り出しを高速化

# %% [markdown]
# # DataLoader

# %%
train_root = './screw/train/good/'  # train dataの保存してあるディレクトリ
val_root = './screw/test/good/'  # val dataの保存してあるディレクトリ

# ディレクトリから画像を読み込んでDataLoaderに渡す用のクラス

class LoadFromFolder(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = natsorted(os.listdir(main_dir)) # ディレクトリ一覧を取得して自然ソート
        self.all_imgs_name = natsorted(all_imgs)
        self.imgs_loc = [os.path.join(self.main_dir, i) for i in self.all_imgs_name] # 画像のディレクトリ一覧

    def __len__(self):
        return len(self.all_imgs_name)
    
    def load_image(self, path):
        image = Image.open(path).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image
    
    def __getitem__(self, idx):
        
        # 後ほどsliceで画像を複数枚取得したいのでsliceでも取れるようにする
        if type(idx) == slice:
            paths = self.imgs_loc[idx]
            tensor_image = [self.load_image(path) for path in paths]
            tensor_image = torch.cat(tensor_image).reshape(len(tensor_image), *tensor_image[0].shape)
        elif type(idx) == int:
            path = self.imgs_loc[idx]
            tensor_image = self.load_image(path)
        return tensor_image

# 画像を読み込む際の前処理

transform_dict = {
    "train": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.RandomHorizontalFlip(), # ランダムに左右反転を行う
            transforms.ToTensor(),
        ]
    ),
    "test": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.ToTensor(),
        ]
    ),
}

# データを読み込む
train_dataset = LoadFromFolder(train_root, transform=transform_dict["train"])

test_dataset = LoadFromFolder(val_root, transform=transform_dict["test"])

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

val_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

# %% [markdown]
# # Encoder

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=4, stride=2, padding=1, bias=False), # 96x96
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.2),

            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(256, 512, kernel_size=6, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(512, 512, kernel_size=1, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
        )

        self.last = nn.Sequential(nn.Conv2d(512, opt.z_dim, kernel_size=1, stride=1, bias=False))

    def forward(self, x):

        out = self.main(x)
        out = self.last(out)
        out = out.view(out.size()[0], -1, 1, 1)
        return out

# %%
# ネットワークを可視化する
summary(Encoder().to(device), (3, opt.image_size, opt.image_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 96, 96]             768
#        BatchNorm2d-2           [-1, 16, 96, 96]              32
#          LeakyReLU-3           [-1, 16, 96, 96]               0
#             Conv2d-4           [-1, 32, 48, 48]           8,192
#        BatchNorm2d-5           [-1, 32, 48, 48]              64
#          LeakyReLU-6           [-1, 32, 48, 48]               0
#             Conv2d-7           [-1, 64, 24, 24]          32,768
#        BatchNorm2d-8           [-1, 64, 24, 24]             128
#          LeakyReLU-9           [-1, 64, 24, 24]               0
#            Conv2d-10          [-1, 128, 12, 12]         131,072
#       BatchNorm2d-11          [-1, 128, 12, 12]             256
#         LeakyReLU-12          [-1, 128, 12, 12]               0
#            Conv2d-13            [-1, 256, 6, 6]         524,288
#       BatchNorm2d-14            [-1, 256, 6, 6]             512
#         LeakyReLU-15            [-1, 256, 6, 6]               0
#            Conv2d-16            [-1, 512, 1, 1]       4,718,592
#       BatchNorm2d-17            [-1, 512, 1, 1]           1,024
#         LeakyReLU-18            [-1, 512, 1, 1]               0
#            Conv2d-19            [-1, 512, 1, 1]         262,144
#       BatchNorm2d-20            [-1, 512, 1, 1]           1,024
#         LeakyReLU-21            [-1, 512, 1, 1]               0
#            Conv2d-22            [-1, 128, 1, 1]          65,536
# ================================================================
# Total params: 5,746,400
# Trainable params: 5,746,400
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.42
# Forward/backward pass size (MB): 6.56
# Params size (MB): 21.92
# Estimated Total Size (MB): 28.91
# ----------------------------------------------------------------

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.main = nn.Sequential(
            nn.ConvTranspose2d(opt.z_dim, 512, kernel_size=6, stride=1, padding=0, bias=False), # 3x3
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(512, 256, kernel_size=7, stride=1, padding=0, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),

            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False), #96x96
            nn.Tanh()
        )

    def forward(self, z):
        out = self.main(z)
        return out

# %%
# ネットワークを可視化する
summary(Generator().to(device), tuple([opt.z_dim, 1, 1]))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 512, 6, 6]       2,359,296
#        BatchNorm2d-2            [-1, 512, 6, 6]           1,024
#          LeakyReLU-3            [-1, 512, 6, 6]               0
#    ConvTranspose2d-4          [-1, 256, 12, 12]       6,422,528
#        BatchNorm2d-5          [-1, 256, 12, 12]             512
#          LeakyReLU-6          [-1, 256, 12, 12]               0
#    ConvTranspose2d-7          [-1, 128, 24, 24]         524,288
#        BatchNorm2d-8          [-1, 128, 24, 24]             256
#          LeakyReLU-9          [-1, 128, 24, 24]               0
#   ConvTranspose2d-10           [-1, 64, 48, 48]         131,072
#       BatchNorm2d-11           [-1, 64, 48, 48]             128
#         LeakyReLU-12           [-1, 64, 48, 48]               0
#   ConvTranspose2d-13           [-1, 32, 96, 96]          32,768
#       BatchNorm2d-14           [-1, 32, 96, 96]              64
#         LeakyReLU-15           [-1, 32, 96, 96]               0
#   ConvTranspose2d-16          [-1, 3, 192, 192]           1,536
#              Tanh-17          [-1, 3, 192, 192]               0
# ================================================================
# Total params: 9,473,472
# Trainable params: 9,473,472
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 14.77
# Params size (MB): 36.14
# Estimated Total Size (MB): 50.90
# ----------------------------------------------------------------

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
            
        self.x_layer = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
            # nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1, inplace=True), #96x96
            nn.Dropout2d(p=0.3),

            nn.AvgPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1, inplace=True), #48x48
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True), #24x24
            nn.Dropout2d(p=0.3),

            nn.AvgPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True), #12x12
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.1, inplace=True), #6x6
            nn.Dropout2d(p=0.3),
            
            nn.AvgPool2d(2),
            nn.Conv2d(256, 256, kernel_size=6, stride=1) #1x1

        )
        self.z_layer = nn.Sequential(
            nn.Conv2d(opt.z_dim, 256, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.2),
        )
        
        self.last1 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=False),
            nn.Dropout2d(p=0.2),
        )
        self.last2 = nn.Sequential(
            nn.Conv2d(512, 1, kernel_size=1, stride=1),
        )

    def forward(self, x, z):
        
        output_x = self.x_layer(x)
        output_z = self.z_layer(z)
        
        concat_x_z = torch.cat((output_x, output_z), 1)
        output = self.last1(concat_x_z)

        feature = output.view(output.size()[0], -1)
        
        output = self.last2(output)
        output = F.sigmoid(output)
        return output.squeeze(), feature

# %%
# ネットワークを可視化する
summary(Discriminator().to(device), [(3, opt.image_size, opt.image_size), (opt.z_dim, 1, 1)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 192, 192]             448
#          LeakyReLU-2         [-1, 16, 192, 192]               0
#          Dropout2d-3         [-1, 16, 192, 192]               0
#          AvgPool2d-4           [-1, 16, 96, 96]               0
#             Conv2d-5           [-1, 32, 96, 96]           4,640
#        BatchNorm2d-6           [-1, 32, 96, 96]              64
#          LeakyReLU-7           [-1, 32, 96, 96]               0
#          Dropout2d-8           [-1, 32, 96, 96]               0
#          AvgPool2d-9           [-1, 32, 48, 48]               0
#            Conv2d-10           [-1, 64, 48, 48]          18,496
#       BatchNorm2d-11           [-1, 64, 48, 48]             128
#         LeakyReLU-12           [-1, 64, 48, 48]               0
#         Dropout2d-13           [-1, 64, 48, 48]               0
#         AvgPool2d-14           [-1, 64, 24, 24]               0
#            Conv2d-15          [-1, 128, 24, 24]          73,856
#       BatchNorm2d-16          [-1, 128, 24, 24]             256
#         LeakyReLU-17          [-1, 128, 24, 24]               0
#         Dropout2d-18          [-1, 128, 24, 24]               0
#         AvgPool2d-19          [-1, 128, 12, 12]               0
#            Conv2d-20          [-1, 256, 12, 12]         295,168
#       BatchNorm2d-21          [-1, 256, 12, 12]             512
#         LeakyReLU-22          [-1, 256, 12, 12]               0
#         Dropout2d-23          [-1, 256, 12, 12]               0
#         AvgPool2d-24            [-1, 256, 6, 6]               0
#            Conv2d-25            [-1, 256, 1, 1]       2,359,552
#            Conv2d-26            [-1, 256, 1, 1]          33,024
#         LeakyReLU-27            [-1, 256, 1, 1]               0
#         Dropout2d-28            [-1, 256, 1, 1]               0
#            Conv2d-29            [-1, 512, 1, 1]         262,656
#         LeakyReLU-30            [-1, 512, 1, 1]               0
#         Dropout2d-31            [-1, 512, 1, 1]               0
#            Conv2d-32              [-1, 1, 1, 1]             513
# ================================================================
# Total params: 3,049,313
# Trainable params: 3,049,313
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 54.00
# Forward/backward pass size (MB): 32.57
# Params size (MB): 11.63
# Estimated Total Size (MB): 98.21
# ----------------------------------------------------------------

# %%
# 重みの初期化を行う関数

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find("Linear") != -1:
        m.bias.data.fill_(0)

E = Encoder().to(device)
E.apply(weights_init)

G = Generator().to(device)
G.apply(weights_init)

D = Discriminator().to(device)
D.apply(weights_init)
# Out:
# Discriminator(
#   (x_layer): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (2): Dropout2d(p=0.3, inplace=False)
#     (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.1, inplace=True)
#     (7): Dropout2d(p=0.3, inplace=False)
#     (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (9): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.1, inplace=True)
#     (12): Dropout2d(p=0.3, inplace=False)
#     (13): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.1, inplace=True)
#     (17): Dropout2d(p=0.3, inplace=False)
#     (18): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (19): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (21): LeakyReLU(negative_slope=0.1, inplace=True)
#     (22): Dropout2d(p=0.3, inplace=False)
#     (23): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (24): Conv2d(256, 256, kernel_size=(6, 6), stride=(1, 1))
#   )
#   (z_layer): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1, inplace=True)
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (last1): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Dropout2d(p=0.2, inplace=False)
#   )
#   (last2): Sequential(
#     (0): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
criterion = nn.BCELoss()  # 評価関数
criterion_L1 = nn.L1Loss(reduction="sum") # 異常スコア計測用

# %%
# gとeは共通のoptimizer
optimizer_ge = torch.optim.Adam(list(G.parameters()) + list(E.parameters()), lr=opt.lr, betas=(opt.beta1,opt.beta2))
optimizer_d = torch.optim.Adam(D.parameters(), lr=opt.lr, betas=(opt.beta1,opt.beta2))

scheduler_ge = torch.optim.lr_scheduler.StepLR(optimizer_ge, step_size=50, gamma=0.9)
scheduler_d = torch.optim.lr_scheduler.StepLR(optimizer_d, step_size=50, gamma=0.9)

# %%
def Anomaly_score(x, E_x, G_E_x, Lambda=0.1):
    
    _,x_feature = D(x, E_x)
    _,G_E_x_feature = D(G_E_x, E_x)
    
    residual_loss = criterion_L1(x, G_E_x)
    discrimination_loss = criterion_L1(x_feature, G_E_x_feature)
    
    total_loss = (1-Lambda)*residual_loss + Lambda*discrimination_loss
    total_loss = total_loss.item()

    return total_loss

# %% [markdown]
# # 学習

# %%
Losses_D = []
Losses_GE = []
anomaly_scores = []

for epoch in range(opt.num_epochs):
    loss_d_sum = 0
    loss_ge_sum = 0
    anomaly_score_sum = 0
    
    for i,(x, x_val) in enumerate(zip(train_loader, val_loader)):
        
        G.train()
        D.train()
        E.train()

        # 値の設定
        y_true = Variable(torch.ones(x.size()[0])).to(device)
        y_fake = Variable(torch.zeros(x.size()[0])).to(device)
        
        x = Variable(x).to(device)
        z = Variable(init.normal(torch.Tensor(x.size()[0],opt.z_dim, 1, 1),mean=0,std=0.1)).to(device)
        
        # Discriminatorに対するノイズ
        noise1 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)
        noise2 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)

        # Discriminator
        optimizer_d.zero_grad()
        
        E_x = E(x) 
        p_true, _ = D(x + noise1, E_x)
        
        G_z = G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_d = criterion(p_true, y_true) + criterion(p_fake, y_fake)
        loss_d.backward(retain_graph=True)
        optimizer_d.step()
        
        # Generator, Encoder
        optimizer_ge.zero_grad()
        
        G_E_x = G(E_x)
        E_G_z = E(G_z)
    
        p_true, _ = D(x + noise1, E_x)
        
        # G_z = model_G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        
        loss_ge_1 = criterion(p_fake, y_true) + criterion(p_true, y_fake)
        loss_ge_2 = criterion_L1(x, G_E_x) +  criterion_L1(z, E_G_z)
        
        alpha = 0.01
        
        loss_ge = (1 - alpha)*loss_ge_1 + alpha*loss_ge_2
        loss_ge.backward(retain_graph=True)
        optimizer_ge.step()
        
        loss_d_sum += loss_d.item()
        loss_ge_sum += loss_ge.item()
        
        # anomaly scoreの記録
        
        G.eval()
        D.eval()
        E.eval()
        x_val = Variable(x_val).to(device)
        E_x_val = E(x_val)
        G_E_x_val = G(E_x_val)
        anomaly_score_sum += Anomaly_score(x_val, E_x_val, G_E_x_val)

        # 画像を保存
        if i == 0:
            
            G.eval()
            D.eval()
            E.eval()
        
            save_image_size_for_z = min(opt.batch_size, 8)
            save_images = G(z)
            save_image(save_images[:save_image_size_for_z], f"{SAVE_IMAGE_FROM_Z_PATH}/epoch_{epoch}.png", nrow=4)

            save_image_size_for_recon = min(opt.batch_size, 8)
            images = x[:save_image_size_for_recon]
            G_E_x = G(E(images))
            diff_images = torch.abs(images - G_E_x)
            comparison = torch.cat([images , G_E_x, diff_images]).to("cpu")
            save_image(comparison, f"{SAVE_IMAGE_RECONSTRUCT}/epoch_{epoch}.png", nrow=save_image_size_for_recon)
            
    scheduler_ge.step()
    scheduler_d.step()
        
    # lossを記録
    loss_d_mean = loss_d_sum / len(train_loader)
    loss_ge_mean = loss_ge_sum / len(train_loader)
    anomaly_score_mean = anomaly_score_sum / len(train_loader)
    
    print(f"{epoch}/{opt.num_epochs} epoch ge_loss: {loss_ge_mean:.3f} d_loss: {loss_d_mean:.3f} anomaly_score: {anomaly_score_mean:.3f}")
    
    Losses_D.append(loss_d_mean)
    Losses_GE.append(loss_ge_mean)
    anomaly_scores.append(anomaly_score_mean)
    
    # モデルを保存
    if (epoch + 1) % 10 == 0:
        torch.save(G.state_dict(),f'{SAVE_MODEL_PATH}/Generator_{epoch + 1}.pkl')
        torch.save(E.state_dict(),f'{SAVE_MODEL_PATH}/Encoder_{epoch + 1}.pkl')
        torch.save(D.state_dict(),f'{SAVE_MODEL_PATH}/Discriminator_{epoch + 1}.pkl')
# Out:
# 0/500 epoch ge_loss: 1841.183 d_loss: 0.209 anomaly_score: 135729.247
# 1/500 epoch ge_loss: 1710.361 d_loss: 0.199 anomaly_score: 132154.737
# 2/500 epoch ge_loss: 1553.803 d_loss: 0.196 anomaly_score: 122096.895
# 3/500 epoch ge_loss: 1404.714 d_loss: 0.172 anomaly_score: 107229.009
# 4/500 epoch ge_loss: 1222.863 d_loss: 0.152 anomaly_score: 89281.387
# 5/500 epoch ge_loss: 1075.639 d_loss: 0.142 anomaly_score: 70500.456
# 6/500 epoch ge_loss: 936.467 d_loss: 0.134 anomaly_score: 54568.400
# 7/500 epoch ge_loss: 776.882 d_loss: 0.113 anomaly_score: 41115.507
# 8/500 epoch ge_loss: 677.033 d_loss: 0.104 anomaly_score: 29657.415
# 9/500 epoch ge_loss: 559.517 d_loss: 0.125 anomaly_score: 26890.028
# 10/500 epoch ge_loss: 473.343 d_loss: 0.110 anomaly_score: 21606.600
# 11/500 epoch ge_loss: 406.049 d_loss: 0.076 anomaly_score: 22675.544
# 12/500 epoch ge_loss: 335.902 d_loss: 0.070 anomaly_score: 20102.265
# 13/500 epoch ge_loss: 279.538 d_loss: 0.051 anomaly_score: 19790.616
# 14/500 epoch ge_loss: 237.433 d_loss: 0.067 anomaly_score: 18558.473
# 15/500 epoch ge_loss: 201.027 d_loss: 0.043 anomaly_score: 17052.804
# 16/500 epoch ge_loss: 185.801 d_loss: 0.025 anomaly_score: 21909.696
# 17/500 epoch ge_loss: 161.341 d_loss: 0.022 anomaly_score: 22626.164
# 18/500 epoch ge_loss: 144.963 d_loss: 0.017 anomaly_score: 20588.877
# 19/500 epoch ge_loss: 130.322 d_loss: 0.025 anomaly_score: 18878.849
# 20/500 epoch ge_loss: 136.138 d_loss: 0.024 anomaly_score: 18325.208
# 21/500 epoch ge_loss: 123.917 d_loss: 0.024 anomaly_score: 21145.525
# 22/500 epoch ge_loss: 115.091 d_loss: 0.040 anomaly_score: 21681.600
# 23/500 epoch ge_loss: 125.975 d_loss: 0.043 anomaly_score: 16093.794
# 24/500 epoch ge_loss: 115.547 d_loss: 0.020 anomaly_score: 15627.689
# 25/500 epoch ge_loss: 112.269 d_loss: 0.015 anomaly_score: 14203.496
# 26/500 epoch ge_loss: 107.861 d_loss: 0.014 anomaly_score: 11689.171
# 27/500 epoch ge_loss: 100.785 d_loss: 0.006 anomaly_score: 15629.255
# 28/500 epoch ge_loss: 109.117 d_loss: 0.014 anomaly_score: 21923.027
# 29/500 epoch ge_loss: 104.492 d_loss: 0.006 anomaly_score: 16296.451
# 30/500 epoch ge_loss: 99.060 d_loss: 0.006 anomaly_score: 12606.075
# 31/500 epoch ge_loss: 95.036 d_loss: 0.004 anomaly_score: 11125.329
# 32/500 epoch ge_loss: 100.225 d_loss: 0.006 anomaly_score: 9755.121
# 33/500 epoch ge_loss: 95.988 d_loss: 0.007 anomaly_score: 9881.005
# 34/500 epoch ge_loss: 98.370 d_loss: 0.015 anomaly_score: 10422.070
# 35/500 epoch ge_loss: 92.712 d_loss: 0.020 anomaly_score: 11097.146
# 36/500 epoch ge_loss: 90.031 d_loss: 0.046 anomaly_score: 9218.135
# 37/500 epoch ge_loss: 91.059 d_loss: 0.035 anomaly_score: 8985.295
# 38/500 epoch ge_loss: 85.172 d_loss: 0.011 anomaly_score: 10213.656
# 39/500 epoch ge_loss: 86.126 d_loss: 0.005 anomaly_score: 9770.410
# 40/500 epoch ge_loss: 83.907 d_loss: 0.004 anomaly_score: 9708.349
# 41/500 epoch ge_loss: 83.103 d_loss: 0.006 anomaly_score: 9302.738
# 42/500 epoch ge_loss: 79.623 d_loss: 0.006 anomaly_score: 8786.542
# 43/500 epoch ge_loss: 85.568 d_loss: 0.005 anomaly_score: 8687.794
# 44/500 epoch ge_loss: 84.603 d_loss: 0.009 anomaly_score: 9233.837
# 45/500 epoch ge_loss: 84.173 d_loss: 0.011 anomaly_score: 8869.333
# 46/500 epoch ge_loss: 80.103 d_loss: 0.022 anomaly_score: 8459.192
# 47/500 epoch ge_loss: 82.957 d_loss: 0.016 anomaly_score: 8498.702
# 48/500 epoch ge_loss: 75.823 d_loss: 0.019 anomaly_score: 7753.887
# 49/500 epoch ge_loss: 77.236 d_loss: 0.006 anomaly_score: 9781.697
# 50/500 epoch ge_loss: 82.608 d_loss: 0.015 anomaly_score: 8683.593
# 51/500 epoch ge_loss: 79.041 d_loss: 0.010 anomaly_score: 9716.240
# 52/500 epoch ge_loss: 75.497 d_loss: 0.005 anomaly_score: 8388.857
# 53/500 epoch ge_loss: 76.421 d_loss: 0.004 anomaly_score: 7818.128
# 54/500 epoch ge_loss: 76.975 d_loss: 0.023 anomaly_score: 8699.007
# 55/500 epoch ge_loss: 75.216 d_loss: 0.027 anomaly_score: 9186.747
# 56/500 epoch ge_loss: 75.414 d_loss: 0.008 anomaly_score: 7547.985
# 57/500 epoch ge_loss: 77.295 d_loss: 0.028 anomaly_score: 7328.582
# 58/500 epoch ge_loss: 75.161 d_loss: 0.023 anomaly_score: 7433.436
# 59/500 epoch ge_loss: 78.232 d_loss: 0.007 anomaly_score: 7613.654
# 60/500 epoch ge_loss: 78.706 d_loss: 0.023 anomaly_score: 9298.731
# 61/500 epoch ge_loss: 74.340 d_loss: 0.009 anomaly_score: 9687.174
# 62/500 epoch ge_loss: 73.682 d_loss: 0.020 anomaly_score: 7764.896
# 63/500 epoch ge_loss: 78.724 d_loss: 0.007 anomaly_score: 7181.116
# 64/500 epoch ge_loss: 70.741 d_loss: 0.006 anomaly_score: 7045.544
# 65/500 epoch ge_loss: 70.458 d_loss: 0.007 anomaly_score: 6704.382
# 66/500 epoch ge_loss: 72.276 d_loss: 0.007 anomaly_score: 7473.968
# 67/500 epoch ge_loss: 83.231 d_loss: 0.009 anomaly_score: 10623.748
# 68/500 epoch ge_loss: 76.308 d_loss: 0.003 anomaly_score: 11935.318
# 69/500 epoch ge_loss: 75.364 d_loss: 0.005 anomaly_score: 9203.151
# 70/500 epoch ge_loss: 73.790 d_loss: 0.002 anomaly_score: 7036.492
# 71/500 epoch ge_loss: 69.386 d_loss: 0.003 anomaly_score: 8143.973
# 72/500 epoch ge_loss: 66.897 d_loss: 0.003 anomaly_score: 8058.404
# 73/500 epoch ge_loss: 71.261 d_loss: 0.006 anomaly_score: 6875.032
# 74/500 epoch ge_loss: 72.127 d_loss: 0.004 anomaly_score: 7108.512
# 75/500 epoch ge_loss: 70.683 d_loss: 0.008 anomaly_score: 6915.526
# 76/500 epoch ge_loss: 70.005 d_loss: 0.003 anomaly_score: 7512.983
# 77/500 epoch ge_loss: 65.206 d_loss: 0.004 anomaly_score: 6525.202
# 78/500 epoch ge_loss: 71.400 d_loss: 0.010 anomaly_score: 7983.541
# 79/500 epoch ge_loss: 66.550 d_loss: 0.004 anomaly_score: 6485.159
# 80/500 epoch ge_loss: 65.804 d_loss: 0.005 anomaly_score: 6706.873
# 81/500 epoch ge_loss: 68.958 d_loss: 0.004 anomaly_score: 7466.711
# 82/500 epoch ge_loss: 67.365 d_loss: 0.003 anomaly_score: 7672.399
# 83/500 epoch ge_loss: 66.748 d_loss: 0.009 anomaly_score: 6275.129
# 84/500 epoch ge_loss: 65.226 d_loss: 0.006 anomaly_score: 6258.873
# 85/500 epoch ge_loss: 69.003 d_loss: 0.004 anomaly_score: 6723.543
# 86/500 epoch ge_loss: 64.056 d_loss: 0.002 anomaly_score: 7113.987
# 87/500 epoch ge_loss: 67.820 d_loss: 0.004 anomaly_score: 7471.325
# 88/500 epoch ge_loss: 69.695 d_loss: 0.003 anomaly_score: 6208.028
# 89/500 epoch ge_loss: 68.107 d_loss: 0.004 anomaly_score: 6570.130
# 90/500 epoch ge_loss: 65.006 d_loss: 0.004 anomaly_score: 6138.916
# 91/500 epoch ge_loss: 70.428 d_loss: 0.005 anomaly_score: 6091.828
# 92/500 epoch ge_loss: 67.793 d_loss: 0.003 anomaly_score: 6649.837
# 93/500 epoch ge_loss: 65.215 d_loss: 0.002 anomaly_score: 6289.220
# 94/500 epoch ge_loss: 68.303 d_loss: 0.001 anomaly_score: 6386.012
# 95/500 epoch ge_loss: 62.467 d_loss: 0.005 anomaly_score: 6375.677
# 96/500 epoch ge_loss: 62.957 d_loss: 0.002 anomaly_score: 6655.498
# 97/500 epoch ge_loss: 65.371 d_loss: 0.001 anomaly_score: 5960.152
# 98/500 epoch ge_loss: 62.901 d_loss: 0.004 anomaly_score: 6324.398
# 99/500 epoch ge_loss: 67.152 d_loss: 0.002 anomaly_score: 6129.798
# 100/500 epoch ge_loss: 67.140 d_loss: 0.002 anomaly_score: 6781.764
# 101/500 epoch ge_loss: 66.000 d_loss: 0.001 anomaly_score: 6140.396
# 102/500 epoch ge_loss: 63.899 d_loss: 0.001 anomaly_score: 5606.965
# 103/500 epoch ge_loss: 66.120 d_loss: 0.001 anomaly_score: 6208.550
# 104/500 epoch ge_loss: 62.892 d_loss: 0.002 anomaly_score: 6009.536
# 105/500 epoch ge_loss: 64.103 d_loss: 0.002 anomaly_score: 7128.733
# 106/500 epoch ge_loss: 60.889 d_loss: 0.001 anomaly_score: 6183.624
# 107/500 epoch ge_loss: 73.528 d_loss: 0.002 anomaly_score: 7086.831
# 108/500 epoch ge_loss: 67.375 d_loss: 0.001 anomaly_score: 6176.150
# 109/500 epoch ge_loss: 66.766 d_loss: 0.002 anomaly_score: 5911.305
# 110/500 epoch ge_loss: 68.114 d_loss: 0.003 anomaly_score: 6966.494
# 111/500 epoch ge_loss: 61.172 d_loss: 0.001 anomaly_score: 5851.598
# 112/500 epoch ge_loss: 61.036 d_loss: 0.001 anomaly_score: 5779.824
# 113/500 epoch ge_loss: 60.407 d_loss: 0.003 anomaly_score: 5671.201
# 114/500 epoch ge_loss: 60.953 d_loss: 0.001 anomaly_score: 5844.147
# 115/500 epoch ge_loss: 61.944 d_loss: 0.001 anomaly_score: 6555.080
# 116/500 epoch ge_loss: 56.795 d_loss: 0.001 anomaly_score: 5379.555
# 117/500 epoch ge_loss: 66.563 d_loss: 0.002 anomaly_score: 5975.839
# 118/500 epoch ge_loss: 61.738 d_loss: 0.002 anomaly_score: 6021.429
# 119/500 epoch ge_loss: 58.941 d_loss: 0.008 anomaly_score: 5907.965
# 120/500 epoch ge_loss: 66.078 d_loss: 0.004 anomaly_score: 6012.130
# 121/500 epoch ge_loss: 59.401 d_loss: 0.002 anomaly_score: 6228.937
# 122/500 epoch ge_loss: 62.849 d_loss: 0.002 anomaly_score: 5410.583
# 123/500 epoch ge_loss: 63.756 d_loss: 0.006 anomaly_score: 5865.251
# 124/500 epoch ge_loss: 60.997 d_loss: 0.002 anomaly_score: 6156.639
# 125/500 epoch ge_loss: 64.341 d_loss: 0.006 anomaly_score: 6257.505
# 126/500 epoch ge_loss: 59.645 d_loss: 0.003 anomaly_score: 6432.712
# 127/500 epoch ge_loss: 63.823 d_loss: 0.004 anomaly_score: 6208.881
# 128/500 epoch ge_loss: 59.075 d_loss: 0.002 anomaly_score: 5714.573
# 129/500 epoch ge_loss: 56.453 d_loss: 0.002 anomaly_score: 6013.185
# 130/500 epoch ge_loss: 64.362 d_loss: 0.001 anomaly_score: 5754.372
# 131/500 epoch ge_loss: 61.191 d_loss: 0.001 anomaly_score: 5609.113
# 132/500 epoch ge_loss: 57.278 d_loss: 0.002 anomaly_score: 8039.673
# 133/500 epoch ge_loss: 60.346 d_loss: 0.002 anomaly_score: 5455.644
# 134/500 epoch ge_loss: 56.556 d_loss: 0.002 anomaly_score: 5596.943
# 135/500 epoch ge_loss: 55.417 d_loss: 0.001 anomaly_score: 5282.003
# 136/500 epoch ge_loss: 62.327 d_loss: 0.003 anomaly_score: 5351.503
# 137/500 epoch ge_loss: 58.298 d_loss: 0.003 anomaly_score: 5611.905
# 138/500 epoch ge_loss: 63.639 d_loss: 0.002 anomaly_score: 5784.448
# 139/500 epoch ge_loss: 59.620 d_loss: 0.001 anomaly_score: 6228.882
# 140/500 epoch ge_loss: 62.376 d_loss: 0.003 anomaly_score: 5974.364
# 141/500 epoch ge_loss: 57.332 d_loss: 0.002 anomaly_score: 5931.422
# 142/500 epoch ge_loss: 64.767 d_loss: 0.001 anomaly_score: 5707.010
# 143/500 epoch ge_loss: 58.046 d_loss: 0.001 anomaly_score: 5726.481
# 144/500 epoch ge_loss: 55.898 d_loss: 0.002 anomaly_score: 6114.163
# 145/500 epoch ge_loss: 55.961 d_loss: 0.002 anomaly_score: 5286.769
# 146/500 epoch ge_loss: 54.126 d_loss: 0.001 anomaly_score: 5405.814
# 147/500 epoch ge_loss: 56.986 d_loss: 0.001 anomaly_score: 5449.946
# 148/500 epoch ge_loss: 59.051 d_loss: 0.001 anomaly_score: 6441.176
# 149/500 epoch ge_loss: 61.611 d_loss: 0.001 anomaly_score: 6647.552
# 150/500 epoch ge_loss: 65.881 d_loss: 0.002 anomaly_score: 5800.808
# 151/500 epoch ge_loss: 67.137 d_loss: 0.002 anomaly_score: 5974.597
# 152/500 epoch ge_loss: 54.318 d_loss: 0.002 anomaly_score: 6368.368
# 153/500 epoch ge_loss: 53.971 d_loss: 0.002 anomaly_score: 6244.833
# 154/500 epoch ge_loss: 56.422 d_loss: 0.001 anomaly_score: 5732.899
# 155/500 epoch ge_loss: 56.597 d_loss: 0.003 anomaly_score: 5403.062
# 156/500 epoch ge_loss: 53.297 d_loss: 0.001 anomaly_score: 5445.877
# 157/500 epoch ge_loss: 52.704 d_loss: 0.002 anomaly_score: 5536.218
# 158/500 epoch ge_loss: 56.835 d_loss: 0.001 anomaly_score: 5177.584
# 159/500 epoch ge_loss: 54.890 d_loss: 0.002 anomaly_score: 5430.216
# 160/500 epoch ge_loss: 58.316 d_loss: 0.002 anomaly_score: 6452.618
# 161/500 epoch ge_loss: 61.902 d_loss: 0.001 anomaly_score: 5481.424
# 162/500 epoch ge_loss: 53.151 d_loss: 0.001 anomaly_score: 5725.673
# 163/500 epoch ge_loss: 55.937 d_loss: 0.001 anomaly_score: 5594.501
# 164/500 epoch ge_loss: 55.822 d_loss: 0.001 anomaly_score: 5260.039
# 165/500 epoch ge_loss: 62.635 d_loss: 0.003 anomaly_score: 6763.247
# 166/500 epoch ge_loss: 63.436 d_loss: 0.002 anomaly_score: 6649.435
# 167/500 epoch ge_loss: 57.443 d_loss: 0.001 anomaly_score: 5733.623
# 168/500 epoch ge_loss: 60.461 d_loss: 0.006 anomaly_score: 5568.648
# 169/500 epoch ge_loss: 61.199 d_loss: 0.001 anomaly_score: 5297.068
# 170/500 epoch ge_loss: 58.443 d_loss: 0.002 anomaly_score: 5522.293
# 171/500 epoch ge_loss: 54.994 d_loss: 0.001 anomaly_score: 5756.687
# 172/500 epoch ge_loss: 57.498 d_loss: 0.001 anomaly_score: 5340.107
# 173/500 epoch ge_loss: 58.636 d_loss: 0.002 anomaly_score: 5838.780
# 174/500 epoch ge_loss: 56.501 d_loss: 0.002 anomaly_score: 5737.735
# 175/500 epoch ge_loss: 54.845 d_loss: 0.002 anomaly_score: 5984.952
# 176/500 epoch ge_loss: 57.304 d_loss: 0.006 anomaly_score: 5213.519
# 177/500 epoch ge_loss: 54.898 d_loss: 0.002 anomaly_score: 5266.041
# 178/500 epoch ge_loss: 56.663 d_loss: 0.001 anomaly_score: 5494.341
# 179/500 epoch ge_loss: 57.120 d_loss: 0.001 anomaly_score: 5233.432
# 180/500 epoch ge_loss: 59.065 d_loss: 0.002 anomaly_score: 5297.518
# 181/500 epoch ge_loss: 56.994 d_loss: 0.001 anomaly_score: 5387.215
# 182/500 epoch ge_loss: 56.232 d_loss: 0.002 anomaly_score: 5420.704
# 183/500 epoch ge_loss: 56.407 d_loss: 0.001 anomaly_score: 5329.675
# 184/500 epoch ge_loss: 58.207 d_loss: 0.001 anomaly_score: 5652.292
# 185/500 epoch ge_loss: 58.232 d_loss: 0.001 anomaly_score: 5434.820
# 186/500 epoch ge_loss: 54.272 d_loss: 0.001 anomaly_score: 5206.657
# 187/500 epoch ge_loss: 56.086 d_loss: 0.002 anomaly_score: 5798.425
# 188/500 epoch ge_loss: 56.674 d_loss: 0.002 anomaly_score: 5096.046
# 189/500 epoch ge_loss: 56.591 d_loss: 0.001 anomaly_score: 4816.020
# 190/500 epoch ge_loss: 61.306 d_loss: 0.001 anomaly_score: 5660.987
# 191/500 epoch ge_loss: 57.225 d_loss: 0.002 anomaly_score: 5611.778
# 192/500 epoch ge_loss: 53.552 d_loss: 0.001 anomaly_score: 5886.872
# 193/500 epoch ge_loss: 54.710 d_loss: 0.001 anomaly_score: 5842.712
# 194/500 epoch ge_loss: 54.771 d_loss: 0.002 anomaly_score: 5023.322
# 195/500 epoch ge_loss: 54.266 d_loss: 0.001 anomaly_score: 5640.729
# 196/500 epoch ge_loss: 57.351 d_loss: 0.001 anomaly_score: 5186.565
# 197/500 epoch ge_loss: 52.586 d_loss: 0.003 anomaly_score: 5230.969
# 198/500 epoch ge_loss: 55.161 d_loss: 0.001 anomaly_score: 5116.706
# 199/500 epoch ge_loss: 53.995 d_loss: 0.003 anomaly_score: 5205.335
# 200/500 epoch ge_loss: 53.888 d_loss: 0.003 anomaly_score: 5160.350
# 201/500 epoch ge_loss: 59.806 d_loss: 0.001 anomaly_score: 5710.400
# 202/500 epoch ge_loss: 55.611 d_loss: 0.001 anomaly_score: 4771.506
# 203/500 epoch ge_loss: 51.473 d_loss: 0.001 anomaly_score: 4970.664
# 204/500 epoch ge_loss: 52.992 d_loss: 0.003 anomaly_score: 5303.166
# 205/500 epoch ge_loss: 56.717 d_loss: 0.004 anomaly_score: 5203.472
# 206/500 epoch ge_loss: 59.479 d_loss: 0.018 anomaly_score: 5394.930
# 207/500 epoch ge_loss: 52.527 d_loss: 0.002 anomaly_score: 5407.754
# 208/500 epoch ge_loss: 55.264 d_loss: 0.003 anomaly_score: 5383.795
# 209/500 epoch ge_loss: 52.051 d_loss: 0.001 anomaly_score: 4731.605
# 210/500 epoch ge_loss: 51.614 d_loss: 0.004 anomaly_score: 4890.025
# 211/500 epoch ge_loss: 53.416 d_loss: 0.003 anomaly_score: 5484.799
# 212/500 epoch ge_loss: 58.164 d_loss: 0.001 anomaly_score: 4974.303
# 213/500 epoch ge_loss: 57.070 d_loss: 0.001 anomaly_score: 5295.738
# 214/500 epoch ge_loss: 53.385 d_loss: 0.001 anomaly_score: 5147.379
# 215/500 epoch ge_loss: 53.354 d_loss: 0.004 anomaly_score: 5131.538
# 216/500 epoch ge_loss: 52.704 d_loss: 0.006 anomaly_score: 4990.406
# 217/500 epoch ge_loss: 55.655 d_loss: 0.004 anomaly_score: 5441.275
# 218/500 epoch ge_loss: 55.272 d_loss: 0.001 anomaly_score: 5135.032
# 219/500 epoch ge_loss: 50.802 d_loss: 0.003 anomaly_score: 4827.745
# 220/500 epoch ge_loss: 51.146 d_loss: 0.002 anomaly_score: 5359.795
# 221/500 epoch ge_loss: 54.078 d_loss: 0.002 anomaly_score: 5047.365
# 222/500 epoch ge_loss: 50.060 d_loss: 0.003 anomaly_score: 5374.991
# 223/500 epoch ge_loss: 53.554 d_loss: 0.002 anomaly_score: 5181.574
# 224/500 epoch ge_loss: 57.910 d_loss: 0.002 anomaly_score: 5096.469
# 225/500 epoch ge_loss: 56.275 d_loss: 0.002 anomaly_score: 5916.004
# 226/500 epoch ge_loss: 53.084 d_loss: 0.001 anomaly_score: 6366.227
# 227/500 epoch ge_loss: 58.748 d_loss: 0.002 anomaly_score: 4990.955
# 228/500 epoch ge_loss: 54.574 d_loss: 0.002 anomaly_score: 5481.268
# 229/500 epoch ge_loss: 53.632 d_loss: 0.001 anomaly_score: 5535.906
# 230/500 epoch ge_loss: 52.856 d_loss: 0.002 anomaly_score: 4809.813
# 231/500 epoch ge_loss: 52.843 d_loss: 0.001 anomaly_score: 5748.891
# 232/500 epoch ge_loss: 53.623 d_loss: 0.002 anomaly_score: 4961.017
# 233/500 epoch ge_loss: 55.069 d_loss: 0.002 anomaly_score: 4989.662
# 234/500 epoch ge_loss: 53.555 d_loss: 0.001 anomaly_score: 5493.727
# 235/500 epoch ge_loss: 49.237 d_loss: 0.001 anomaly_score: 4859.914
# 236/500 epoch ge_loss: 52.581 d_loss: 0.001 anomaly_score: 4908.420
# 237/500 epoch ge_loss: 51.621 d_loss: 0.001 anomaly_score: 5110.454
# 238/500 epoch ge_loss: 55.216 d_loss: 0.001 anomaly_score: 4924.307
# 239/500 epoch ge_loss: 52.159 d_loss: 0.002 anomaly_score: 4975.514
# 240/500 epoch ge_loss: 58.989 d_loss: 0.001 anomaly_score: 5528.111
# 241/500 epoch ge_loss: 54.854 d_loss: 0.001 anomaly_score: 5590.808
# 242/500 epoch ge_loss: 51.135 d_loss: 0.002 anomaly_score: 5129.283
# 243/500 epoch ge_loss: 55.233 d_loss: 0.001 anomaly_score: 4936.070
# 244/500 epoch ge_loss: 53.736 d_loss: 0.001 anomaly_score: 5378.494
# 245/500 epoch ge_loss: 50.697 d_loss: 0.001 anomaly_score: 5953.548
# 246/500 epoch ge_loss: 55.652 d_loss: 0.001 anomaly_score: 4766.162
# 247/500 epoch ge_loss: 51.245 d_loss: 0.001 anomaly_score: 4743.307
# 248/500 epoch ge_loss: 50.060 d_loss: 0.002 anomaly_score: 5132.469
# 249/500 epoch ge_loss: 51.883 d_loss: 0.002 anomaly_score: 5512.160
# 250/500 epoch ge_loss: 52.060 d_loss: 0.001 anomaly_score: 4807.779
# 251/500 epoch ge_loss: 56.741 d_loss: 0.001 anomaly_score: 5564.904
# 252/500 epoch ge_loss: 49.543 d_loss: 0.001 anomaly_score: 4412.172
# 253/500 epoch ge_loss: 49.009 d_loss: 0.002 anomaly_score: 5007.014
# 254/500 epoch ge_loss: 51.557 d_loss: 0.001 anomaly_score: 4546.128
# 255/500 epoch ge_loss: 49.016 d_loss: 0.001 anomaly_score: 4805.685
# 256/500 epoch ge_loss: 49.180 d_loss: 0.001 anomaly_score: 5401.693
# 257/500 epoch ge_loss: 48.174 d_loss: 0.001 anomaly_score: 5772.531
# 258/500 epoch ge_loss: 51.287 d_loss: 0.001 anomaly_score: 5973.492
# 259/500 epoch ge_loss: 51.075 d_loss: 0.001 anomaly_score: 4884.585
# 260/500 epoch ge_loss: 52.030 d_loss: 0.002 anomaly_score: 5207.714
# 261/500 epoch ge_loss: 58.257 d_loss: 0.001 anomaly_score: 5355.273
# 262/500 epoch ge_loss: 50.773 d_loss: 0.003 anomaly_score: 4482.823
# 263/500 epoch ge_loss: 54.016 d_loss: 0.002 anomaly_score: 4828.916
# 264/500 epoch ge_loss: 53.140 d_loss: 0.005 anomaly_score: 5267.369
# 265/500 epoch ge_loss: 53.417 d_loss: 0.007 anomaly_score: 5427.718
# 266/500 epoch ge_loss: 49.187 d_loss: 0.003 anomaly_score: 5498.782
# 267/500 epoch ge_loss: 55.117 d_loss: 0.004 anomaly_score: 5365.199
# 268/500 epoch ge_loss: 51.294 d_loss: 0.003 anomaly_score: 5055.721
# 269/500 epoch ge_loss: 53.311 d_loss: 0.002 anomaly_score: 5214.805
# 270/500 epoch ge_loss: 53.555 d_loss: 0.003 anomaly_score: 4702.191
# 271/500 epoch ge_loss: 49.629 d_loss: 0.001 anomaly_score: 4886.990
# 272/500 epoch ge_loss: 48.711 d_loss: 0.002 anomaly_score: 4855.629
# 273/500 epoch ge_loss: 53.887 d_loss: 0.002 anomaly_score: 5184.940
# 274/500 epoch ge_loss: 52.967 d_loss: 0.002 anomaly_score: 4941.114
# 275/500 epoch ge_loss: 52.871 d_loss: 0.002 anomaly_score: 5114.941
# 276/500 epoch ge_loss: 52.425 d_loss: 0.002 anomaly_score: 4809.640
# 277/500 epoch ge_loss: 49.664 d_loss: 0.001 anomaly_score: 5360.428
# 278/500 epoch ge_loss: 48.839 d_loss: 0.002 anomaly_score: 5226.766
# 279/500 epoch ge_loss: 51.079 d_loss: 0.002 anomaly_score: 4892.567
# 280/500 epoch ge_loss: 55.979 d_loss: 0.001 anomaly_score: 5075.043
# 281/500 epoch ge_loss: 49.057 d_loss: 0.004 anomaly_score: 4732.211
# 282/500 epoch ge_loss: 50.074 d_loss: 0.003 anomaly_score: 4756.842
# 283/500 epoch ge_loss: 48.429 d_loss: 0.001 anomaly_score: 5034.055
# 284/500 epoch ge_loss: 55.729 d_loss: 0.002 anomaly_score: 5326.100
# 285/500 epoch ge_loss: 51.082 d_loss: 0.002 anomaly_score: 5227.253
# 286/500 epoch ge_loss: 52.570 d_loss: 0.001 anomaly_score: 5169.947
# 287/500 epoch ge_loss: 52.300 d_loss: 0.001 anomaly_score: 5360.762
# 288/500 epoch ge_loss: 50.921 d_loss: 0.001 anomaly_score: 5010.853
# 289/500 epoch ge_loss: 51.424 d_loss: 0.002 anomaly_score: 5419.829
# 290/500 epoch ge_loss: 54.869 d_loss: 0.001 anomaly_score: 4796.198
# 291/500 epoch ge_loss: 54.644 d_loss: 0.001 anomaly_score: 5278.934
# 292/500 epoch ge_loss: 48.636 d_loss: 0.001 anomaly_score: 4818.804
# 293/500 epoch ge_loss: 59.509 d_loss: 0.001 anomaly_score: 5288.401
# 294/500 epoch ge_loss: 52.375 d_loss: 0.001 anomaly_score: 4519.450
# 295/500 epoch ge_loss: 50.095 d_loss: 0.002 anomaly_score: 5167.259
# 296/500 epoch ge_loss: 53.692 d_loss: 0.002 anomaly_score: 5010.412
# 297/500 epoch ge_loss: 51.091 d_loss: 0.002 anomaly_score: 4538.914
# 298/500 epoch ge_loss: 54.272 d_loss: 0.003 anomaly_score: 4658.504
# 299/500 epoch ge_loss: 50.044 d_loss: 0.001 anomaly_score: 4953.002
# 300/500 epoch ge_loss: 60.198 d_loss: 0.001 anomaly_score: 5162.953
# 301/500 epoch ge_loss: 52.368 d_loss: 0.002 anomaly_score: 4835.406
# 302/500 epoch ge_loss: 53.641 d_loss: 0.002 anomaly_score: 5050.174
# 303/500 epoch ge_loss: 49.667 d_loss: 0.002 anomaly_score: 5056.941
# 304/500 epoch ge_loss: 47.508 d_loss: 0.001 anomaly_score: 4722.075
# 305/500 epoch ge_loss: 48.905 d_loss: 0.003 anomaly_score: 4966.167
# 306/500 epoch ge_loss: 47.583 d_loss: 0.001 anomaly_score: 4748.553
# 307/500 epoch ge_loss: 49.206 d_loss: 0.001 anomaly_score: 4967.600
# 308/500 epoch ge_loss: 48.641 d_loss: 0.002 anomaly_score: 4502.092
# 309/500 epoch ge_loss: 47.856 d_loss: 0.002 anomaly_score: 4908.666
# 310/500 epoch ge_loss: 48.704 d_loss: 0.002 anomaly_score: 4821.659
# 311/500 epoch ge_loss: 57.229 d_loss: 0.002 anomaly_score: 5216.642
# 312/500 epoch ge_loss: 58.709 d_loss: 0.001 anomaly_score: 4952.596
# 313/500 epoch ge_loss: 52.835 d_loss: 0.001 anomaly_score: 5465.643
# 314/500 epoch ge_loss: 47.954 d_loss: 0.001 anomaly_score: 4754.358
# 315/500 epoch ge_loss: 50.591 d_loss: 0.001 anomaly_score: 5291.405
# 316/500 epoch ge_loss: 45.166 d_loss: 0.001 anomaly_score: 4885.996
# 317/500 epoch ge_loss: 54.047 d_loss: 0.001 anomaly_score: 4776.661
# 318/500 epoch ge_loss: 52.155 d_loss: 0.001 anomaly_score: 5335.429
# 319/500 epoch ge_loss: 51.438 d_loss: 0.002 anomaly_score: 5464.453
# 320/500 epoch ge_loss: 55.348 d_loss: 0.002 anomaly_score: 5616.452
# 321/500 epoch ge_loss: 49.571 d_loss: 0.001 anomaly_score: 4826.548
# 322/500 epoch ge_loss: 54.077 d_loss: 0.002 anomaly_score: 4942.573
# 323/500 epoch ge_loss: 51.153 d_loss: 0.002 anomaly_score: 5131.161
# 324/500 epoch ge_loss: 59.313 d_loss: 0.001 anomaly_score: 5017.947
# 325/500 epoch ge_loss: 49.471 d_loss: 0.002 anomaly_score: 5616.991
# 326/500 epoch ge_loss: 48.606 d_loss: 0.001 anomaly_score: 4981.612
# 327/500 epoch ge_loss: 53.628 d_loss: 0.002 anomaly_score: 4589.547
# 328/500 epoch ge_loss: 46.537 d_loss: 0.002 anomaly_score: 5079.122
# 329/500 epoch ge_loss: 49.685 d_loss: 0.001 anomaly_score: 5059.017
# 330/500 epoch ge_loss: 53.919 d_loss: 0.001 anomaly_score: 5188.248
# 331/500 epoch ge_loss: 50.558 d_loss: 0.002 anomaly_score: 4953.379
# 332/500 epoch ge_loss: 48.948 d_loss: 0.002 anomaly_score: 5342.513
# 333/500 epoch ge_loss: 59.361 d_loss: 0.002 anomaly_score: 4995.590
# 334/500 epoch ge_loss: 52.474 d_loss: 0.001 anomaly_score: 5706.644
# 335/500 epoch ge_loss: 52.183 d_loss: 0.003 anomaly_score: 5472.823
# 336/500 epoch ge_loss: 48.928 d_loss: 0.002 anomaly_score: 5118.175
# 337/500 epoch ge_loss: 46.815 d_loss: 0.001 anomaly_score: 5056.142
# 338/500 epoch ge_loss: 51.042 d_loss: 0.001 anomaly_score: 4817.772
# 339/500 epoch ge_loss: 52.101 d_loss: 0.001 anomaly_score: 5070.187
# 340/500 epoch ge_loss: 50.867 d_loss: 0.001 anomaly_score: 5185.339
# 341/500 epoch ge_loss: 49.489 d_loss: 0.003 anomaly_score: 4706.900
# 342/500 epoch ge_loss: 54.488 d_loss: 0.002 anomaly_score: 4708.160
# 343/500 epoch ge_loss: 50.493 d_loss: 0.003 anomaly_score: 5309.991
# 344/500 epoch ge_loss: 47.615 d_loss: 0.001 anomaly_score: 4929.920
# 345/500 epoch ge_loss: 47.389 d_loss: 0.001 anomaly_score: 5067.554
# 346/500 epoch ge_loss: 52.406 d_loss: 0.001 anomaly_score: 5066.577
# 347/500 epoch ge_loss: 46.024 d_loss: 0.004 anomaly_score: 5637.377
# 348/500 epoch ge_loss: 49.069 d_loss: 0.002 anomaly_score: 4956.247
# 349/500 epoch ge_loss: 50.344 d_loss: 0.005 anomaly_score: 5138.211
# 350/500 epoch ge_loss: 51.624 d_loss: 0.002 anomaly_score: 5229.975
# 351/500 epoch ge_loss: 48.618 d_loss: 0.002 anomaly_score: 5021.058
# 352/500 epoch ge_loss: 51.527 d_loss: 0.002 anomaly_score: 5174.952
# 353/500 epoch ge_loss: 52.026 d_loss: 0.001 anomaly_score: 5152.740
# 354/500 epoch ge_loss: 45.712 d_loss: 0.001 anomaly_score: 5098.467
# 355/500 epoch ge_loss: 49.904 d_loss: 0.001 anomaly_score: 4882.689
# 356/500 epoch ge_loss: 50.939 d_loss: 0.001 anomaly_score: 5007.253
# 357/500 epoch ge_loss: 48.392 d_loss: 0.002 anomaly_score: 5036.549
# 358/500 epoch ge_loss: 50.861 d_loss: 0.002 anomaly_score: 5408.731
# 359/500 epoch ge_loss: 46.140 d_loss: 0.002 anomaly_score: 4911.909
# 360/500 epoch ge_loss: 48.315 d_loss: 0.002 anomaly_score: 4632.295
# 361/500 epoch ge_loss: 45.681 d_loss: 0.001 anomaly_score: 4543.820
# 362/500 epoch ge_loss: 48.043 d_loss: 0.002 anomaly_score: 4622.513
# 363/500 epoch ge_loss: 55.718 d_loss: 0.008 anomaly_score: 5929.532
# 364/500 epoch ge_loss: 45.290 d_loss: 0.016 anomaly_score: 5702.626
# 365/500 epoch ge_loss: 52.326 d_loss: 0.007 anomaly_score: 5437.625
# 366/500 epoch ge_loss: 45.138 d_loss: 0.004 anomaly_score: 5143.409
# 367/500 epoch ge_loss: 49.432 d_loss: 0.003 anomaly_score: 4958.681
# 368/500 epoch ge_loss: 47.291 d_loss: 0.001 anomaly_score: 4753.170
# 369/500 epoch ge_loss: 48.608 d_loss: 0.003 anomaly_score: 5194.571
# 370/500 epoch ge_loss: 49.409 d_loss: 0.002 anomaly_score: 5106.349
# 371/500 epoch ge_loss: 52.443 d_loss: 0.002 anomaly_score: 4813.965
# 372/500 epoch ge_loss: 48.743 d_loss: 0.004 anomaly_score: 5396.802
# 373/500 epoch ge_loss: 52.531 d_loss: 0.004 anomaly_score: 5248.728
# 374/500 epoch ge_loss: 50.417 d_loss: 0.003 anomaly_score: 4763.349
# 375/500 epoch ge_loss: 50.194 d_loss: 0.002 anomaly_score: 5206.393
# 376/500 epoch ge_loss: 54.930 d_loss: 0.024 anomaly_score: 4603.411
# 377/500 epoch ge_loss: 57.708 d_loss: 0.007 anomaly_score: 4892.418
# 378/500 epoch ge_loss: 51.659 d_loss: 0.036 anomaly_score: 4936.874
# 379/500 epoch ge_loss: 54.112 d_loss: 0.013 anomaly_score: 5400.210
# 380/500 epoch ge_loss: 48.839 d_loss: 0.006 anomaly_score: 4804.857
# 381/500 epoch ge_loss: 46.538 d_loss: 0.003 anomaly_score: 4987.366
# 382/500 epoch ge_loss: 45.607 d_loss: 0.002 anomaly_score: 4947.201
# 383/500 epoch ge_loss: 49.866 d_loss: 0.002 anomaly_score: 5137.798
# 384/500 epoch ge_loss: 58.986 d_loss: 0.002 anomaly_score: 4617.644
# 385/500 epoch ge_loss: 49.614 d_loss: 0.002 anomaly_score: 4661.198
# 386/500 epoch ge_loss: 47.548 d_loss: 0.001 anomaly_score: 4922.545
# 387/500 epoch ge_loss: 49.258 d_loss: 0.002 anomaly_score: 4871.379
# 388/500 epoch ge_loss: 48.961 d_loss: 0.003 anomaly_score: 5303.681
# 389/500 epoch ge_loss: 45.050 d_loss: 0.002 anomaly_score: 4925.704
# 390/500 epoch ge_loss: 52.269 d_loss: 0.002 anomaly_score: 4875.061
# 391/500 epoch ge_loss: 49.852 d_loss: 0.004 anomaly_score: 5138.514
# 392/500 epoch ge_loss: 43.271 d_loss: 0.002 anomaly_score: 4802.459
# 393/500 epoch ge_loss: 56.905 d_loss: 0.014 anomaly_score: 4755.939
# 394/500 epoch ge_loss: 47.470 d_loss: 0.004 anomaly_score: 4961.772
# 395/500 epoch ge_loss: 55.474 d_loss: 0.002 anomaly_score: 4942.791
# 396/500 epoch ge_loss: 52.539 d_loss: 0.005 anomaly_score: 4751.752
# 397/500 epoch ge_loss: 48.491 d_loss: 0.003 anomaly_score: 4807.804
# 398/500 epoch ge_loss: 45.102 d_loss: 0.005 anomaly_score: 4694.914
# 399/500 epoch ge_loss: 44.235 d_loss: 0.003 anomaly_score: 4543.843
# 400/500 epoch ge_loss: 47.344 d_loss: 0.002 anomaly_score: 4808.977
# 401/500 epoch ge_loss: 47.905 d_loss: 0.002 anomaly_score: 4385.437
# 402/500 epoch ge_loss: 44.186 d_loss: 0.002 anomaly_score: 4672.570
# 403/500 epoch ge_loss: 48.968 d_loss: 0.001 anomaly_score: 4851.770
# 404/500 epoch ge_loss: 51.164 d_loss: 0.002 anomaly_score: 5033.135
# 405/500 epoch ge_loss: 45.663 d_loss: 0.002 anomaly_score: 5481.234
# 406/500 epoch ge_loss: 47.834 d_loss: 0.002 anomaly_score: 5232.260
# 407/500 epoch ge_loss: 45.534 d_loss: 0.002 anomaly_score: 4942.144
# 408/500 epoch ge_loss: 49.542 d_loss: 0.003 anomaly_score: 4662.956
# 409/500 epoch ge_loss: 65.238 d_loss: 0.002 anomaly_score: 5885.161
# 410/500 epoch ge_loss: 51.724 d_loss: 0.002 anomaly_score: 4543.611
# 411/500 epoch ge_loss: 53.316 d_loss: 0.001 anomaly_score: 4538.058
# 412/500 epoch ge_loss: 47.764 d_loss: 0.003 anomaly_score: 5065.441
# 413/500 epoch ge_loss: 50.595 d_loss: 0.002 anomaly_score: 4781.273
# 414/500 epoch ge_loss: 44.976 d_loss: 0.003 anomaly_score: 4899.089
# 415/500 epoch ge_loss: 46.806 d_loss: 0.002 anomaly_score: 4770.926
# 416/500 epoch ge_loss: 48.142 d_loss: 0.001 anomaly_score: 5262.499
# 417/500 epoch ge_loss: 45.567 d_loss: 0.002 anomaly_score: 5286.900
# 418/500 epoch ge_loss: 49.720 d_loss: 0.001 anomaly_score: 5243.494
# 419/500 epoch ge_loss: 47.825 d_loss: 0.001 anomaly_score: 5270.055
# 420/500 epoch ge_loss: 49.109 d_loss: 0.003 anomaly_score: 5062.204
# 421/500 epoch ge_loss: 47.864 d_loss: 0.001 anomaly_score: 5153.387
# 422/500 epoch ge_loss: 43.556 d_loss: 0.002 anomaly_score: 5114.953
# 423/500 epoch ge_loss: 44.660 d_loss: 0.003 anomaly_score: 4843.262
# 424/500 epoch ge_loss: 52.349 d_loss: 0.004 anomaly_score: 4435.116
# 425/500 epoch ge_loss: 44.731 d_loss: 0.004 anomaly_score: 4698.448
# 426/500 epoch ge_loss: 49.730 d_loss: 0.003 anomaly_score: 4790.519
# 427/500 epoch ge_loss: 49.993 d_loss: 0.002 anomaly_score: 4712.379
# 428/500 epoch ge_loss: 48.246 d_loss: 0.004 anomaly_score: 4865.062
# 429/500 epoch ge_loss: 51.967 d_loss: 0.002 anomaly_score: 4428.314
# 430/500 epoch ge_loss: 44.714 d_loss: 0.004 anomaly_score: 5040.091
# 431/500 epoch ge_loss: 50.436 d_loss: 0.004 anomaly_score: 5448.700
# 432/500 epoch ge_loss: 46.158 d_loss: 0.001 anomaly_score: 5232.846
# 433/500 epoch ge_loss: 50.938 d_loss: 0.003 anomaly_score: 5199.239
# 434/500 epoch ge_loss: 48.736 d_loss: 0.004 anomaly_score: 5299.625
# 435/500 epoch ge_loss: 48.702 d_loss: 0.003 anomaly_score: 5270.833
# 436/500 epoch ge_loss: 51.684 d_loss: 0.001 anomaly_score: 5196.336
# 437/500 epoch ge_loss: 47.893 d_loss: 0.001 anomaly_score: 4869.945
# 438/500 epoch ge_loss: 46.133 d_loss: 0.001 anomaly_score: 4992.890
# 439/500 epoch ge_loss: 50.336 d_loss: 0.001 anomaly_score: 4549.897
# 440/500 epoch ge_loss: 45.635 d_loss: 0.001 anomaly_score: 4529.422
# 441/500 epoch ge_loss: 46.176 d_loss: 0.002 anomaly_score: 4929.786
# 442/500 epoch ge_loss: 45.475 d_loss: 0.001 anomaly_score: 4803.182
# 443/500 epoch ge_loss: 44.188 d_loss: 0.002 anomaly_score: 4821.441
# 444/500 epoch ge_loss: 45.023 d_loss: 0.002 anomaly_score: 4728.248
# 445/500 epoch ge_loss: 50.582 d_loss: 0.001 anomaly_score: 4872.778
# 446/500 epoch ge_loss: 45.530 d_loss: 0.002 anomaly_score: 4706.846
# 447/500 epoch ge_loss: 45.550 d_loss: 0.001 anomaly_score: 5040.589
# 448/500 epoch ge_loss: 46.333 d_loss: 0.002 anomaly_score: 4457.468
# 449/500 epoch ge_loss: 47.338 d_loss: 0.001 anomaly_score: 4592.279
# 450/500 epoch ge_loss: 46.402 d_loss: 0.002 anomaly_score: 4819.694
# 451/500 epoch ge_loss: 48.395 d_loss: 0.002 anomaly_score: 4704.831
# 452/500 epoch ge_loss: 43.780 d_loss: 0.002 anomaly_score: 5114.536
# 453/500 epoch ge_loss: 47.655 d_loss: 0.003 anomaly_score: 5188.294
# 454/500 epoch ge_loss: 53.720 d_loss: 0.001 anomaly_score: 5428.278
# 455/500 epoch ge_loss: 47.834 d_loss: 0.007 anomaly_score: 5028.513
# 456/500 epoch ge_loss: 42.747 d_loss: 0.003 anomaly_score: 4763.223
# 457/500 epoch ge_loss: 54.369 d_loss: 0.004 anomaly_score: 4772.700
# 458/500 epoch ge_loss: 45.760 d_loss: 0.003 anomaly_score: 4582.958
# 459/500 epoch ge_loss: 46.275 d_loss: 0.004 anomaly_score: 4782.885
# 460/500 epoch ge_loss: 46.101 d_loss: 0.021 anomaly_score: 4716.988
# 461/500 epoch ge_loss: 46.235 d_loss: 0.011 anomaly_score: 5253.552
# 462/500 epoch ge_loss: 45.601 d_loss: 0.006 anomaly_score: 5129.128
# 463/500 epoch ge_loss: 49.493 d_loss: 0.004 anomaly_score: 5086.204
# 464/500 epoch ge_loss: 48.287 d_loss: 0.008 anomaly_score: 4406.403
# 465/500 epoch ge_loss: 44.117 d_loss: 0.006 anomaly_score: 4564.777
# 466/500 epoch ge_loss: 46.562 d_loss: 0.007 anomaly_score: 4889.702
# 467/500 epoch ge_loss: 47.037 d_loss: 0.006 anomaly_score: 4635.360
# 468/500 epoch ge_loss: 42.197 d_loss: 0.002 anomaly_score: 4708.157
# 469/500 epoch ge_loss: 45.332 d_loss: 0.008 anomaly_score: 4618.601
# 470/500 epoch ge_loss: 45.543 d_loss: 0.003 anomaly_score: 4606.464
# 471/500 epoch ge_loss: 47.979 d_loss: 0.001 anomaly_score: 5193.840
# 472/500 epoch ge_loss: 44.675 d_loss: 0.002 anomaly_score: 4616.463
# 473/500 epoch ge_loss: 46.211 d_loss: 0.020 anomaly_score: 4548.001
# 474/500 epoch ge_loss: 58.625 d_loss: 0.005 anomaly_score: 4621.743
# 475/500 epoch ge_loss: 44.296 d_loss: 0.003 anomaly_score: 4587.469
# 476/500 epoch ge_loss: 45.743 d_loss: 0.011 anomaly_score: 4795.814
# 477/500 epoch ge_loss: 46.652 d_loss: 0.006 anomaly_score: 5139.999
# 478/500 epoch ge_loss: 52.427 d_loss: 0.003 anomaly_score: 5067.973
# 479/500 epoch ge_loss: 49.362 d_loss: 0.004 anomaly_score: 5209.774
# 480/500 epoch ge_loss: 43.175 d_loss: 0.004 anomaly_score: 5374.215
# 481/500 epoch ge_loss: 47.587 d_loss: 0.002 anomaly_score: 5117.687
# 482/500 epoch ge_loss: 46.093 d_loss: 0.002 anomaly_score: 4572.080
# 483/500 epoch ge_loss: 45.490 d_loss: 0.002 anomaly_score: 5002.188
# 484/500 epoch ge_loss: 42.835 d_loss: 0.002 anomaly_score: 4465.650
# 485/500 epoch ge_loss: 46.023 d_loss: 0.004 anomaly_score: 4743.059
# 486/500 epoch ge_loss: 46.684 d_loss: 0.002 anomaly_score: 4796.419
# 487/500 epoch ge_loss: 48.321 d_loss: 0.001 anomaly_score: 4445.486
# 488/500 epoch ge_loss: 43.373 d_loss: 0.004 anomaly_score: 4684.877
# 489/500 epoch ge_loss: 47.003 d_loss: 0.003 anomaly_score: 4374.429
# 490/500 epoch ge_loss: 43.473 d_loss: 0.003 anomaly_score: 4646.580
# 491/500 epoch ge_loss: 44.684 d_loss: 0.002 anomaly_score: 4970.368
# 492/500 epoch ge_loss: 44.500 d_loss: 0.002 anomaly_score: 4886.135
# 493/500 epoch ge_loss: 41.615 d_loss: 0.002 anomaly_score: 4765.149
# 494/500 epoch ge_loss: 43.942 d_loss: 0.002 anomaly_score: 4969.438
# 495/500 epoch ge_loss: 44.828 d_loss: 0.001 anomaly_score: 5162.898
# 496/500 epoch ge_loss: 51.845 d_loss: 0.001 anomaly_score: 5750.380
# 497/500 epoch ge_loss: 44.853 d_loss: 0.001 anomaly_score: 4931.567
# 498/500 epoch ge_loss: 46.833 d_loss: 0.001 anomaly_score: 5182.121
# 499/500 epoch ge_loss: 47.071 d_loss: 0.002 anomaly_score: 5024.758

# %%
# Generator+EncoderとDiscriminatorのLossの推移と、anomaly scoreの推移
plt.figure(figsize=(12, 8*2))

plt.subplot(211)
plt.plot(range(len(Losses_GE)), Losses_GE, label="ge loss",color="blue")
plt.legend()

plt.plot(range(len(Losses_D)), Losses_D, label="d loss",color="orange")
plt.legend()
plt.subplot(212)
plt.plot(range(len(anomaly_scores)), anomaly_scores, label="anomaly score",color="green")
plt.legend()

plt.show()

# %% [markdown]
# # 潜在変数Zの最適化とテスト画像での異常検知

# %%
# 学習したモデルの読み込み

LOAD_EPOCH = 500

G = Generator().to(device)
G.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Generator_{LOAD_EPOCH}.pkl"))
G.eval()


E = Encoder().to(device)
E.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Encoder_{LOAD_EPOCH}.pkl"))
E.eval()

D = Discriminator().to(device)
D.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Discriminator_{LOAD_EPOCH}.pkl"))
D.eval()
print("load model")
# Out:
# load model

# %% [markdown]
# # good

# %%
# 正常な画像で実行

random_image_size = 40

test_root_normal = './screw/test/good/'
test_dataset_normal = LoadFromFolder(test_root_normal, transform=transform_dict["test"])

test_images_normal = random.sample(list(test_dataset_normal), random_image_size)

normal_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_normal)):

    x = test_images_normal[idx].view(1, 3, 192, 192).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    normal_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %% [markdown]
# # manipulated_front

# %%
# manipulated_frontで実行

random_image_size = 20

test_root_manipulated_front = './screw/test/manipulated_front/'
test_dataset_manipulated_front = LoadFromFolder(test_root_manipulated_front, transform=transform_dict["test"])

test_images_manipulated_front = random.sample(list(test_dataset_manipulated_front), random_image_size)

manipulated_front_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_manipulated_front)):

    x = test_images_manipulated_front[idx].view(1, 3, 192, 192).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    manipulated_front_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %% [markdown]
# # scratch_head

# %%
# scratch_headで実行

random_image_size = 20

test_root_scratch_head = './screw/test/scratch_head/'
test_dataset_scratch_head = LoadFromFolder(test_root_scratch_head, transform=transform_dict["test"])

test_images_scratch_head = random.sample(list(test_dataset_scratch_head), random_image_size)

scratch_head_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_scratch_head)):

    x = test_images_scratch_head[idx].view(1, 3, 192, 192).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    scratch_head_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %% [markdown]
# # scratch_neck

# %%
# scratch_neckで実行

random_image_size = 20

test_root_scratch_neck = './screw/test/scratch_neck/'
test_dataset_scratch_neck = LoadFromFolder(test_root_scratch_neck, transform=transform_dict["test"])

test_images_scratch_neck = random.sample(list(test_dataset_scratch_neck), random_image_size)

scratch_neck_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_scratch_neck)):

    x = test_images_scratch_neck[idx].view(1, 3, 192, 192).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    scratch_neck_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %% [markdown]
# # thread_side

# %%
# thread_sideで実行

random_image_size = 20

test_root_thread_side = './screw/test/thread_side/'
test_dataset_thread_side = LoadFromFolder(test_root_thread_side, transform=transform_dict["test"])

test_images_thread_side = random.sample(list(test_dataset_thread_side), random_image_size)

thread_side_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_thread_side)):

    x = test_images_thread_side[idx].view(1, 3, 192, 192).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    thread_side_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %% [markdown]
# # thread_top

# %%
# thread_topで実行

random_image_size = 20

test_root_thread_top = './screw/test/thread_top/'
test_dataset_thread_top = LoadFromFolder(test_root_thread_top, transform=transform_dict["test"])

test_images_thread_top = random.sample(list(test_dataset_thread_top), random_image_size)

thread_top_anomaly_score = []

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_thread_top)):

    x = test_images_thread_top[idx].view(1, 3, 192, 192).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    thread_top_anomaly_score.append(loss)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %%
# 正常品のスコアをデータフレーム化
normal_df = pd.DataFrame({'score': normal_anomaly_score})
normal_df['label'] = 'normal'

# manipulated_frontのスコアをデータフレーム化
manipulated_front_df = pd.DataFrame({'score': manipulated_front_anomaly_score})
manipulated_front_df['label'] = 'manipulated_front'

# scratch_headのスコアをデータフレーム化
scratch_head_df = pd.DataFrame({'score': scratch_head_anomaly_score})
scratch_head_df['label'] = 'scratch_head'

# scratch_neckのスコアをデータフレーム化
scratch_neck_df = pd.DataFrame({'score': scratch_neck_anomaly_score})
scratch_neck_df['label'] = 'scratch_neck'

# thread_sideのスコアをデータフレーム化
thread_side_df = pd.DataFrame({'score': thread_side_anomaly_score})
thread_side_df['label'] = 'thread_side'

# thread_topのスコアをデータフレーム化
thread_top_df = pd.DataFrame({'score': thread_top_anomaly_score})
thread_top_df['label'] = 'thread_top'

#テストデータのlossを可視化
plt.hist(normal_df['score'], alpha=0.5, bins=20, label='normal')
plt.hist(manipulated_front_df['score'], alpha=0.5, bins=20, label='manipulated_front')
plt.hist(scratch_head_df['score'], alpha=0.5, bins=20, label='scratch_head')
plt.hist(scratch_neck_df['score'], alpha=0.5, bins=20, label='scratch_neck')
plt.hist(thread_side_df['score'], alpha=0.5, bins=20, label='thread_side')
plt.hist(thread_top_df['score'], alpha=0.5, bins=20, label='thread_top')
plt.legend(loc="upper right", fontsize=13)
plt.show()
